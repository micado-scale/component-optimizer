# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Import-dependecies" data-toc-modified-id="Import-dependecies-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Import dependecies</a></span></li><li><span><a href="#Set-variables" data-toc-modified-id="Set-variables-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Set variables</a></span></li><li><span><a href="#Data-Pre-processing" data-toc-modified-id="Data-Pre-processing-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Data Pre-processing</a></span></li><li><span><a href="#Define-Target-Variable" data-toc-modified-id="Define-Target-Variable-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Define Target Variable</a></span></li><li><span><a href="#Rename-Worker-count-to-WorkerCount" data-toc-modified-id="Rename-Worker-count-to-WorkerCount-1.0.5"><span class="toc-item-num">1.0.5&nbsp;&nbsp;</span>Rename Worker count to WorkerCount</a></span></li><li><span><a href="#Define-Metric-Names" data-toc-modified-id="Define-Metric-Names-1.0.6"><span class="toc-item-num">1.0.6&nbsp;&nbsp;</span>Define Metric Names</a></span></li><li><span><a href="#Extended-Metric-Names" data-toc-modified-id="Extended-Metric-Names-1.0.7"><span class="toc-item-num">1.0.7&nbsp;&nbsp;</span>Extended Metric Names</a></span></li><li><span><a href="#Filter-some-cases---cut-off-the-begining-of-the-Time-Series" data-toc-modified-id="Filter-some-cases---cut-off-the-begining-of-the-Time-Series-1.0.8"><span class="toc-item-num">1.0.8&nbsp;&nbsp;</span>Filter some cases - cut off the begining of the Time Series</a></span></li><li><span><a href="#Filtered-to-preProcessed" data-toc-modified-id="Filtered-to-preProcessed-1.0.9"><span class="toc-item-num">1.0.9&nbsp;&nbsp;</span>Filtered to preProcessed</a></span></li></ul></li><li><span><a href="#Data-Investigation" data-toc-modified-id="Data-Investigation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Investigation</a></span><ul class="toc-item"><li><span><a href="#Describe-DataFrame" data-toc-modified-id="Describe-DataFrame-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Describe DataFrame</a></span></li><li><span><a href="#Correlation-Matrix" data-toc-modified-id="Correlation-Matrix-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Correlation Matrix</a></span></li><li><span><a href="#Visualize-Data" data-toc-modified-id="Visualize-Data-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Visualize Data</a></span></li><li><span><a href="#Innter-State-Metrics-over-Time" data-toc-modified-id="Innter-State-Metrics-over-Time-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Innter State Metrics over Time</a></span></li><li><span><a href="#Auto-Correlation" data-toc-modified-id="Auto-Correlation-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>Auto Correlation</a></span></li><li><span><a href="#Measure-Auto-Correlation" data-toc-modified-id="Measure-Auto-Correlation-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Measure Auto Correlation</a></span></li></ul></li><li><span><a href="#Create-a-whole-new-DataFrame-for-Before-After-Data" data-toc-modified-id="Create-a-whole-new-DataFrame-for-Before-After-Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Create a whole new DataFrame for Before After Data</a></span><ul class="toc-item"><li><span><a href="#Set-Features-for-Neural-Network---these-are-the-input-variables" data-toc-modified-id="Set-Features-for-Neural-Network---these-are-the-input-variables-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Set Features for Neural Network - these are the input variables</a></span></li><li><span><a href="#Set-Target-Variable-for-Neural-Network---this-is-the-target-variable" data-toc-modified-id="Set-Target-Variable-for-Neural-Network---this-is-the-target-variable-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Set Target Variable for Neural Network - this is the target variable</a></span></li><li><span><a href="#Normalize-the-whole-X" data-toc-modified-id="Normalize-the-whole-X-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Normalize the whole X</a></span></li><li><span><a href="#Load-MinMaxScalerXFull" data-toc-modified-id="Load-MinMaxScalerXFull-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Load MinMaxScalerXFull</a></span></li><li><span><a href="#Normalize-the-whole-y" data-toc-modified-id="Normalize-the-whole-y-1.2.5"><span class="toc-item-num">1.2.5&nbsp;&nbsp;</span>Normalize the whole y</a></span></li><li><span><a href="#Load-MinMaxScalerYFull" data-toc-modified-id="Load-MinMaxScalerYFull-1.2.6"><span class="toc-item-num">1.2.6&nbsp;&nbsp;</span>Load MinMaxScalerYFull</a></span></li></ul></li><li><span><a href="#Train-Neural-Network-with-Optimizer-Class,-trainMultiLayerRegressor-method" data-toc-modified-id="Train-Neural-Network-with-Optimizer-Class,-trainMultiLayerRegressor-method-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Train Neural Network with Optimizer Class, trainMultiLayerRegressor method</a></span><ul class="toc-item"><li><span><a href="#Create-Prediction-for-Evaluation" data-toc-modified-id="Create-Prediction-for-Evaluation-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Create Prediction for Evaluation</a></span></li><li><span><a href="#Evaluate-Goodness-of-Fit" data-toc-modified-id="Evaluate-Goodness-of-Fit-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Evaluate Goodness of Fit</a></span></li><li><span><a href="#Show-the-input-variables" data-toc-modified-id="Show-the-input-variables-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Show the input variables</a></span></li><li><span><a href="#Visualize-Data" data-toc-modified-id="Visualize-Data-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Visualize Data</a></span></li><li><span><a href="#De-normlaize" data-toc-modified-id="De-normlaize-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>De-normlaize</a></span></li><li><span><a href="#Can-I-visualize-the-de-normalized-data-as-well?" data-toc-modified-id="Can-I-visualize-the-de-normalized-data-as-well?-1.3.6"><span class="toc-item-num">1.3.6&nbsp;&nbsp;</span>Can I visualize the de-normalized data as well?</a></span></li><li><span><a href="#Compare-the-Original-Target-Variable-and-the-mean-of-its-Predicted-Values" data-toc-modified-id="Compare-the-Original-Target-Variable-and-the-mean-of-its-Predicted-Values-1.3.7"><span class="toc-item-num">1.3.7&nbsp;&nbsp;</span>Compare the Original Target Variable and the mean of its Predicted Values</a></span></li><li><span><a href="#De-normalizer-function" data-toc-modified-id="De-normalizer-function-1.3.8"><span class="toc-item-num">1.3.8&nbsp;&nbsp;</span>De-normalizer function</a></span></li></ul></li><li><span><a href="#Create-Train-Test-Validation-set" data-toc-modified-id="Create-Train-Test-Validation-set-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Create Train-Test-Validation set</a></span><ul class="toc-item"><li><span><a href="#Split-Data" data-toc-modified-id="Split-Data-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Split Data</a></span></li><li><span><a href="#Differences-between-Train-and-Test-X" data-toc-modified-id="Differences-between-Train-and-Test-X-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Differences between Train and Test X</a></span></li><li><span><a href="#Differences-between-Train-and-Test-y" data-toc-modified-id="Differences-between-Train-and-Test-y-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Differences between Train and Test y</a></span></li><li><span><a href="#There-are-major-differencies" data-toc-modified-id="There-are-major-differencies-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>There are major differencies</a></span></li><li><span><a href="#The-Bad-Plot" data-toc-modified-id="The-Bad-Plot-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>The Bad Plot</a></span></li><li><span><a href="#Train-Test-set-comparison" data-toc-modified-id="Train-Test-set-comparison-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Train Test set comparison</a></span></li><li><span><a href="#Normalize-Data---based-on-Train-set---It-is-forbiden-to-use-Test-set" data-toc-modified-id="Normalize-Data---based-on-Train-set---It-is-forbiden-to-use-Test-set-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>Normalize Data - based on Train set - It is forbiden to use Test set</a></span></li><li><span><a href="#Csináltam-egy-Train-Test-összehasonlítást-de-csak-a-target-változóra,-jó-lenne-az-Inputokra-is" data-toc-modified-id="Csináltam-egy-Train-Test-összehasonlítást-de-csak-a-target-változóra,-jó-lenne-az-Inputokra-is-1.4.8"><span class="toc-item-num">1.4.8&nbsp;&nbsp;</span>Csináltam egy Train Test összehasonlítást de csak a target változóra, jó lenne az Inputokra is</a></span></li><li><span><a href="#De-normalizer-function-train-test-version" data-toc-modified-id="De-normalizer-function-train-test-version-1.4.9"><span class="toc-item-num">1.4.9&nbsp;&nbsp;</span>De-normalizer function train test version</a></span></li><li><span><a href="#Is-there-a-huge-difference-between-the-real-Response-Time-and-the-De-Normalized-Response-time?-In-the-Train-and-the-Test-set-respectively?" data-toc-modified-id="Is-there-a-huge-difference-between-the-real-Response-Time-and-the-De-Normalized-Response-time?-In-the-Train-and-the-Test-set-respectively?-1.4.10"><span class="toc-item-num">1.4.10&nbsp;&nbsp;</span>Is there a huge difference between the real Response Time and the De-Normalized Response time? In the Train and the Test set respectively?</a></span></li></ul></li><li><span><a href="#Train-the-Neural-Network-on-the-Train-Data-Set,-then-make-prediction-on-Test-Data-Set" data-toc-modified-id="Train-the-Neural-Network-on-the-Train-Data-Set,-then-make-prediction-on-Test-Data-Set-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Train the Neural Network on the Train Data Set, then make prediction on Test Data Set</a></span><ul class="toc-item"><li><span><a href="#!!!-Same-as-the-Original-Whole-Data-solution" data-toc-modified-id="!!!-Same-as-the-Original-Whole-Data-solution-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>!!! Same as the Original Whole Data solution</a></span></li><li><span><a href="#Create-Prediction-for-Evaluation" data-toc-modified-id="Create-Prediction-for-Evaluation-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Create Prediction for Evaluation</a></span></li><li><span><a href="#Evaluate-Goodness-of-Fit" data-toc-modified-id="Evaluate-Goodness-of-Fit-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Evaluate Goodness of Fit</a></span></li><li><span><a href="#De-normalize-data" data-toc-modified-id="De-normalize-data-1.5.4"><span class="toc-item-num">1.5.4&nbsp;&nbsp;</span>De-normalize data</a></span></li><li><span><a href="#Visualize-De-Normalized-Data" data-toc-modified-id="Visualize-De-Normalized-Data-1.5.5"><span class="toc-item-num">1.5.5&nbsp;&nbsp;</span>Visualize De-Normalized Data</a></span></li><li><span><a href="#Visualize-Normalized-Data" data-toc-modified-id="Visualize-Normalized-Data-1.5.6"><span class="toc-item-num">1.5.6&nbsp;&nbsp;</span>Visualize Normalized Data</a></span></li><li><span><a href="#Show-Predicted-values-on-Test-data" data-toc-modified-id="Show-Predicted-values-on-Test-data-1.5.7"><span class="toc-item-num">1.5.7&nbsp;&nbsp;</span>Show Predicted values on Test data</a></span><ul class="toc-item"><li><span><a href="#Train-De-normalized" data-toc-modified-id="Train-De-normalized-1.5.7.1"><span class="toc-item-num">1.5.7.1&nbsp;&nbsp;</span>Train De-normalized</a></span></li><li><span><a href="#Train-Normalized" data-toc-modified-id="Train-Normalized-1.5.7.2"><span class="toc-item-num">1.5.7.2&nbsp;&nbsp;</span>Train Normalized</a></span></li></ul></li><li><span><a href="#Show-Predcited-values-on-Test-data" data-toc-modified-id="Show-Predcited-values-on-Test-data-1.5.8"><span class="toc-item-num">1.5.8&nbsp;&nbsp;</span>Show Predcited values on Test data</a></span><ul class="toc-item"><li><span><a href="#Test-De-normalized" data-toc-modified-id="Test-De-normalized-1.5.8.1"><span class="toc-item-num">1.5.8.1&nbsp;&nbsp;</span>Test De-normalized</a></span></li><li><span><a href="#Test-Normalized" data-toc-modified-id="Test-Normalized-1.5.8.2"><span class="toc-item-num">1.5.8.2&nbsp;&nbsp;</span>Test Normalized</a></span></li></ul></li></ul></li><li><span><a href="#Inner-state-variable-and-Linear-Regression-Part" data-toc-modified-id="Inner-state-variable-and-Linear-Regression-Part-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Inner state variable and Linear Regression Part</a></span><ul class="toc-item"><li><span><a href="#Import-Python-dependencies" data-toc-modified-id="Import-Python-dependencies-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Import Python dependencies</a></span></li><li><span><a href="#Create-Inner-State-Variables-Lags" data-toc-modified-id="Create-Inner-State-Variables-Lags-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Create Inner State Variables Lags</a></span></li><li><span><a href="#Create-Inner-State-Variables-Leads" data-toc-modified-id="Create-Inner-State-Variables-Leads-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Create Inner State Variables Leads</a></span></li><li><span><a href="#Show-Prev,-Current,-Next" data-toc-modified-id="Show-Prev,-Current,-Next-1.6.4"><span class="toc-item-num">1.6.4&nbsp;&nbsp;</span>Show Prev, Current, Next</a></span><ul class="toc-item"><li><span><a href="#Assert" data-toc-modified-id="Assert-1.6.4.1"><span class="toc-item-num">1.6.4.1&nbsp;&nbsp;</span>Assert</a></span></li></ul></li><li><span><a href="#Calculate-difference-of-the-number-of-Workers" data-toc-modified-id="Calculate-difference-of-the-number-of-Workers-1.6.5"><span class="toc-item-num">1.6.5&nbsp;&nbsp;</span>Calculate difference of the number of Workers</a></span></li><li><span><a href="#Select-that-cases-where-WorkerCount-and-nextWorkerCount-is-not-equall" data-toc-modified-id="Select-that-cases-where-WorkerCount-and-nextWorkerCount-is-not-equall-1.6.6"><span class="toc-item-num">1.6.6&nbsp;&nbsp;</span>Select that cases where WorkerCount and nextWorkerCount is not equall</a></span></li><li><span><a href="#Before-I-get-further-lets-see-some-distribution-of-Inner-State-Variables---regards-to-the-addedWorkerCount" data-toc-modified-id="Before-I-get-further-lets-see-some-distribution-of-Inner-State-Variables---regards-to-the-addedWorkerCount-1.6.7"><span class="toc-item-num">1.6.7&nbsp;&nbsp;</span>Before I get further lets see some distribution of Inner State Variables - regards to the addedWorkerCount</a></span></li><li><span><a href="#Create-a-temporary-DataFrame-where-I-am-going-to-store-the-differecne-between-the-inner-state-metrics-before-after-values" data-toc-modified-id="Create-a-temporary-DataFrame-where-I-am-going-to-store-the-differecne-between-the-inner-state-metrics-before-after-values-1.6.8"><span class="toc-item-num">1.6.8&nbsp;&nbsp;</span>Create a temporary DataFrame where I am going to store the differecne between the inner state metrics before after values</a></span></li><li><span><a href="#Means-of-Metrics-after-changed-the-number-of-workers" data-toc-modified-id="Means-of-Metrics-after-changed-the-number-of-workers-1.6.9"><span class="toc-item-num">1.6.9&nbsp;&nbsp;</span>Means of Metrics after changed the number of workers</a></span></li><li><span><a href="#This-is-the-end-of-Data-Visualization-and-Exploration-Part" data-toc-modified-id="This-is-the-end-of-Data-Visualization-and-Exploration-Part-1.6.10"><span class="toc-item-num">1.6.10&nbsp;&nbsp;</span>This is the end of Data Visualization and Exploration Part</a></span></li></ul></li><li><span><a href="#Lets-discover-and-learn-the-linear-relationship-between-the-before-after-metrics-values" data-toc-modified-id="Lets-discover-and-learn-the-linear-relationship-between-the-before-after-metrics-values-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Lets discover and learn the linear relationship between the before after metrics values</a></span><ul class="toc-item"><li><span><a href="#Here-comes-the-magic-function" data-toc-modified-id="Here-comes-the-magic-function-1.7.1"><span class="toc-item-num">1.7.1&nbsp;&nbsp;</span>Here comes the magic function</a></span></li><li><span><a href="#Use-the-above-formula-to-create-model" data-toc-modified-id="Use-the-above-formula-to-create-model-1.7.2"><span class="toc-item-num">1.7.2&nbsp;&nbsp;</span>Use the above formula to create model</a></span></li><li><span><a href="#I-wrote-some-functions-for-Linear-Regression:" data-toc-modified-id="I-wrote-some-functions-for-Linear-Regression:-1.7.3"><span class="toc-item-num">1.7.3&nbsp;&nbsp;</span>I wrote some functions for Linear Regression:</a></span></li><li><span><a href="#Create-a-Copy-of-scalingDF" data-toc-modified-id="Create-a-Copy-of-scalingDF-1.7.4"><span class="toc-item-num">1.7.4&nbsp;&nbsp;</span>Create a Copy of scalingDF</a></span></li><li><span><a href="#Learn-the-relation-between-WorkerCount,-AddedWorker-and-Metrics-with-Linear-Regression" data-toc-modified-id="Learn-the-relation-between-WorkerCount,-AddedWorker-and-Metrics-with-Linear-Regression-1.7.5"><span class="toc-item-num">1.7.5&nbsp;&nbsp;</span>Learn the relation between WorkerCount, AddedWorker and Metrics with Linear Regression</a></span></li><li><span><a href="#Stored-Linear-Regression-Models-in-a-dictionary" data-toc-modified-id="Stored-Linear-Regression-Models-in-a-dictionary-1.7.6"><span class="toc-item-num">1.7.6&nbsp;&nbsp;</span>Stored Linear Regression Models in a dictionary</a></span></li><li><span><a href="#Stored-temporaryScalingDF-for-exploration" data-toc-modified-id="Stored-temporaryScalingDF-for-exploration-1.7.7"><span class="toc-item-num">1.7.7&nbsp;&nbsp;</span>Stored temporaryScalingDF for exploration</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-1.7.8"><span class="toc-item-num">1.7.8&nbsp;&nbsp;</span>Plots</a></span></li><li><span><a href="#End-of-Learning-Phase" data-toc-modified-id="End-of-Learning-Phase-1.7.9"><span class="toc-item-num">1.7.9&nbsp;&nbsp;</span>End of Learning Phase</a></span></li></ul></li></ul></li><li><span><a href="#Advice-Phase---Production-Phase" data-toc-modified-id="Advice-Phase---Production-Phase-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Advice Phase - Production Phase</a></span><ul class="toc-item"><li><span><a href="#Begining-of-Estimation-Phase" data-toc-modified-id="Begining-of-Estimation-Phase-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Begining of Estimation Phase</a></span><ul class="toc-item"><li><span><a href="#ToDo" data-toc-modified-id="ToDo-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>ToDo</a></span></li><li><span><a href="#Solution-1" data-toc-modified-id="Solution-1-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Solution 1</a></span><ul class="toc-item"><li><span><a href="#-2.-Import-functions-from-utils" data-toc-modified-id="-2.-Import-functions-from-utils-2.1.2.1"><span class="toc-item-num">2.1.2.1&nbsp;&nbsp;</span>-2. Import functions from utils</a></span></li><li><span><a href="#-1.-Load-sclaers,-models" data-toc-modified-id="-1.-Load-sclaers,-models-2.1.2.2"><span class="toc-item-num">2.1.2.2&nbsp;&nbsp;</span>-1. Load sclaers, models</a></span></li><li><span><a href="#0.-Set-variables" data-toc-modified-id="0.-Set-variables-2.1.2.3"><span class="toc-item-num">2.1.2.3&nbsp;&nbsp;</span>0. Set variables</a></span></li><li><span><a href="#1.-Read-data" data-toc-modified-id="1.-Read-data-2.1.2.4"><span class="toc-item-num">2.1.2.4&nbsp;&nbsp;</span>1. Read data</a></span></li><li><span><a href="#2.-Pre-process-data" data-toc-modified-id="2.-Pre-process-data-2.1.2.5"><span class="toc-item-num">2.1.2.5&nbsp;&nbsp;</span>2. Pre-process data</a></span></li></ul></li><li><span><a href="#Check-out-newFilteredDF" data-toc-modified-id="Check-out-newFilteredDF-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Check out newFilteredDF</a></span><ul class="toc-item"><li><span><a href="#Add-new-workers-(increse-the-nuber-of-added-Worker)" data-toc-modified-id="Add-new-workers-(increse-the-nuber-of-added-Worker)-2.1.3.1"><span class="toc-item-num">2.1.3.1&nbsp;&nbsp;</span>Add new workers (increse the nuber of added Worker)</a></span></li><li><span><a href="#Method-A." data-toc-modified-id="Method-A.-2.1.3.2"><span class="toc-item-num">2.1.3.2&nbsp;&nbsp;</span>Method A.</a></span></li><li><span><a href="#Complex-cummulative-inner-state-meric-prediction" data-toc-modified-id="Complex-cummulative-inner-state-meric-prediction-2.1.3.3"><span class="toc-item-num">2.1.3.3&nbsp;&nbsp;</span>Complex cummulative inner state meric prediction</a></span></li></ul></li><li><span><a href="#Merge-Up-and-Down-Adviser" data-toc-modified-id="Merge-Up-and-Down-Adviser-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Merge Up and Down Adviser</a></span></li><li><span><a href="#Show-Result" data-toc-modified-id="Show-Result-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Show Result</a></span></li><li><span><a href="#Get-Advice" data-toc-modified-id="Get-Advice-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Get Advice</a></span></li><li><span><a href="#Brand-New" data-toc-modified-id="Brand-New-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Brand New</a></span></li><li><span><a href="#Save-Output" data-toc-modified-id="Save-Output-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>Save Output</a></span></li><li><span><a href="#End-of-Test" data-toc-modified-id="End-of-Test-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>End of Test</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <a id="train_import"></a>
# - [jump method A](#method_A)
# - [jump test import](#test_import)
# - [jump test begin](#test_begin)

# %% [markdown]
# # Initialize
# ### Import dependecies

# %%
# import optimizer as op

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.externals import joblib

# import plotly
# import plotly.plotly as py
# import plotly.graph_objs as go
# import plotly.figure_factory as ff

np.set_printoptions(precision=3, suppress=True)

pandas_dataframe_styles = {
    'font-family': 'monospace',
    'white-space': 'pre'
}

# %% [markdown]
# ### Set variables

# %%
inputCSVFile   = 'data/grafana_data_export_long_running_test.csv'
# inputCSVFile   = 'data/micado_v0.7.3_0725_v2.csv'

targetVariable = 'avg latency (quantile 0.5)'


scaler_min = -1                     # 0
scaler_max = 1                      # 1
train_test_ratio = 0.3              # 0.3
activation_function = 'tanh'        # tanh, relu, logistic
neuronsWhole = 10                   # 10
neuronsTrainTest = 4                # 4
cutFirstCases = 10                  # 10

lead = 1                            # 1 default

showPlots = True                    # True

# %% [markdown]
# ### Data Pre-processing

# %%
def readCSV(filename):
    df = pd.read_csv(filename, sep=";", header="infer", skiprows=1, na_values="null" )

    # Return DataFrame
    return df

# %%
# Read DataFrame
df = readCSV(inputCSVFile)

# %%
def removeMissingData(df):
    cleanDF = df.dropna(axis=0)
    return cleanDF


def dropVariable(df, column):
    del df[column]
    return df


def preProcessing(df):
    df = df.copy()
    
    # Drop Time
    if( df.columns.contains('Time')):
        df = dropVariable(df, 'Time')
    if( df.columns.contains('avg latency (quantile 0.9)')):
        df = dropVariable(df, 'avg latency (quantile 0.9)')
    if( df.columns.contains('stddev q0.5')):
        df = dropVariable(df, 'stddev q0.5')
    if( df.columns.contains('stddev q0.9')):
        df = dropVariable(df, 'stddev q0.9')

    # Debug
    # printDF(df)

    # Remove cases with missing values
    df = removeMissingData(df)
    return df

# %%
# Preprecess DataFrame
preProcessedDF = preProcessing(df)

# %% [markdown]
# ### Define Target Variable

# %%
targetVariable = targetVariable

# %% [markdown]
# ### Rename Worker count to WorkerCount

# %%
def renameVariable(df, old_var_name, new_var_name):
    new_df = df.copy()
    new_df.rename(columns={old_var_name: new_var_name}, inplace=True)
    return new_df

# %%
preProcessedDF = renameVariable(preProcessedDF, 'Worker count', 'WorkerCount')

# %% [markdown]
# ### Define Metric Names

# %%
def setMetricNames(names):
    new_metricNames = names.copy()
    return new_metricNames

# %%
metricNames = setMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut'])

# %% [markdown]
# ### Extended Metric Names

# %%
def setExtendedMetricNames(names):
    new_extendedMetricNames = names.copy()
    return new_extendedMetricNames

# %%
extendedMetricNames = setExtendedMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount'])

extendedMetricNames
# Out:
# ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount']

# %% [markdown]
# ### Reorder columns

# %%
def reorderColumns(df, metricNames, targetVariable):
    metricNames = ['AVG RR', 'SUM RR'] + metricNames + ['WorkerCount'] + [targetVariable]
    print(metricNames)
    tmp_df = df[metricNames]
    return tmp_df

# %%
preProcessedDF = reorderColumns(preProcessedDF, metricNames, targetVariable)
# Out:
# ['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)']

# %% [markdown]
# ### Filter some cases - cut off the begining of the Time Series

# %%
def dropFirstCases(df, n):
    new_df = df.copy()
    filteredDF = new_df[new_df.index > n]
    return filteredDF

# %%
# because in the begining of the samples have a lot of outliers

filteredDF = dropFirstCases(preProcessedDF, cutFirstCases)

# %% [markdown]
# ### Filtered to preProcessed

# %%
preProcessedDF = filteredDF

# %% [markdown]
# ## Data Investigation
#
# ### Describe DataFrame

# %%
preProcessedDF.describe().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c26d5726_c1af_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
preProcessedDF.describe().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c42dd748_c1af_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### Correlation Matrix

# %%
from visualizer import CorrelationMatrixSave

# %%
CorrelationMatrixSave(preProcessedDF)
# Out:
# Loading page (1/2)
# Rendering (2/2)
# Done

# %%
preProcessedDF.corr().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}").background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_ca801f5c_c1af_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#             background-color:  #08306b;
#         }    #T_ca801f5c_c1af_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#             background-color:  #f7fbff;
#         }    #T_ca801f5c_c1af_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#             background-color:  #5aa2cf;
#         }    #T_ca801f5c_c1af_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#             background-color:  #3080bd;
#         }    #T_ca801f5c_c1af_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#             background-color:  #549fcd;
#         }    #T_ca801f5c_c1af_11e9_b6b8_fa163ebcacb9row0_col5 {
# ...

# %% [markdown]
# ### Visualize Data

# %%
from visualizer import ScatterPlots

# %%
if showPlots : ScatterPlots(preProcessedDF, preProcessedDF[targetVariable], extendedMetricNames, targetVariable)

# %%
from visualizer import TimeLinePlot

# %%
if showPlots : TimeLinePlot(preProcessedDF, targetVariable)

# %% [markdown]
# ### Innter State Metrics over Time

# %%
from visualizer import TimeLinePlots

# %%
if showPlots : TimeLinePlots(preProcessedDF, extendedMetricNames)

# %% [markdown]
# ### Auto Correlation

# %%
from pandas.plotting import autocorrelation_plot

fig = plt.figure(figsize=(20,8))

if showPlots : autocorrelation_plot(preProcessedDF[targetVariable])

# %% [markdown]
# ### Measure Auto Correlation
#
# because later these values will be calculated from predicted inner state variables

# %%
n = 1
for i in preProcessedDF.columns:
    print('AC(1)      ', i, '\t= ', np.round(preProcessedDF[i].autocorr(lag=1), 2))
    n = n+1
    if( n == 10 ):
        break
# Out:
# AC(1)       AVG RR 	=  0.71
# AC(1)       SUM RR 	=  0.82
# AC(1)       CPU 	=  0.77
# AC(1)       Inter 	=  0.76
# AC(1)       CTXSW 	=  0.75
# AC(1)       KBIn 	=  0.4
# AC(1)       PktIn 	=  0.8
# AC(1)       KBOut 	=  0.76
# AC(1)       PktOut 	=  0.78

# %% [markdown]
# ## Create a whole new DataFrame for Before After Data

# %%
def createBeforeafterDF(df, lag):
    beforeafterDF = df.copy()
    inputVariables = np.flip(beforeafterDF.columns[0:9].ravel(), axis=-1)
    print('Input Variablels : ', inputVariables)

    index = 9
    for i in inputVariables:
        new_column = beforeafterDF[i].shift(lag)
        new_column_name = (i + str(1)) # Todo: rename str(lag)
        beforeafterDF.insert(loc=index, column=new_column_name, value=new_column)
    
    beforeafterDF = beforeafterDF[lag:]
    
    print('Before After DF columns: ', beforeafterDF.columns)
    
    return beforeafterDF

# %%
beforeafterDF = createBeforeafterDF(preProcessedDF, 1)
# Out:
# Input Variablels :  ['PktOut' 'KBOut' 'PktIn' 'KBIn' 'CTXSW' 'Inter' 'CPU' 'SUM RR' 'AVG RR']
# Before After DF columns:  Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'AVG RR1', 'SUM RR1', 'CPU1', 'Inter1', 'CTXSW1', 'KBIn1',
#        'PktIn1', 'KBOut1', 'PktOut1', 'WorkerCount',
#        'avg latency (quantile 0.5)'],
#       dtype='object')

# %%
beforeafterDF.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_0e80b5e4_c1c5_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### Set Features for Neural Network - these are the input variables

# %%
def setFeaturesAndTheirLags(df):
    X = df.iloc[:,0:9]
    return X

# %%
X = setFeaturesAndTheirLags(beforeafterDF)

# %%
X.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_122add0a_c1c5_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
X.describe().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_131aa09c_c1c5_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### Set Target Variable for Neural Network - this is the target variable

# %%
def setTarget(df, targetVariable):
    y = df[targetVariable]
    return y

# %%
y = setTarget(beforeafterDF, targetVariable)

# %%
y.values[0:10]
# Out:
# array([ 1498608.567,  1499530.468,  2170280.382,  1602826.789,
#         1679743.324,    24193.916,    32378.571,    50828.776,
#         2760269.008,  2760269.008])

# %%
y.head()
# Out:
# 13    1.498609e+06
# 14    1.499530e+06
# 15    2.170280e+06
# 16    1.602827e+06
# 17    1.679743e+06
# Name: avg latency (quantile 0.5), dtype: float64

# %%
y.describe()
# Out:
# count    6.730000e+02
# mean     3.619691e+06
# std      3.217239e+06
# min      2.419392e+04
# 25%      2.479101e+06
# 50%      3.207532e+06
# 75%      4.119402e+06
# max      4.203820e+07
# Name: avg latency (quantile 0.5), dtype: float64

# %% [markdown]
# ### Normalize the whole X

# %%
def normalizeX(df):
    """Return a normalized value of df.
    Save MinMaxScaler normalizer for X variable"""
    
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    # scaler.fit(df)
    scaler.fit(df.astype(np.float64))
    # normalized = scaler.transform(df)
    normalized = scaler.transform(df.astype(np.float64))
    
    # store MinMaxScaler for X
    joblib.dump(scaler, 'models/scaler_normalizeX.save') 

    return normalized, scaler

# %%
X_normalized, X_normalized_MinMaxScaler = normalizeX(X)

# %% [markdown]
# ### Load MinMaxScalerXFull

# %%
def loadMinMaxScalerXFull():
    X_normalized_MinMaxScaler = joblib.load('models/scaler_normalizeX.save')
    
    return X_normalized_MinMaxScaler

# %%
X_normalized_MinMaxScaler = loadMinMaxScalerXFull()

# %%
def printNormalizedX(X_normalized):
    print("X_normalized type        = ", type(X_normalized))
    print("X_normalizde dtype       = ", X_normalized.dtype)
    print("X_normalized shape       = ", X_normalized.shape)
    print("X_normalized ndim        = ", X_normalized.ndim)
    print("X_normalized[:,0].max()  = ", X_normalized[:,0].max())
    print("X_normalized[:,0].min()  = ", X_normalized[:,0].min())

# %%
printNormalizedX(X_normalized)
# Out:
# X_normalized type        =  <class 'numpy.ndarray'>
# X_normalizde dtype       =  float64
# X_normalized shape       =  (673, 9)
# X_normalized ndim        =  2
# X_normalized[:,0].max()  =  1.0
# X_normalized[:,0].min()  =  -1.0

# %%
X_normalized[1]
# Out:
# array([-0.495, -0.586,  0.437, -0.143,  0.272, -0.627, -0.37 , -0.222,
#        -0.229])

# %%
X_denormalized = X_normalized_MinMaxScaler.inverse_transform(X_normalized)

# %%
X_denormalized[1]
# Out:
# array([    43.837,     87.674,     87.675,   6773.008,  10261.946,
#          1086.267,   1985.507,    205.35 ,   1670.186])

# %%
X_denormalized[-1]
# Out:
# array([   56.849,   113.698,    84.537,  6142.203,  9008.754,   981.49 ,
#         1888.163,   201.356,  1698.07 ])

# %% [markdown]
# ### Normalize the whole y

# %%
def normalizeY(df):
    """Return a normalized value of df.
    Save MinMaxScaler normalizer for Y variable"""
    
    new_df = df.copy()
    new_df_reshaped = new_df.values.reshape(-1,1)
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    scaler.fit(new_df_reshaped.astype(np.float64))
    normalizedY = scaler.transform(new_df_reshaped.astype(np.float64))
    normalizedY = normalizedY.flatten()
    
    # store MinMaxScaler for Y
    joblib.dump(scaler, 'models/scaler_normalizeY.save') 

    return normalizedY, scaler

# %%
y_normalized, y_normalized_MinMaxScaler = normalizeY(y)

# %%
def printNormalizedY(y_normalized):
    """Void. Print normalizeY(df) values"""
    
    print("y_normalized type        = ", type(y_normalized))
    print("y_normalized dtype       = ", y_normalized.dtype)
    print("y_normalized shape       = ", y_normalized.shape)
    print("y_normalized ndim        = ", y_normalized.ndim)
    print("y_normalized[:].max()    = ", y_normalized[:].max())
    print("y_normalized[:].min()    = ", y_normalized[:].min())

# %%
printNormalizedY(y_normalized)
# Out:
# y_normalized type        =  <class 'numpy.ndarray'>
# y_normalized dtype       =  float64
# y_normalized shape       =  (673,)
# y_normalized ndim        =  1
# y_normalized[:].max()    =  1.0
# y_normalized[:].min()    =  -1.0

# %%
y_normalized[0:3]
# Out:
# array([-0.93 , -0.93 , -0.898])

# %% [markdown]
# ### Load MinMaxScalerYFull

# %%
def loadMinMaxScalerYFull():
    y_normalized_MinMaxScaler = joblib.load('models/scaler_normalizeY.save')
    
    return y_normalized_MinMaxScaler

# %%
y_normalized_MinMaxScaler = loadMinMaxScalerYFull()

# %%
### Test MinMaxScalerYFull

# %%
y_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_normalized.reshape(y_normalized.shape[0],1))

# %%
y_denormalized[0:3]
# Out:
# array([[ 1498608.567],
#        [ 1499530.468],
#        [ 2170280.382]])

# %%
y_denormalized[-3:]
# Out:
# array([[ 4974982.36 ],
#        [ 4081220.691],
#        [ 4553424.952]])

# %% [markdown]
# ## Train Neural Network with Optimizer Class, trainMultiLayerRegressor method

# %%
def trainMultiLayerRegressor(X_normalized, y_normalized, activation, neuronsWhole):

    # Train Neural Network
    mlp = MLPRegressor(hidden_layer_sizes=neuronsWhole, \
                       max_iter=250, \
                       activation=activation, \
                       solver="lbfgs", \
                       learning_rate="constant", \
                       learning_rate_init=0.01, \
                       alpha=0.01, \
                       verbose=False, \
                       momentum=0.9, \
                       early_stopping=False, \
                       tol=0.00000001, \
                       shuffle=False, \
                       # n_iter_no_change=20, \
                       random_state=1234)

    mlp.fit(X_normalized, y_normalized)
    
    # ide kéne beilleszteni a modell elmentését
    joblib.dump(mlp, 'models/saved_mlp_model.pkl')

    return mlp

# %%
# Train Neural Network
mlp = trainMultiLayerRegressor(X_normalized, y_normalized, activation_function, neuronsWhole)

# %% [markdown]
# ### Create Prediction for Evaluation

# %%
def predictMultiLayerRegressor(mlp, X_normalized):
    y_predicted = mlp.predict(X_normalized)

    return y_predicted

# %%
# Create prediction
y_predicted = predictMultiLayerRegressor(mlp, X_normalized)

# %% [markdown]
# ### Evaluate Goodness of Fit
#
# <a id="neural_network_evaluation"></a>

# %%
from utils import evaluateGoodnessOfPrediction

# %%
evaluateGoodnessOfPrediction(y_normalized, y_predicted)
# Out:
# Correlation           = 0.605
# Explained variance    = 0.366
# Mean Absolute Error   = 0.067
# Mean Squared Error    = 0.015
# R2 Score              = 0.366

# %% [markdown]
# ### Show the input variables

# %%
X.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut'],
#       dtype='object')

# %% [markdown]
# ### Visualize Data

# %%
from visualizer import VisualizePredictedYScatter

# %%
VisualizePredictedYScatter(y_normalized, y_predicted, targetVariable)

# %%
from visualizer import VisualizePredictedYLine, VisualizePredictedYLineWithValues

# %%
VisualizePredictedYLineWithValues(y_normalized, y_predicted, targetVariable, 'Normalized')

# %% [markdown]
# ### De-normlaize
#
# I want to see the result in original scale. I don't care about the X but the y_normalized and y_predcited.

# %%
y_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_normalized.reshape(y_normalized.shape[0],1))

y_predicted_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_predicted.reshape(y_predicted.shape[0],1))

# %% [markdown]
# While `y_predicted` has 1 dimension and its shape is (673,) de-normalization based on scikit.MinMaxScaler can be done if the input is transformed back to its own original shape which shape is (673, 1)
#
# I can check it with these two lines of code:
#
# `print(y_predicted.shape)`<br>
# `print(y_predicted_denormalized.shape)`

# %% [markdown]
# ### Can I visualize the de-normalized data as well?

# %%
VisualizePredictedYLineWithValues(y_denormalized, y_predicted_denormalized, targetVariable, 'Denormalized')

# %% [markdown]
# ### Compare the Original Target Variable and the mean of its Predicted Values

# %%
meanOfOriginalPandasDataframe = y.values.mean()
meanOfOriginalTargetVariable  = y_denormalized.mean()
meanOfPredictedTargetVariable = y_predicted_denormalized.mean()

print('mean original pandas dataframe = ', meanOfOriginalPandasDataframe)
print('mean original target variable  = ', meanOfOriginalTargetVariable)
print('mean predicted target variable = ', meanOfPredictedTargetVariable)
# Out:
# mean original pandas dataframe =  3619691.41872
# mean original target variable  =  3619691.41872
# mean predicted target variable =  3627819.30705

# %% [markdown]
# ### De-normalizer function

# %%
def denormalizeX(X_normalized, X_normalized_MinMaxScaler):
    X_denormalized = X_normalized_MinMaxScaler.inverse_transform(X_normalized)
    return X_denormalized

# %%
X_denormalized = denormalizeX(X_normalized, X_normalized_MinMaxScaler)

# %%
X_denormalized[1]
# Out:
# array([    43.837,     87.674,     87.675,   6773.008,  10261.946,
#          1086.267,   1985.507,    205.35 ,   1670.186])

# %%
X_normalized[1]
# Out:
# array([-0.495, -0.586,  0.437, -0.143,  0.272, -0.627, -0.37 , -0.222,
#        -0.229])

# %%
X_denormalized[-1]
# Out:
# array([   56.849,   113.698,    84.537,  6142.203,  9008.754,   981.49 ,
#         1888.163,   201.356,  1698.07 ])

# %%
X_normalized[-1]
# Out:
# array([ 0.074, -0.383,  0.294, -0.471, -0.318, -0.733, -0.462, -0.263,
#        -0.197])

# %%
def denormalizeY(y_normalized, y_normalized_MinMaxScaler):
    y_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_normalized.reshape(y_normalized.shape[0],1))
    return y_denormalized

# %%
y_denormalized = denormalizeY(y_normalized, y_normalized_MinMaxScaler)

y_predicted_denormalized = denormalizeY(y_predicted, y_normalized_MinMaxScaler)

# %%
VisualizePredictedYLineWithValues(y_denormalized, y_predicted_denormalized, targetVariable, 'Denormalized')

# %% [markdown]
# ## Create Train-Test-Validation set
#
# ### Split Data

# %%
def splitDataFrame(X, y, testSize):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, \
                                                        random_state=12345, \
                                                        shuffle=False, \
                                                        stratify=None)

    return X_train, X_test, y_train, y_test

# %%
# Split DataFrame
X_train, X_test, y_train, y_test = splitDataFrame(X, y, train_test_ratio)

# %%
print(X_train.count())
# Out:
# AVG RR    471
# SUM RR    471
# CPU       471
# Inter     471
# CTXSW     471
# KBIn      471
# PktIn     471
# KBOut     471
# PktOut    471
# dtype: int64

# %%
print(X_test.count())
# Out:
# AVG RR    202
# SUM RR    202
# CPU       202
# Inter     202
# CTXSW     202
# KBIn      202
# PktIn     202
# KBOut     202
# PktOut    202
# dtype: int64

# %%
print("y_train.count() = ", y_train.count())
print("y_test.count()  = ", y_test.count())
# Out:
# y_train.count() =  471
# y_test.count()  =  202

# %% [markdown]
# ### Differences between Train and Test X

# %%
describeX_train = X_train.describe()
describeX_test  = X_test.describe()
columnNamesX_test = [x + 'T' for x in describeX_test.columns]
describeX_test.columns = columnNamesX_test
# compareX_train_X_test = pd.concat([describeX_train, describeX_test], axis=1, sort=False)
compareX_train_X_test = pd.concat([describeX_train, describeX_test], axis=1)
compareX_train_X_test.sort_index(axis=1, inplace=True)

compareX_train_X_test.style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6c_c1c6_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### Differences between Train and Test y
#
# <a id="compare_train_test_set"></a>
#
# `There is huge difference in y_train and y_test and you can see not just in the normalized data, but in the raw data as well.`
#
# `This fact indicates that the model can not be good.`
#
# `As far as I do here nothing but a back test, the test result doesn't play a big role in this case.`
#
# `What is more important is the overall or the train result.`

# %%
describey_train = y_train.describe().to_frame()
describey_test  = y_test.describe().to_frame()
columnNamesy_test = [x + 'T' for x in describey_test.columns]
describey_test.columns = columnNamesy_test
# comparey_train_y_test = pd.concat([describey_train, describey_test], axis=1, sort=False)
comparey_train_y_test = pd.concat([describey_train, describey_test], axis=1)
comparey_train_y_test.sort_index(axis=1, inplace=True)

comparey_train_y_test['Difference in percent'] = (comparey_train_y_test['avg latency (quantile 0.5)'] - comparey_train_y_test['avg latency (quantile 0.5)T'])/(comparey_train_y_test['avg latency (quantile 0.5)'])*100

comparey_train_y_test.style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b5e85e6d_c1c6_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
from utils import compareTwoVariables

# %%
compareTwoVariables(X_train, X_test, 'CPU')
# Out:
# <style  type="text/css" >
#     #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89a_c1c6_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
compareTwoVariables(X_train, X_test, 'CTXSW')
# Out:
# <style  type="text/css" >
#     #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89b_c1c6_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
compareTwoVariables(X_train, X_test, 'AVG RR')
# Out:
# <style  type="text/css" >
#     #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_b70aa89c_c1c6_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### There are major differencies
#
# `This is how it looks like the real data without null values. There are two differencies. First, there are lot more observations. Second, there are not interpollated data at all. So this plot is more reliable than the following one.`

# %%
VisualizePredictedYLineWithValues(y.values, y_train.values, targetVariable, 'Denormalized')

# %% [markdown]
# ### The Bad Plot
#
# `If I take into account the missing values than the plot will be incorrect`

# %%
VisualizePredictedYLineWithValues(y, y_train, targetVariable, 'Denormalized')

# %% [markdown]
# `y_test is a pandas.dataframe so it preserves the indexes`

# %%
VisualizePredictedYLineWithValues(0, y_test, targetVariable, 'Denormalized')

# %% [markdown]
# `while y_test.values is a numpy.array without any indexes`

# %%
VisualizePredictedYLineWithValues(0, y_test.values, targetVariable, 'Denormalized')

# %% [markdown]
# `I can show the differences on the following plot`

# %%
VisualizePredictedYLineWithValues(y_train, y_train.values, targetVariable, 'Denormalized')

# %% [markdown]
# ### Train Test set comparison

# %%
from utils import printInfoTrainTestSet

# %%
printInfoTrainTestSet(y_train, y_test)
# Out:
# y_train.min()             =  24193.916
# y_test.min()              =  229587.881
# ------------------------------------------
# type(y_train)             =  <class 'pandas.core.series.Series'>
# type(y_test)              =  <class 'pandas.core.series.Series'>
# ------------------------------------------
# type(y_train.values)      =  <class 'numpy.ndarray'>
# type(y_test.values)       =  <class 'numpy.ndarray'>
# ------------------------------------------
# y_train.values.min()      =  24193.916
# y_test.values.min()       =  229587.881
# ------------------------------------------
# y_train.values.max()      =  32912000.374
# y_test.values.max()       =  42038198.617
# ------------------------------------------
# y_train.values.argmin()   =  5
# y_test.values.argmin()    =  19
# ------------------------------------------
# y_train.values.argmax()   =  240
# y_test.values.argmax()    =  28
# ------------------------------------------
# y_train.idxmin()          =  18
# ...

# %%
y_train.values[0:10]
# Out:
# array([ 1498608.567,  1499530.468,  2170280.382,  1602826.789,
#         1679743.324,    24193.916,    32378.571,    50828.776,
#         2760269.008,  2760269.008])

# %%
y_test.values[10:20]
# Out:
# array([ 5594757.536,  5547258.272,  3778227.519,  2343328.501,
#         3842487.763,  5217770.458,  4943885.104,  2584097.733,
#         2083820.325,   229587.881])

# %% [markdown]
# ### Normalize Data - based on Train set - It is forbiden to use Test set

# %%
def normalizeXTrainTest(X_train, X_test):
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    scaler.fit(X_train)
    X_train_normalized = scaler.transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    return X_train_normalized, X_test_normalized, scaler

# %%
X_train_normalized, X_test_normalized, X_normalized_MinMaxScalerTrainTest = normalizeXTrainTest(X_train, X_test)

# %%
print("X_train_normalized max = ", X_train_normalized.max())
print("X_train_normalized min = ", X_train_normalized.min())
print("X_test_normalized max  = ", X_test_normalized.max())
print("X_test_normalized min  = ", X_test_normalized.min())
# Out:
# X_train_normalized max =  1.0
# X_train_normalized min =  -1.0
# X_test_normalized max  =  1.0
# X_test_normalized min  =  -1.02083227423

# %%
def normalizeYTrainTest(y_train, y_test):
    # Create numpy.array from pandas.series then reshape numpy array
    y_train_input = y_train.values.reshape(-1, 1)
    y_test_input = y_test.values.reshape(-1, 1)
    # Scaler
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    scaler.fit(y_train_input)
    # Scale
    y_train_normalized_tmp = scaler.transform(y_train_input)
    y_test_normalized_tmp = scaler.transform(y_test_input)
    # Flat numpy.array
    y_train_normalized = y_train_normalized_tmp.flatten()
    y_test_normalized = y_test_normalized_tmp.flatten()

    return y_train_normalized, y_test_normalized, scaler

# %%
y_train_normalized, y_test_normalized, y_normalized_MinMaxScalerTrainTest = normalizeYTrainTest(y_train, y_test)

# %%
print("y_train_normalized max = ", y_train_normalized.max())
print("y_train_normalized min = ", y_train_normalized.min())
print("y_test_normalized max  = ", y_test_normalized.max())
print("y_test_normalized min  = ", y_test_normalized.min())
# Out:
# y_train_normalized max =  1.0
# y_train_normalized min =  -1.0
# y_test_normalized max  =  1.55498978046
# y_test_normalized min  =  -0.987509415366

# %%
# ToDo: There is a quite big diff between the train max and the test max value

# %%
from utils import printInfoNumpyArrays

# %%
printInfoNumpyArrays(y_train_normalized, y_test_normalized)
# Out:
# type(y_train)             =  <class 'numpy.ndarray'>
# type(y_test)              =  <class 'numpy.ndarray'>
# ------------------------------------------
# len(y_train)              =  471
# len(y_test)               =  202
# ------------------------------------------
# y_train.size              =  471
# y_test.size               =  202
# ------------------------------------------
# y_train.shape             =  (471,)
# y_test.shape              =  (202,)
# ------------------------------------------
# y_train.min               =  -1.0
# y_test.min                =  -0.987509415366
# ------------------------------------------
# y_train.max               =  1.0
# y_test.max                =  1.55498978046

# %%
printInfoNumpyArrays(y_train, y_test)
# Out:
# type(y_train)             =  <class 'pandas.core.series.Series'>
# type(y_test)              =  <class 'pandas.core.series.Series'>
# ------------------------------------------
# len(y_train)              =  471
# len(y_test)               =  202
# ------------------------------------------
# y_train.size              =  471
# y_test.size               =  202
# ------------------------------------------
# y_train.shape             =  (471,)
# y_test.shape              =  (202,)
# ------------------------------------------
# y_train.min               =  24193.916
# y_test.min                =  229587.881
# ------------------------------------------
# y_train.max               =  32912000.374
# y_test.max                =  42038198.617

# %% [markdown]
# ### Csináltam egy Train Test összehasonlítást de csak a target változóra, jó lenne az Inputokra is

# %%
for i in range(0,9):
    print(X_test_normalized[:,i].min())
    print(X_test_normalized[:,i].max())
    print('--------------------------')
# Out:
# -0.892778123319
# 0.925000613381
# --------------------------
# -1.02083227423
# 0.903520298425
# --------------------------
# -0.122322514627
# 1.0
# --------------------------
# -0.76708183367
# 0.912774493606
# --------------------------
# -0.750447581807
# 0.878339324448
# --------------------------
# -0.872004712958
# 0.874473818425
# --------------------------
# -0.6713302944
# 0.699040661439
# --------------------------
# -0.588795295738
# 0.917562261089
# --------------------------
# -0.529004385985
# 0.916726794555
# --------------------------

# %% [markdown]
# ### De-normalizer function train test version
#
# It is enough to use/create one scaler both for training and test data, because the scaler was trained on train data.
#
# Moreover I can use the same denormalizer function, as far as I pass the Scaler object to the denormalizer function.

# %%
X_train_denormalized = denormalizeX(X_train_normalized, X_normalized_MinMaxScalerTrainTest)

# %%
X_train_denormalized[1]
# Out:
# array([    43.837,     87.674,     87.675,   6773.008,  10261.946,
#          1086.267,   1985.507,    205.35 ,   1670.186])

# %%
X_train_denormalized[-1]
# Out:
# array([    37.367,     37.367,     99.861,   7154.323,  10088.424,
#          1159.979,   2323.698,    230.304,   1964.863])

# %%
X_test_denormalized = denormalizeX(X_test_normalized, X_normalized_MinMaxScalerTrainTest)

# %%
X_test_denormalized[-1]
# Out:
# array([   56.849,   113.698,    84.537,  6142.203,  9008.754,   981.49 ,
#         1888.163,   201.356,  1698.07 ])

# %%
X_test_normalized[-1]
# Out:
# array([ 0.074, -0.397,  0.294, -0.471, -0.318, -0.733, -0.462, -0.263,
#        -0.197])

# %%
y_train_denormalized = denormalizeY(y_train_normalized, y_normalized_MinMaxScalerTrainTest)

# %%
y_train_denormalized[0:3]
# Out:
# array([[ 1498608.567],
#        [ 1499530.467],
#        [ 2170280.382]])

# %%
y_train_denormalized[-3:]
# Out:
# array([[ 2083708.691],
#        [   27936.473],
#        [ 3330059.227]])

# %%
y_test_denormalized = denormalizeY(y_test_normalized, y_normalized_MinMaxScalerTrainTest)

# %%
y_test_denormalized[0:3]
# Out:
# array([[ 3322625.049],
#        [ 3240987.356],
#        [ 4750506.478]])

# %%
y_test_denormalized[-3:]
# Out:
# array([[ 4974982.36 ],
#        [ 4081220.691],
#        [ 4553424.952]])

# %%
y_test_normalized[-3:]
# Out:
# array([-0.699, -0.753, -0.725])

# %% [markdown]
# While `y_test_denormalized` won't change as differnt split point will be chosen the `y_test_normalized` will.
#
# This means that these normalize, de-normalize procedures work fine.<br><br>

# %% [markdown]
# ### Is there a huge difference between the real Response Time and the De-Normalized Response time? In the Train and the Test set respectively?

# %%
# plottoljuk ki az eredeti average response timeot és a normalizáció után helyreállítottat a test és a tanuló mintán

# %%
VisualizePredictedYLineWithValues(y.values, y_train_denormalized, targetVariable, 'Denormalized')

# %%
VisualizePredictedYLineWithValues(y.values[len(y_train_denormalized):], y_test_denormalized, targetVariable, 'Denormalized')

# %%
# Gyakorlatilag igaz, hogy csak a train adatokon tanítottuk meg a normalizációt,
# de mivel utána ennek alapján normalizáltuk le a teszt adatokat is azon természetesen az eredeti min max értéknél
# nagyobbak is előfordultak.
#
# Ugyanakkor ez nem jelenti azt, hogy a vissza normalizálásnál ne tudnánk helyre állítani az eredeti adatokat,
# csak a train adatokon megtanult normalizáció alapján, akár a teszt adatokon is.

# %% [markdown]
# ## Train the Neural Network on the Train Data Set, then make prediction on Test Data Set

# %% [markdown]
# ### !!! Same as the Original Whole Data solution

# %%
# this is the same as did it before, when whole dataset was trained

def trainMultiLayerRegressor(X_train_normalized, y_train_normalized, activation, neuronsTrainTest):

    # Train Neural Network
    mlp = MLPRegressor(hidden_layer_sizes=neuronsTrainTest, \
                       max_iter=250, \
                       activation=activation, \
                       solver="lbfgs", \
                       learning_rate="constant", \
                       learning_rate_init=0.01, \
                       alpha=0.01, \
                       verbose=False, \
                       momentum=0.9, \
                       early_stopping=False, \
                       tol=0.00000001, \
                       shuffle=False, \
                       # n_iter_no_change=200, \
                       random_state=1234)

    mlp.fit(X_train_normalized, y_train_normalized)
    
    # ide kéne beilleszteni a modell elmentését
    joblib.dump(mlp, 'models/saved_mlp_model_train_test.pkl')

    return mlp

# %%
# Train Neural Network
mlp = trainMultiLayerRegressor(X_train_normalized, y_train_normalized, activation_function, neuronsTrainTest)

# %% [markdown]
# ### Create Prediction for Evaluation

# %%
def predictMultiLayerRegressor(mlp, X_normalized):
    y_predicted = mlp.predict(X_normalized)

    return y_predicted

# %%
# Create prediction
y_train_predicted = predictMultiLayerRegressor(mlp, X_train_normalized)

# Create prediction
y_test_predicted = predictMultiLayerRegressor(mlp, X_test_normalized)

# %% [markdown]
# ### Evaluate Goodness of Fit
#
# <a id="neural_network_evaluation_train_test"></a>

# %%
evaluateGoodnessOfPrediction(y_train_normalized, y_train_predicted)
print('---------------------')
evaluateGoodnessOfPrediction(y_test_normalized, y_test_predicted)
# Out:
# Correlation           = 0.652
# Explained variance    = 0.424
# Mean Absolute Error   = 0.086
# Mean Squared Error    = 0.020
# R2 Score              = 0.424
# ---------------------
# Correlation           = 0.396
# Explained variance    = -0.652
# Mean Absolute Error   = 0.121
# Mean Squared Error    = 0.072
# R2 Score              = -0.746

# %% [markdown]
# ### De-normalize data
#
# I want to see the result in original scale. I don't care about the X but the y_normalized and y_predcited.

# %%
y_train_denormalized = denormalizeY(y_train_normalized, y_normalized_MinMaxScalerTrainTest)

y_test_denormalized = denormalizeY(y_test_normalized, y_normalized_MinMaxScalerTrainTest)

y_train_predicted_denormalized = denormalizeY(y_train_predicted, y_normalized_MinMaxScalerTrainTest)

y_test_predicted_denormalized = denormalizeY(y_test_predicted, y_normalized_MinMaxScalerTrainTest)

# %%
y_train_denormalized[0:3]
# Out:
# array([[ 1498608.567],
#        [ 1499530.467],
#        [ 2170280.382]])

# %%
y_train_denormalized[-3:]
# Out:
# array([[ 2083708.691],
#        [   27936.473],
#        [ 3330059.227]])

# %%
y_test_denormalized[0:3]
# Out:
# array([[ 3322625.049],
#        [ 3240987.356],
#        [ 4750506.478]])

# %%
y_test_denormalized[-3:]
# Out:
# array([[ 4974982.36 ],
#        [ 4081220.691],
#        [ 4553424.952]])

# %%
y_train_predicted_denormalized[0:3]
# Out:
# array([[ 2601003.892],
#        [ 2883510.522],
#        [ 3269518.437]])

# %%
y_train_predicted_denormalized[-3:]
# Out:
# array([[ 3282024.754],
#        [ 3823449.789],
#        [  701679.609]])

# %%
y_test_predicted_denormalized[0:3]
# Out:
# array([[ -585238.608],
#        [ 4094980.592],
#        [ 3849264.761]])

# %%
y_test_predicted_denormalized[-3:]
# Out:
# array([[ 2464847.315],
#        [ 2701791.305],
#        [ 4357811.839]])

# %% [markdown]
# ### Visualize De-Normalized Data

# %%
from visualizer import ScatterPlotsTrainTest

# %%
ScatterPlotsTrainTest(y_train_denormalized, y_train_predicted_denormalized, \
                      y_test_denormalized, y_test_predicted_denormalized, targetVariable)

# %% [markdown]
# ### Visualize Normalized Data

# %%
ScatterPlotsTrainTest(y_train_normalized, y_train_predicted, \
                      y_test_normalized, y_test_predicted, targetVariable)

# %% [markdown]
# ### Show Predicted values on Test data

# %% [markdown]
# #### Train De-normalized

# %%
VisualizePredictedYLine(y_train_denormalized, y_train_predicted_denormalized, targetVariable, lines = True)

# %% [markdown]
# #### Train Normalized

# %%
VisualizePredictedYLine(y_train_normalized, y_train_predicted, targetVariable, lines = True)

# %% [markdown]
# ### Show Predcited values on Test data

# %% [markdown]
# #### Test De-normalized

# %%
VisualizePredictedYLine(y_test_denormalized, y_test_predicted_denormalized, targetVariable, lines = True)

# %% [markdown]
# #### Test Normalized

# %%
VisualizePredictedYLine(y_test_normalized, y_test_predicted, targetVariable, lines = True)

# %% [markdown]
# ## Inner state variable and Linear Regression Part
#
# In order to make prediction we need the measure the before state.
#
# - First I will create a new DataFrame called beforeafterDF. I will store lags and leads in this DataFrame. This will be used for learning the relation between metrics before scale and after scale. What I really need is the model and not the DataFrame itself.
#
#
# - This is why the original target variable is not necessery in this case. I wont use it at all.

# %% [markdown]
# ### Import Python dependencies

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ### Create Inner State Variables Lags
#
# Hmm.. Comment needed

# %%
def createBeforeafterDFLags(df, lag):
    beforeafterDFLags = df.copy()
    inputVariables = np.flip(beforeafterDFLags.columns[0:10].ravel(), axis=-1)
    print('Input Variablels : ', inputVariables)

    index = 10
    for i in inputVariables:
        new_column = beforeafterDFLags[i].shift(lag)
        new_column_name = (str('prev') + str(1) + i) # Todo: rename str(lag)
        beforeafterDFLags.insert(loc=index, column=new_column_name, value=new_column)

    beforeafterDFLags = beforeafterDFLags[lag:]             # remove first row as we haven't got data in lag var
    
    return beforeafterDFLags

# %%
beforeafterDFLags = createBeforeafterDFLags(preProcessedDF, 1)
# Out:
# Input Variablels :  ['WorkerCount' 'PktOut' 'KBOut' 'PktIn' 'KBIn' 'CTXSW' 'Inter' 'CPU'
#  'SUM RR' 'AVG RR']

# %%
beforeafterDFLags.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'prev1AVG RR', 'prev1SUM RR', 'prev1CPU',
#        'prev1Inter', 'prev1CTXSW', 'prev1KBIn', 'prev1PktIn', 'prev1KBOut',
#        'prev1PktOut', 'prev1WorkerCount', 'avg latency (quantile 0.5)'],
#       dtype='object')

# %% [markdown]
# ### Create Inner State Variables Leads

# %%
def createBeforeafterDFLeads(df, lead = 1):
    beforeafterDFLeads = df.copy()
    inputVariables = np.flip(beforeafterDFLeads.columns[0:10].ravel(), axis=-1)
    print('Input Variablels : ', inputVariables)

    index = 10
    for i in inputVariables:
        new_column = beforeafterDFLeads[i].shift(-lead)
        new_column_name = (str('next') + str(1) + i) # Todo: rename str(lead)
        beforeafterDFLeads.insert(loc=index, column=new_column_name, value=new_column)

    beforeafterDFLeads = beforeafterDFLeads[:-lead]             # remove last row as we haven't got data in lead var
    
    beforeafterDFLeads = beforeafterDFLeads.iloc[:,:-1]     # remove last column - Latency
    
    return beforeafterDFLeads

# %%
beforeafterDF = createBeforeafterDFLeads(beforeafterDFLags, lead = lead)
# Out:
# Input Variablels :  ['WorkerCount' 'PktOut' 'KBOut' 'PktIn' 'KBIn' 'CTXSW' 'Inter' 'CPU'
#  'SUM RR' 'AVG RR']

# %%
beforeafterDF.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'next1AVG RR', 'next1SUM RR', 'next1CPU',
#        'next1Inter', 'next1CTXSW', 'next1KBIn', 'next1PktIn', 'next1KBOut',
#        'next1PktOut', 'next1WorkerCount', 'prev1AVG RR', 'prev1SUM RR',
#        'prev1CPU', 'prev1Inter', 'prev1CTXSW', 'prev1KBIn', 'prev1PktIn',
#        'prev1KBOut', 'prev1PktOut', 'prev1WorkerCount'],
#       dtype='object')

# %% [markdown]
# ### Show Prev, Current, Next
#
# #### Assert

# %%
# assert

a_colName = beforeafterDF.columns[-1]
a_cols = beforeafterDF.shape[1]

assert a_colName == 'prev1WorkerCount', "This column name is: {0} insted of prev1WorkerCount".format(a_colName)
assert a_cols == 30, "This column number is: {0} insted of 17".format(a_colName)

# %% [markdown]
# ### Calculate difference of the number of Workers
#
# and add to the DataFrame as a new column

# %%
def calculateWorkerCountDifferences(beforeafterDF):
    new_beforeafterDF = beforeafterDF.copy()
    new_beforeafterDF['addedWorkerCount'] = new_beforeafterDF['next1WorkerCount'].values - new_beforeafterDF['WorkerCount']
    
    return new_beforeafterDF

# %%
theBeforeAfterDF = calculateWorkerCountDifferences(beforeafterDF)

# %% [markdown]
# ### Select that cases where WorkerCount and nextWorkerCount is not equall
#
# just in case store in a new DataFrame
#
# i am going to use the next (foreward like) data, that means i comper the current values with the next values

# %%
def createScalingDF(theBeforeAfterDF):
    new_beforeafterDF = theBeforeAfterDF.copy()
    scalingDF = new_beforeafterDF[new_beforeafterDF.WorkerCount != new_beforeafterDF.next1WorkerCount]
    
    return scalingDF

# %%
scalingDF = createScalingDF(theBeforeAfterDF)

# %% [markdown]
# ### Before I get further lets see some distribution of Inner State Variables - regards to the addedWorkerCount
#
# ### Create a temporary DataFrame where I am going to store the differecne between the inner state metrics before after values
#
# - Just to satisfy my curiosity
#
# *Negativ* values mean something *decreased* after scale, *positive* values mean something *increased* after scale

# %%
beforeafterMetricsDF = scalingDF.copy()

for i in metricNames:
    # print(i)
    changeInMetricAfterScale = beforeafterMetricsDF['next1'+i]-beforeafterMetricsDF[i]
    beforeafterMetricsDF['changed1'+i] = changeInMetricAfterScale

# %% [markdown]
# *Negativ* values mean something *decreased* after scale, *positive* values mean something *increased* after scale

# %%
beforeafterMetricsDF[['prev1CPU','CPU','next1CPU','changed1CPU','prev1WorkerCount','WorkerCount','next1WorkerCount']]. \
head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd22_c1c6_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
beforeafterMetricsDF[['prev1CPU','CPU','next1CPU','changed1CPU','prev1WorkerCount','WorkerCount','next1WorkerCount']]. \
head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd23_c1c6_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %%
beforeafterMetricsDF[['prev1CPU','CPU','next1CPU','changed1CPU','prev1WorkerCount','WorkerCount','next1WorkerCount']]. \
head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_f8d1bd24_c1c6_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### Means of Metrics after changed the number of workers

# %%
beforeafterMetricsDF[['changed1CPU', 'changed1Inter', 'changed1CTXSW', 'changed1KBIn', \
                      'changed1KBOut', 'changed1PktIn', 'changed1PktOut', 'addedWorkerCount']]. \
groupby(['addedWorkerCount'], as_index=False).mean().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4e_c1c6_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# Table show how changed the mean of a particular metric after changed the number of workers.
#
# For example:
# - if decreased the number of workers (-3) then the CPU usage increased ( 0.99)
# - if increased the number of workers ( 2) then the CPU usage decreased (-7.40)

# %%
beforeafterMetricsDF[['changed1CPU', 'changed1Inter', 'changed1CTXSW', 'changed1KBIn', \
                      'changed1KBOut', 'changed1PktIn', 'changed1PktOut', 'addedWorkerCount']]. \
groupby(['addedWorkerCount'], as_index=False).count().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_fa024b4f_c1c6_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### This is the end of Data Visualization and Exploration Part

# %% [markdown]
# ## Lets discover and learn the linear relationship between the before after metrics values
#
# ### Here comes the magic function
#
# `c0 = bias`<br>
# `c1 = weigth1`<br>
# `c2 = weight2`<br>
# `m  = current metric`<br>
# `w  = current number of workers`<br>
# `k  = proposed number of additional workers`<br>
#
# `m' = c0 + c1 · m · w/(w + k) + c2 · m · k/(w + k)`
#
# `var' = c0 + c1 * var * currentWorker/(currentWorker + addedWorker) + c2 * var * addedWorker/(currentWorker + addedWorker)`
#
# We want to learn the linear relation between the metric and the next - after scaled - metric.<br>
# There are several ways to do that, but now we wil use the 'Lead' insted of 'Lag'<br>
#
# ### Use the above formula to create model
#
# I use the `scalingDF` again.
#
# Remember: `beforeafterMetricsDF` was used only for exploaration
#
# While `beforeafterDF` contains all observation, `scalingDF` contans cases where scaling was made.

# %%
print(theBeforeAfterDF.shape)

print(scalingDF.shape)
# Out:
# (672, 31)
# (106, 31)

# %% [markdown]
# As far as I want to use a linear regression model I have to use the scalingDF DataFrame.
#
# Reminder:
#
# metricNames has been already deffined. I keept it here as a reminder.
#
# It should look like this:<br>
# `['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']`

# %%
metricNames
# Out:
# ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']

# %% [markdown]
# ### I wrote some functions for Linear Regression:
#
# - `calculateLinearRegressionTerms(list, dataFrame)` {Create two new column in tempDF DataFrame, which is a copy of the given df}
# - `createInputAndTargetToLinearRegression(list, dataFrame)` {Return with two numpy.array X, y}
# - `calculateLinearRegressionModel(list, dataFrame)` {Return sklearn.linear_model}
# - `calculateLinearRegressionPrediction(list, dataFrame, sklearn.linear_model)` {Return a numpy.array}
#
# ***

# %%
def calculateLinearRegressionTerms(metric, dataFrame):
    termDF = dataFrame.copy()
    termDF['metric'] = termDF[metric]
    termDF['term1']  = termDF[metric] * termDF['WorkerCount'] / (termDF['WorkerCount'] + termDF['addedWorkerCount'])
    termDF['term2']  = termDF[metric] * termDF['addedWorkerCount'] / (termDF['WorkerCount'] + termDF['addedWorkerCount'])
    return termDF


def createInputAndTargetToLinearRegression(currentMetric, dataFrameB):
    newDataFrameB = dataFrameB.copy()
    yb = newDataFrameB['next1' + str(currentMetric)]
    featuresDF = newDataFrameB[[str(currentMetric), 'WorkerCount', 'next1WorkerCount', 'addedWorkerCount']]
    
    tmpDF = calculateLinearRegressionTerms(currentMetric, featuresDF)
    
    Xb = tmpDF.iloc[:, [-3, -2, -1]]     # keep last three column - given metric, term1, term2
    
    # These are only for check everything is in order
    # print(y.head(1))
    # print(featuresDF.head(1))
    # print(X.head(2))
    # scalingDF[['CPU', 'next1CPU', 'WorkerCount', 'next1WorkerCount', 'addedWorkerCount']][0:3]
    return Xb, yb


def calculateLinearRegressionModel(currentMetric, dataFrameA):
    newDataFrameA = dataFrameA.copy()
    Xa, ya = createInputAndTargetToLinearRegression(currentMetric, newDataFrameA)
    
    # ToDo : Return and store particular model
    
    lr = LinearRegression(fit_intercept=True, normalize=False)
    lr.fit(Xa, ya)
    # prediction = lr.predict(X)
    
    return lr


def calculateLinearRegressionPrediction(metric, dataFrame, model):
    X, y = createInputAndTargetToLinearRegression(metric, dataFrame)
    
    model.fit(X, y)
    y_predicted = model.predict(X)
    
    # print('Score = ', model.score(X, y))
    # print(metric, 'MAE \t=\t{:0.2f}'.format(metrics.mean_absolute_error(y, y_predicted)))
    
    # todo: refactor
    print(metric)
    evaluateGoodnessOfPrediction(y, y_predicted)
    print('-----------------------------------')
    
    return y_predicted

# %% [markdown]
# ### Create a Copy of scalingDF
#
# I am going to store the predictions in this DataFrame as original variables as well.<br>
# But it is iportant to know this DataFrame doesn't really important at all.<br>

# %%
temporaryScalingDF = scalingDF.copy()

# %% [markdown]
# ### Learn the relation between WorkerCount, AddedWorker and Metrics with Linear Regression

# %%
d={}
for i in metricNames:
    d["model{0}".format(i)]="Hello " + i
    # print(d)
    
d.get('modelCPU')
# Out:
# 'Hello CPU'

# %%
def learningLinearRegression(scalingDF, temporaryScalingDF, metricNames):
    # linearRegressionModels = {}
    # temporaryScalingDF = scalingDF.copy()
    d={}
    
    for i in metricNames:

        # d["model{0}".format(i)]="Hello " + i
        
        model = calculateLinearRegressionModel(i, scalingDF)
        prediction = calculateLinearRegressionPrediction(i, scalingDF, model)
        
        # save model to the file system
        joblib.dump(model, 'models/saved_linearregression_model_' + i + '.pkl')

        # nos van egy ilyen modellünk mit tegyünk vele, tároljuk el mindegyiket különböző néven
        d["model{0}".format(i)] = model

        # el kéne tárolni
        temporaryScalingDF['predictedNext1'+i] = prediction

    
    return temporaryScalingDF, d

# %%
temporaryScalingDF, linearRegressionModels = learningLinearRegression(scalingDF, temporaryScalingDF, metricNames)
# Out:
# CPU
# Correlation           = 0.652
# Explained variance    = 0.425
# Mean Absolute Error   = 5.310
# Mean Squared Error    = 48.328
# R2 Score              = 0.425
# -----------------------------------
# Inter
# Correlation           = 0.647
# Explained variance    = 0.419
# Mean Absolute Error   = 395.734
# Mean Squared Error    = 299776.965
# R2 Score              = 0.419
# -----------------------------------
# CTXSW
# Correlation           = 0.547
# Explained variance    = 0.300
# Mean Absolute Error   = 385.045
# Mean Squared Error    = 297667.521
# R2 Score              = 0.300
# -----------------------------------
# KBIn
# Correlation           = 0.311
# Explained variance    = 0.097
# Mean Absolute Error   = 220.380
# Mean Squared Error    = 107965.121
# R2 Score              = 0.097
# -----------------------------------
# PktIn
# Correlation           = 0.650
# Explained variance    = 0.423
# Mean Absolute Error   = 203.032
# Mean Squared Error    = 80902.089
# ...

# %% [markdown]
# ### Stored Linear Regression Models in a dictionary
#
# I will use it to predict inner state variable in a different conditions. These models will be the basis of a later prediction. What is also important at this point I ended up the learning phase. Next is prediction phase.

# %%
linearRegressionModelNames = linearRegressionModels.keys()

print(linearRegressionModelNames)

modelCPU = linearRegressionModels.get('modelCPU')

print(type(modelCPU))
# Out:
# dict_keys(['modelCPU', 'modelInter', 'modelCTXSW', 'modelKBIn', 'modelPktIn', 'modelKBOut', 'modelPktOut'])
# <class 'sklearn.linear_model.base.LinearRegression'>

# %% [markdown]
# ### Stored temporaryScalingDF for exploration
#
# Remember:
# - I use this df to examine the data only

# %%
temporaryScalingDF.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'next1AVG RR', 'next1SUM RR', 'next1CPU',
#        'next1Inter', 'next1CTXSW', 'next1KBIn', 'next1PktIn', 'next1KBOut',
#        'next1PktOut', 'next1WorkerCount', 'prev1AVG RR', 'prev1SUM RR',
#        'prev1CPU', 'prev1Inter', 'prev1CTXSW', 'prev1KBIn', 'prev1PktIn',
#        'prev1KBOut', 'prev1PktOut', 'prev1WorkerCount', 'addedWorkerCount',
#        'predictedNext1CPU', 'predictedNext1Inter', 'predictedNext1CTXSW',
#        'predictedNext1KBIn', 'predictedNext1PktIn', 'predictedNext1KBOut',
#        'predictedNext1PktOut'],
#       dtype='object')

# %%
temporaryScalingDF.shape
# Out:
# (106, 38)

# %%
temporaryScalingDF.shape
# Out:
# (106, 38)

# %%
temporaryScalingDF.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_04cae23e_c1c7_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# ### Plots
#
# Visualize the relation between the real and the predicted metrics.<br>
#
# Remember:<br>
# **This shows the metrics, after scale (metric) and metrics predicted after scale (next1metrics).**<br>
#
# *Not to confuse with before after dichotomy*
#
#    *This is real vs predicted*
#
# These two variables should be on x and y axis respectively, while addedWorker can be represented by colour
# Don’t forget: There is also another variable (currentWorkerCont),
# but none of them can be affected to the one-to-one predicted-real data pairs.
# That is another issue.

# %%
from visualizer import ipythonPlotMetricsRealAgainstPredicted

# %%
metricNames = ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']

ipythonPlotMetricsRealAgainstPredicted(temporaryScalingDF, metricNames)

# %%
from visualizer import ipythonPlotMetricsRealAgainstPredictedRegression

# %%
ipythonPlotMetricsRealAgainstPredictedRegression(temporaryScalingDF, metricNames)

# %% [markdown]
# ### End of Learning Phase

# %% [markdown]
# <a id="test_begin"></a>
#
# # Advice Phase - Production Phase

# %% [markdown]
# ## Begining of Estimation Phase
#
# ### ToDo
#
# Till now, I have a pre-trained Neural Network and pre-trained Linear Regression models.
#
# - The next logical step is to create a new dataframe, where I will store the estimated inner state variables for every possible cases. For example, what would be the inner state variable if I add +1, +2, +3 new resources.<br><br>
#
# - Based on these new inner state values I will estimate the new Response Time.<br><br>
#
# - Stored the estimated response times in a dataframe I can calculate which solution leads back the response time into the pre-definied zone.<br><br>
#
# - I have a linearRegressionModels (a dictionary with scikit learn linear regression models)<br><br>
#
# - I have a stored scikt learn neural network model (in `model` library)<br><br>
#
# Combine these two with a hypothetical scaling I can estimate the expected Response Time
#
#
# ### Solution 1
#
# I create a funcition where arguments are a dataframe and number of newly added workers.<br>
# Then this function call a lot of predefined function which creates estimation.
#
# - Import utils.py library
# - Load saved models {scalerX, scalerY, neural net} {linreg models will be loaded later}
# - Read data
# - Pre-process
# - Add new workers (increse the nuber of added Worker)
# - Estimate the new inner state variables
# - Use neural net model to estimate the response time
#
# >#### -2. Import functions from utils
#
# <a id="test_import"></a>

# %%
from utils import loadMinMaxScalerXFull, loadMinMaxScalerYFull
from utils import loadNeuralNetworkModel
from utils import readCSV
from utils import preProcessing, renameVariable, setMetricNames, setExtendedMetricNames, dropFirstCases

from linearregression import calculateLinearRegressionTerms

from visualizer import VisualizePredictedYLine, VisualizePredictedYWithWorkers

from sklearn.externals import joblib

pandas_dataframe_styles = {
    'font-family': 'monospace',
    'white-space': 'pre'
}

# %% [markdown]
# >#### -1. Load sclaers, models

# %%
X_normalized_MinMaxScaler = loadMinMaxScalerXFull()
y_normalized_MinMaxScaler = loadMinMaxScalerYFull()

modelNeuralNet = loadNeuralNetworkModel()

# %% [markdown]
# >#### 0. Set variables

# %%
# Vigyázat ennek azonosnak kell lennie a korábbi értékkel különben para van (ezt valahogy ki kéne vezetni valami külső
# fájlba, vagy csinálni valamilyen osztályt amiben ez el van tárolva)

cutFirstCases = 0                                                      # 10
targetVariable = 'avg latency (quantile 0.5)'
testFileName = 'data/grafana_data_export_long_running_test.csv'        # original data
testFileName = 'data/test_data.csv'                                    # test data
testFileName = 'data/test_data2.csv'                                   # test data
# testFileName = 'data/micado0730715_v2.csv'

maximumNumberIncreasableNode = 6                                       # must be positive
minimumNumberReducibleNode = -4                                        # must be negativ

upperLimit = 4000000                                                   # 6000000
lowerLimit = 1000000                                                   # 1000000

# %% [markdown]
# >#### 1. Read data

# %%
newDF = readCSV(testFileName)

# %% [markdown]
# >#### 2. Pre-process data

# %%
newPreProcessedDF = preProcessing(newDF)

newRenamedDF = renameVariable(newPreProcessedDF, 'Worker count', 'WorkerCount')

metricNames         = setMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut'])
extendedMetricNames = setExtendedMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount'])

newFilteredDF = dropFirstCases(newRenamedDF, cutFirstCases)

# %% [markdown]
# ### Check out newFilteredDF
#
# While test data comes from a different sources the input variables names, orders, distribution can be different. In order to avoid any further problem I should look inside the new DataFrame.

# %%
newFilteredDF.describe().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_969562c4_b4df_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
# ...

# %% [markdown]
# >#### Add new workers (increse the nuber of added Worker)

# %%
metricNames
# Out:
# ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']

# %% [markdown]
# #### Method A.
# #### Complex cummulative inner state meric prediction
#
# <a id="method_A"></a>

# %%
def calculatePredictedLatencyWithVariousWorkers(modelNeuralNet, to):

    newDFForRegression = newFilteredDF.copy()
    nDD = newFilteredDF.copy()
    
    step = 0
    
    if( to == 0 ):
        print("")
        assert to != 0,"This value can not be 0. Error in calculatePredictedLatencyWithVariousWorkers method set maximum number of scalable nodes."
    elif( to > 0 ):
        step = 1
        print('............. up maximum vm = ' + str(to) + ' ...........')
    elif( to < 0 ):
        step = -1
        print('............. down maximum vm = ' + str(to) + ' ...........')

    for j in range(0, to, step):
        
        addedWorkerCount = j

        newDFForRegression['addedWorkerCount'] = addedWorkerCount

        for i in metricNames:

            newDFForRegressionWithTerms = calculateLinearRegressionTerms(i, newDFForRegression)

            print("------------     ", newDFForRegressionWithTerms.CPU.values[1], "     ------------")
            print("------------     ", newDFForRegressionWithTerms.shape, "     ------------")
            print("------------     ", newDFForRegressionWithTerms.columns, "     ------------")

            # keep last three column - given metric, term1, term2
            X = newDFForRegressionWithTerms.iloc[:, [-3, -2, -1]]
            
            print("------------     ", X.shape, "     ------------")
            print("------------     ", X.values[0], "     ------------") # Error ez az érték első eleme fix kéne hogy legyen
            print("------------     ", X.values[-1], "     ------------")# ugyanakkor folyamatosan változik
            
            # load the proper current metric model
            modelForMetric = joblib.load('models/saved_linearregression_model_' + i + '.pkl')

            print("------------     ", modelForMetric.get_params(), "     ------------")

            if( np.isinf(X).any()[1] ):
                X['term1'] = np.where(np.isinf(X['term1'].values), X['metric'], X['term1'])
                X['term2'] = np.where(np.isinf(X['term2'].values), 0, X['term2'])
                # print('-----------')
                # print(X.to_string())
                
            
            # create prediction and store in a new numpy.array object
            predictedMetric = modelForMetric.predict(X)
            
            
            # leave original metric value (just for fun and investigation) and store in a new column
            newDFForRegression['original' + i] = newDFForRegression[i]

            # store predicted value pretend as would be the original. for example predictedCPU will be CPU
            newDFForRegression[i] = predictedMetric
            nDD[i] = predictedMetric

            print("------------     ", newDFForRegression[['CPU']].values[1], "    ------------")
            print("------------     ", nDD[['CPU']].values[1], "    ------------")

            # print out the new data frame
            newDFForRegression.head()


        newDFForNerualNetworkPrediction = newDFForRegression.copy()     
        
        # X must contain exactly the same columns as the model does
        X = newDFForNerualNetworkPrediction.iloc[:, :9]
        
        # X must be normalized based on a previously created MinMaxScaler
        X_normalized_MinMaxScaler # the name of the MinMaxScaler

        X_normalized = X_normalized_MinMaxScaler.transform(X)

        # modelNeuralNet = joblib.load('models/saved_mlp_model.pkl')
        modelNeuralNet = modelNeuralNet

        # create and store predicted values in a numpy.array object
        y_predicted_with_new_metrics = modelNeuralNet.predict(X_normalized)

        # denormalized predicted values
        y_predicted_with_new_metrics_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_predicted_with_new_metrics.reshape(y_predicted_with_new_metrics.shape[0],1))

        newDFForNerualNetworkPrediction['predictedResponseTimeAdded' + str(j) + 'Worker'] = y_predicted_with_new_metrics
        newDFForNerualNetworkPrediction['denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'] = y_predicted_with_new_metrics_denormalized

        if(j == 0):
            investigationDF = newDFForNerualNetworkPrediction[[targetVariable, 'WorkerCount']]
            investigationDFDeNormalized = newDFForNerualNetworkPrediction[[targetVariable, 'WorkerCount']]
            #investigationDF = newDFForNerualNetworkPrediction[['predictedResponseTimeAdded0Worker']]
            #investigationDFDeNormalized = newDFForNerualNetworkPrediction[['denormalizedPredictedResponseTimeAdded0Worker']]

        investigationDF['predictedResponseTimeAdded' + str(j) + 'Worker'] = newDFForNerualNetworkPrediction[['predictedResponseTimeAdded' + str(j) + 'Worker']]
        investigationDFDeNormalized['denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'] = newDFForNerualNetworkPrediction[['denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker']]

    print(newDFForNerualNetworkPrediction.columns)
    
    print(investigationDFDeNormalized.columns)
    
    return investigationDF, investigationDFDeNormalized

# %%
investigationDFUp, investigationDFDeNormalizedUp = calculatePredictedLatencyWithVariousWorkers(modelNeuralNet, \
                                                                                               maximumNumberIncreasableNode)
# Out:
# ............. up maximum vm = 6 ...........
# ------------      90.205557037      ------------
# ------------      (659, 15)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 85.2  85.2   0. ]      ------------
# ------------      [ 84.689  84.689   0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 16)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
# ...

# %%
investigationDFDown, investigationDFDeNormalizedDown = calculatePredictedLatencyWithVariousWorkers(modelNeuralNet, \
                                                                                                   minimumNumberReducibleNode)
# Out:
# ............. down maximum vm = -4 ...........
# ------------      90.205557037      ------------
# ------------      (659, 15)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 85.2  85.2   0. ]      ------------
# ------------      [ 84.689  84.689   0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 16)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
# ...

# %% [markdown]
# ### Merge Up and Down Adviser

# %%
investigationDeNormalizedDF = pd.concat([investigationDFDeNormalizedDown, \
                             investigationDFDeNormalizedUp], axis = 1).T.drop_duplicates().T

investigationDeNormalizedDF.values.shape

# %%
investigationDeNormalizedDF.columns

# %% [markdown]
# ### Show Result

# %%
investigationDeNormalizedDF.head().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}")

# %%
investigationDFUp.head().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}")

# %%
investigationDFDown.head().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}")

# %%
investigationDFDeNormalizedUp.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")

# %%
investigationDFDeNormalizedDown.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")

# %%
VisualizePredictedYWithWorkers(0, investigationDFDown[['predictedResponseTimeAdded0Worker', \
                                                       'predictedResponseTimeAdded-1Worker', \
                                                       'predictedResponseTimeAdded-2Worker', \
                                                       'predictedResponseTimeAdded-3Worker']], targetVariable)

# %%
VisualizePredictedYWithWorkers(0, investigationDFUp[['predictedResponseTimeAdded1Worker', \
                                                     'predictedResponseTimeAdded2Worker', \
                                                     'predictedResponseTimeAdded3Worker']], targetVariable)

# %%
VisualizePredictedYWithWorkers(0, investigationDFUp[['predictedResponseTimeAdded0Worker', \
                                              'predictedResponseTimeAdded1Worker', \
                                              'predictedResponseTimeAdded2Worker', \
                                              'predictedResponseTimeAdded3Worker', \
                                              'predictedResponseTimeAdded4Worker', \
                                              'predictedResponseTimeAdded5Worker']], targetVariable)

# %%
VisualizePredictedYWithWorkers(0, investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded1Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded2Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded3Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded4Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded5Worker']], targetVariable)

# %%
VisualizePredictedYLine(investigationDFDeNormalizedUp['avg latency (quantile 0.5)'], \
                        investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker', \
                                                          'denormalizedPredictedResponseTimeAdded1Worker', \
                                                          'denormalizedPredictedResponseTimeAdded2Worker', \
                                                          'denormalizedPredictedResponseTimeAdded3Worker', \
                                                          'denormalizedPredictedResponseTimeAdded4Worker', \
                                                          'denormalizedPredictedResponseTimeAdded5Worker']], targetVariable)

# %%
VisualizePredictedYLine(investigationDFDeNormalizedUp[[targetVariable]], \
                        investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker']], targetVariable)

# %%
VisualizePredictedYLine(investigationDFDeNormalizedUp[[targetVariable]], \
                        investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker']], targetVariable)

# %% [markdown]
# ### Get Advice

# %%
from visualizer import VisualizePredictedXYLine
from visualizer import VisualizePredictedXY2Line

# %%
VisualizePredictedXYLine(0, investigationDFDeNormalizedUp[[targetVariable]], \
                         targetVariable, lowerLimit, upperLimit)

# %% [markdown]
# ### Brand New

# %%
advice = 0
countInRange = 0
countViolatedUp = 0
countViolatedDown = 0

advicedDF = investigationDeNormalizedDF.copy()
advicedDF['advice'] = 0
advicedDF['postScaledTargetVariable'] = np.nan

for i in investigationDeNormalizedDF.index:
    distance = 99999999999
    real = investigationDeNormalizedDF[[targetVariable]].get_value(i, targetVariable)
    if( upperLimit > real and lowerLimit < real ):
        advice = 0
        advicedDF.ix[i,'advice'] = 0
        countInRange += 1
        print("ok")
    else:
        print("threshold violation at index " + str(i))
        if( upperLimit < real ):
            countViolatedUp += 1
            print("threshold up violation")
            advice = 0
            postScaledTargetVariable = np.nan # 0
            distance = float('inf')
            for j in range(1, 6):
                print(distance)
                advice = 0
                # két feltételnek kell megfelelnie sorrendben legyen a legkisebb távolsága a felső limittől
                # kettő legyen a felső limit alatt (utóbbi nem biztos, hogy teljesül)
                varName = 'denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'
                relatedTargetVariable = investigationDeNormalizedDF.get_value(i, varName)
                calculatedDistance = investigationDeNormalizedDF.get_value(i, varName)
                if( calculatedDistance < upperLimit ):
                    distance = calculatedDistance
                    advice = j
                    postScaledTargetVariable = relatedTargetVariable
                    break
                print(calculatedDistance)
            advicedDF.ix[i,'advice'] = advice
            advicedDF.ix[i, 'postScaledTargetVariable'] = postScaledTargetVariable
        elif( lowerLimit > real ):
            countViolatedDown += 1
            print("threshold down violation")
            advice = 0
            postScaledTargetVariable = np.nan # 0
            distance = float('-inf')
            for j in range(-1, -3, -1):
                print(distance)
                advice = 0
                # két feltételnek kell megfelelnie sorrendben legyen a legkisebb távolsága az alsó limittől
                # kettő legyen az alsó limit fölött (utóbbi nem biztos, hogy teljesül)
                varName = 'denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'
                relatedTargetVariable = investigationDeNormalizedDF.get_value(i, varName)
                calculateDistance = investigationDeNormalizedDF.get_value(i, varName)
                if( calculateDistance > lowerLimit ):
                    distance = calculateDistance
                    advice = j
                    postScaledTargetVariable = relatedTargetVariable
                    if( calculateDistance < upperLimit ):
                        distance = calculateDistance
                        advice = j
                        postScaledTargetVariable = relatedTargetVariable
                        break
                    # break
                print(calculateDistance)
            advicedDF.ix[i, 'advice'] = advice
            advicedDF.ix[i, 'postScaledTargetVariable'] = postScaledTargetVariable

# %%
advicedDF.head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.0f}")

# %%
VisualizePredictedXYLine(advicedDF[['advice']] * 2000000, advicedDF[[targetVariable]], \
                         targetVariable, lowerLimit, upperLimit)

# %%
print('countInRange      = ', countInRange)
print('countViolatedDown = ', countViolatedDown)
print('countVilolatedUp  = ', countViolatedUp)

# %%
VisualizePredictedXY2Line(advicedDF[[targetVariable]], advicedDF[['advice']], \
                         targetVariable, lowerLimit, upperLimit)

# %%
from visualizer import VisualizePredictedXY3Line

# %%
VisualizePredictedXY3Line(advicedDF[[targetVariable]], \
                          advicedDF[['postScaledTargetVariable']], \
                          advicedDF[['advice']], \
                          targetVariable, lowerLimit, upperLimit)

# %%
# valami nem stimmel szerintem a fenti ábrán a sárga vonal és a második y tengely lehet, hogy nincs összhangban,
#
# összhangban van minden, ezek a furcsa elnyúlások a sárga vonalban azért jelennek meg, mert
# plot minden időpvfffffontot megjelenít, miközben a valósgban óriási hézagok vannak az adatsorban
# a 49 minta után a 73-ik minta jön
#
# ilyen értelemben a plot hibás és egy kicsit félrevezető
#
# persze a megoldás az lenne, ha nem lennének az adatokban ilyen és ekkora hézagok

# %%
advicedDF.style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")

# %% [markdown]
# ### Save Output

# %%
advicedDF.to_csv('outputs/adviceDF.csv', sep=';', encoding='utf-8')

# %% [markdown]
# ### End of Test
#
#
# - [Linreg Method A](#method_A)
# - [Test import](#test_import)
# - [Test begin](#test_begin)
#
# - [Train import](#train_import)
#
# - [Neural network evaluation](#neural_network_evaluation)
#
# - [Neural network evaluation train test](#neural_network_evaluation_train_test)
#
# - [Compare train test set](#compare_train_test_set)
