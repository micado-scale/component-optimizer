# %%
# import optimizer as op

import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.externals import joblib

# import plotly
# import plotly.plotly as py
# import plotly.graph_objs as go
# import plotly.figure_factory as ff

np.set_printoptions(precision=3, suppress=True)

pandas_dataframe_styles = {
    'font-family': 'monospace',
    'white-space': 'pre'
}

# %%
inputCSVFile   = 'data/grafana_data_export_long_running_test.csv'

targetVariable = 'avg latency (quantile 0.5)'


scaler_min = -1                     # 0
scaler_max = 1                      # 1
train_test_ratio = 0.3              # 0.3
activation_function = 'tanh'        # tanh, relu, logistic
neuronsWhole = 10                   # 10
neuronsTrainTest = 4                # 4
cutFirstCases = 10                  # 10

lead = 1                            # 1 default

showPlots = True                    # True

# %%
def readCSV(filename):
    df = pd.read_csv(filename, sep=";", header="infer", skiprows=0, na_values="null" )

    # Return DataFrame
    return df

# %%
# Read DataFrame
df = readCSV(inputCSVFile)

# %%
def removeMissingData(df):
    cleanDF = df.dropna(axis=0)
    return cleanDF


def dropVariable(df, column):
    del df[column]
    return df


def preProcessing(df):
    df = df.copy()
    
    # Drop Time
    df = dropVariable(df, 'Time')
    df = dropVariable(df, 'avg latency (quantile 0.9)')

    # Debug
    # printDF(df)

    # Remove cases with missing values
    df = removeMissingData(df)
    return df

# %%
# Preprecess DataFrame
preProcessedDF = preProcessing(df)

# %%
targetVariable = targetVariable

# %%
def renameVariable(df, old_var_name, new_var_name):
    new_df = df.copy()
    new_df.rename(columns={old_var_name: new_var_name}, inplace=True)
    return new_df

# %%
preProcessedDF = renameVariable(preProcessedDF, 'Worker count', 'WorkerCount')

# %%
def setMetricNames(names):
    new_metricNames = names.copy()
    return new_metricNames

# %%
metricNames = setMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut'])

# %%
def setExtendedMetricNames(names):
    new_extendedMetricNames = names.copy()
    return new_extendedMetricNames

# %%
extendedMetricNames = setExtendedMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount'])

extendedMetricNames
# Out:
# ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount']

# %%
def dropFirstCases(df, n):
    new_df = df.copy()
    filteredDF = new_df[new_df.index > n]
    return filteredDF

# %%
# because in the begining of the samples have a lot of outliers

filteredDF = dropFirstCases(preProcessedDF, cutFirstCases)

# %%
preProcessedDF = filteredDF

# %% [markdown]
# ### Correlation Matrix

# %%
from visualizerlinux import CorrelationMatrixSave

# %%
CorrelationMatrixSave(preProcessedDF)
# Out:
# Loading page (1/2)
# Rendering (2/2)
# Done

# %%
from visualizerlinux import ScatterPlots

# %%
if showPlots : ScatterPlots(preProcessedDF, preProcessedDF[targetVariable], extendedMetricNames, targetVariable)

# %%
from visualizerlinux import TimeLinePlot

# %%
if showPlots : TimeLinePlot(preProcessedDF, targetVariable)

# %%
from visualizerlinux import TimeLinePlots

# %%
if showPlots : TimeLinePlots(preProcessedDF, extendedMetricNames)

# %%
n = 1
for i in preProcessedDF.columns:
    print('AC(1)      ', i, '\t= ', np.round(preProcessedDF[i].autocorr(lag=1), 2))
    n = n+1
    if( n == 10 ):
        break
# Out:
# AC(1)       AVG RR 	=  0.71
# AC(1)       SUM RR 	=  0.82
# AC(1)       CPU 	=  0.77
# AC(1)       Inter 	=  0.76
# AC(1)       CTXSW 	=  0.75
# AC(1)       KBIn 	=  0.4
# AC(1)       PktIn 	=  0.8
# AC(1)       KBOut 	=  0.76
# AC(1)       PktOut 	=  0.78

# %% [markdown]
# ## Create a whole new DataFrame for Before After Data

# %%
def createBeforeafterDF(df, lag):
    beforeafterDF = df.copy()
    inputVariables = np.flip(beforeafterDF.columns[0:9].ravel(), axis=-1)
    print('Input Variablels : ', inputVariables)

    index = 9
    for i in inputVariables:
        new_column = beforeafterDF[i].shift(lag)
        new_column_name = (i + str(1)) # Todo: rename str(lag)
        beforeafterDF.insert(loc=index, column=new_column_name, value=new_column)
    
    beforeafterDF = beforeafterDF[lag:]
    
    print('Before After DF columns: ', beforeafterDF.columns)
    
    return beforeafterDF

# %%
beforeafterDF = createBeforeafterDF(preProcessedDF, 1)
# Out:
# Input Variablels :  ['PktOut' 'KBOut' 'PktIn' 'KBIn' 'CTXSW' 'Inter' 'CPU' 'SUM RR' 'AVG RR']
# Before After DF columns:  Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'AVG RR1', 'SUM RR1', 'CPU1', 'Inter1', 'CTXSW1', 'KBIn1',
#        'PktIn1', 'KBOut1', 'PktOut1', 'WorkerCount',
#        'avg latency (quantile 0.5)'],
#       dtype='object')

# %% [markdown]
# ### Set Features for Neural Network - these are the input variables

# %%
def setFeaturesAndTheirLags(df):
    X = df.iloc[:,0:9]
    return X

# %%
X = setFeaturesAndTheirLags(beforeafterDF)

# %% [markdown]
# ### Set Target Variable for Neural Network - this is the target variable

# %%
def setTarget(df, targetVariable):
    y = df[targetVariable]
    return y

# %%
y = setTarget(beforeafterDF, targetVariable)

# %%
y.values[0:10]
# Out:
# array([ 1498608.567,  1499530.468,  2170280.382,  1602826.789,
#         1679743.324,    24193.916,    32378.571,    50828.776,
#         2760269.008,  2760269.008])

# %%
y.head()
# Out:
# 13    1.498609e+06
# 14    1.499530e+06
# 15    2.170280e+06
# 16    1.602827e+06
# 17    1.679743e+06
# Name: avg latency (quantile 0.5), dtype: float64

# %%
y.describe()
# Out:
# count    6.730000e+02
# mean     3.619691e+06
# std      3.217239e+06
# min      2.419392e+04
# 25%      2.479101e+06
# 50%      3.207532e+06
# 75%      4.119402e+06
# max      4.203820e+07
# Name: avg latency (quantile 0.5), dtype: float64

# %% [markdown]
# ### Normalize the whole X

# %%
def normalizeX(df):
    """Return a normalized value of df.
    Save MinMaxScaler normalizer for X variable"""
    
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    # scaler.fit(df)
    scaler.fit(df.astype(np.float64))
    # normalized = scaler.transform(df)
    normalized = scaler.transform(df.astype(np.float64))
    
    # store MinMaxScaler for X
    joblib.dump(scaler, 'models/scaler_normalizeX.save') 

    return normalized, scaler

# %%
X_normalized, X_normalized_MinMaxScaler = normalizeX(X)

# %% [markdown]
# ### Load MinMaxScalerXFull

# %%
def loadMinMaxScalerXFull():
    X_normalized_MinMaxScaler = joblib.load('models/scaler_normalizeX.save')
    
    return X_normalized_MinMaxScaler

# %%
X_normalized_MinMaxScaler = loadMinMaxScalerXFull()

# %%
def printNormalizedX(X_normalized):
    print("X_normalized type        = ", type(X_normalized))
    print("X_normalizde dtype       = ", X_normalized.dtype)
    print("X_normalized shape       = ", X_normalized.shape)
    print("X_normalized ndim        = ", X_normalized.ndim)
    print("X_normalized[:,0].max()  = ", X_normalized[:,0].max())
    print("X_normalized[:,0].min()  = ", X_normalized[:,0].min())

# %%
printNormalizedX(X_normalized)
# Out:
# X_normalized type        =  <class 'numpy.ndarray'>
# X_normalizde dtype       =  float64
# X_normalized shape       =  (673, 9)
# X_normalized ndim        =  2
# X_normalized[:,0].max()  =  1.0
# X_normalized[:,0].min()  =  -1.0

# %%
X_normalized[1]
# Out:
# array([-0.495, -0.586,  0.437, -0.143,  0.272, -0.627, -0.37 , -0.222,
#        -0.229])

# %%
X_denormalized = X_normalized_MinMaxScaler.inverse_transform(X_normalized)

# %%
X_denormalized[1]
# Out:
# array([    43.837,     87.674,     87.675,   6773.008,  10261.946,
#          1086.267,   1985.507,    205.35 ,   1670.186])

# %%
X_denormalized[-1]
# Out:
# array([   56.849,   113.698,    84.537,  6142.203,  9008.754,   981.49 ,
#         1888.163,   201.356,  1698.07 ])

# %% [markdown]
# ### Normalize the whole y

# %%
def normalizeY(df):
    """Return a normalized value of df.
    Save MinMaxScaler normalizer for Y variable"""
    
    new_df = df.copy()
    new_df_reshaped = new_df.values.reshape(-1,1)
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    scaler.fit(new_df_reshaped.astype(np.float64))
    normalizedY = scaler.transform(new_df_reshaped.astype(np.float64))
    normalizedY = normalizedY.flatten()
    
    # store MinMaxScaler for Y
    joblib.dump(scaler, 'models/scaler_normalizeY.save') 

    return normalizedY, scaler

# %%
y_normalized, y_normalized_MinMaxScaler = normalizeY(y)

# %%
def printNormalizedY(y_normalized):
    """Void. Print normalizeY(df) values"""
    
    print("y_normalized type        = ", type(y_normalized))
    print("y_normalized dtype       = ", y_normalized.dtype)
    print("y_normalized shape       = ", y_normalized.shape)
    print("y_normalized ndim        = ", y_normalized.ndim)
    print("y_normalized[:].max()    = ", y_normalized[:].max())
    print("y_normalized[:].min()    = ", y_normalized[:].min())

# %%
printNormalizedY(y_normalized)
# Out:
# y_normalized type        =  <class 'numpy.ndarray'>
# y_normalized dtype       =  float64
# y_normalized shape       =  (673,)
# y_normalized ndim        =  1
# y_normalized[:].max()    =  1.0
# y_normalized[:].min()    =  -1.0

# %%
y_normalized[0:3]
# Out:
# array([-0.93 , -0.93 , -0.898])

# %% [markdown]
# ### Load MinMaxScalerYFull

# %%
def loadMinMaxScalerYFull():
    y_normalized_MinMaxScaler = joblib.load('models/scaler_normalizeY.save')
    
    return y_normalized_MinMaxScaler

# %%
y_normalized_MinMaxScaler = loadMinMaxScalerYFull()

# %%
y_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_normalized.reshape(y_normalized.shape[0],1))

# %%
y_denormalized[0:3]
# Out:
# array([[ 1498608.567],
#        [ 1499530.468],
#        [ 2170280.382]])

# %%
y_denormalized[-3:]
# Out:
# array([[ 4974982.36 ],
#        [ 4081220.691],
#        [ 4553424.952]])

# %% [markdown]
# ## Train Neural Network with Optimizer Class, trainMultiLayerRegressor method

# %%
def trainMultiLayerRegressor(X_normalized, y_normalized, activation, neuronsWhole):

    # Train Neural Network
    mlp = MLPRegressor(hidden_layer_sizes=neuronsWhole, \
                       max_iter=250, \
                       activation=activation, \
                       solver="lbfgs", \
                       learning_rate="constant", \
                       learning_rate_init=0.01, \
                       alpha=0.01, \
                       verbose=False, \
                       momentum=0.9, \
                       early_stopping=False, \
                       tol=0.00000001, \
                       shuffle=False, \
                       # n_iter_no_change=20, \
                       random_state=1234)

    mlp.fit(X_normalized, y_normalized)
    
    # ide kéne beilleszteni a modell elmentését
    joblib.dump(mlp, 'models/saved_mlp_model.pkl')

    return mlp

# %%
# Train Neural Network
mlp = trainMultiLayerRegressor(X_normalized, y_normalized, activation_function, neuronsWhole)

# %%
def predictMultiLayerRegressor(mlp, X_normalized):
    y_predicted = mlp.predict(X_normalized)

    return y_predicted

# %%
# Create prediction
y_predicted = predictMultiLayerRegressor(mlp, X_normalized)

# %%
from utils import evaluateGoodnessOfPrediction

# %%
evaluateGoodnessOfPrediction(y_normalized, y_predicted)
# Out:
# Correlation           = 0.605
# Explained variance    = 0.366
# Mean Absolute Error   = 0.067
# Mean Squared Error    = 0.015
# R2 Score              = 0.366

# %% [markdown]
# ### Visualize Data

# %%
from visualizerlinux import VisualizePredictedYScatter

# %%
VisualizePredictedYScatter(y_normalized, y_predicted, targetVariable)

# %%
from visualizerlinux import VisualizePredictedYLine, VisualizePredictedYLineWithValues

# %%
VisualizePredictedYLineWithValues(y_normalized, y_predicted, targetVariable, 'Normalized')

# %% [markdown]
# ### De-normlaize
#
# I want to see the result in original scale. I don't care about the X but the y_normalized and y_predcited.

# %%
y_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_normalized.reshape(y_normalized.shape[0],1))

y_predicted_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_predicted.reshape(y_predicted.shape[0],1))

# %% [markdown]
# ### Can I visualize the de-normalized data as well?

# %%
VisualizePredictedYLineWithValues(y_denormalized, y_predicted_denormalized, targetVariable, 'Denormalized')

# %% [markdown]
# ### Compare the Original Target Variable and the mean of its Predicted Values

# %%
meanOfOriginalPandasDataframe = y.values.mean()
meanOfOriginalTargetVariable  = y_denormalized.mean()
meanOfPredictedTargetVariable = y_predicted_denormalized.mean()

print('mean original pandas dataframe = ', meanOfOriginalPandasDataframe)
print('mean original target variable  = ', meanOfOriginalTargetVariable)
print('mean predicted target variable = ', meanOfPredictedTargetVariable)
# Out:
# mean original pandas dataframe =  3619691.41872
# mean original target variable  =  3619691.41872
# mean predicted target variable =  3627819.30705

# %% [markdown]
# ### De-normalizer function

# %%
def denormalizeX(X_normalized, X_normalized_MinMaxScaler):
    X_denormalized = X_normalized_MinMaxScaler.inverse_transform(X_normalized)
    return X_denormalized

# %%
X_denormalized = denormalizeX(X_normalized, X_normalized_MinMaxScaler)

# %%
X_denormalized[1]
# Out:
# array([    43.837,     87.674,     87.675,   6773.008,  10261.946,
#          1086.267,   1985.507,    205.35 ,   1670.186])

# %%
X_normalized[1]
# Out:
# array([-0.495, -0.586,  0.437, -0.143,  0.272, -0.627, -0.37 , -0.222,
#        -0.229])

# %%
X_denormalized[-1]
# Out:
# array([   56.849,   113.698,    84.537,  6142.203,  9008.754,   981.49 ,
#         1888.163,   201.356,  1698.07 ])

# %%
X_normalized[-1]
# Out:
# array([ 0.074, -0.383,  0.294, -0.471, -0.318, -0.733, -0.462, -0.263,
#        -0.197])

# %%
def denormalizeY(y_normalized, y_normalized_MinMaxScaler):
    y_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_normalized.reshape(y_normalized.shape[0],1))
    return y_denormalized

# %%
y_denormalized = denormalizeY(y_normalized, y_normalized_MinMaxScaler)

y_predicted_denormalized = denormalizeY(y_predicted, y_normalized_MinMaxScaler)

# %%
VisualizePredictedYLineWithValues(y_denormalized, y_predicted_denormalized, targetVariable, 'Denormalized')

# %% [markdown]
# ## Create Train-Test-Validation set
#
# ### Split Data

# %%
def splitDataFrame(X, y, testSize):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testSize, \
                                                        random_state=12345, \
                                                        shuffle=False, \
                                                        stratify=None)

    return X_train, X_test, y_train, y_test

# %%
# Split DataFrame
X_train, X_test, y_train, y_test = splitDataFrame(X, y, train_test_ratio)

# %%
print(X_train.count())
# Out:
# AVG RR    471
# SUM RR    471
# CPU       471
# Inter     471
# CTXSW     471
# KBIn      471
# PktIn     471
# KBOut     471
# PktOut    471
# dtype: int64

# %%
print(X_test.count())
# Out:
# AVG RR    202
# SUM RR    202
# CPU       202
# Inter     202
# CTXSW     202
# KBIn      202
# PktIn     202
# KBOut     202
# PktOut    202
# dtype: int64

# %%
print("y_train.count() = ", y_train.count())
print("y_test.count()  = ", y_test.count())
# Out:
# y_train.count() =  471
# y_test.count()  =  202

# %%
from utils import compareTwoVariables

# %%
compareTwoVariables(X_train, X_test, 'CPU')
# Out:
# <style  type="text/css" >
#     #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row5_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row5_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row5_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >CPU</th>
#         <th class="col_heading level0 col1" >CPUT</th>
#         <th class="col_heading level0 col2" >Difference in percent</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >count</th>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >471.00</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >202.00</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >57.11</td>
#     </tr>    <tr>
#         <th id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >mean</th>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >95.16</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >90.99</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >4.39</td>
#     </tr>    <tr>
#         <th id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >std</th>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row2_col0" class="data row2 col0" >7.33</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row2_col1" class="data row2 col1" >7.46</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row2_col2" class="data row2 col2" >-1.75</td>
#     </tr>    <tr>
#         <th id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9level0_row3" class="row_heading level0 row3" >min</th>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row3_col0" class="data row3 col0" >56.22</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row3_col1" class="data row3 col1" >75.43</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row3_col2" class="data row3 col2" >-34.18</td>
#     </tr>    <tr>
#         <th id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9level0_row4" class="row_heading level0 row4" >50%</th>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row4_col0" class="data row4 col0" >98.93</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row4_col1" class="data row4 col1" >85.55</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row4_col2" class="data row4 col2" >13.52</td>
#     </tr>    <tr>
#         <th id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9level0_row5" class="row_heading level0 row5" >max</th>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row5_col0" class="data row5 col0" >100.00</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row5_col1" class="data row5 col1" >100.00</td>
#         <td id="T_c5970870_aeb3_11e9_b6b8_fa163ebcacb9row5_col2" class="data row5 col2" >0.00</td>
#     </tr></tbody>
# </table>

# %%
compareTwoVariables(X_train, X_test, 'CTXSW')
# Out:
# <style  type="text/css" >
#     #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row5_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row5_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row5_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >CTXSW</th>
#         <th class="col_heading level0 col1" >CTXSWT</th>
#         <th class="col_heading level0 col2" >Difference in percent</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >count</th>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >471.00</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >202.00</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >57.11</td>
#     </tr>    <tr>
#         <th id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >mean</th>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >10126.84</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >9508.34</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >6.11</td>
#     </tr>    <tr>
#         <th id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >std</th>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row2_col0" class="data row2 col0" >494.67</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row2_col1" class="data row2 col1" >680.00</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row2_col2" class="data row2 col2" >-37.47</td>
#     </tr>    <tr>
#         <th id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9level0_row3" class="row_heading level0 row3" >min</th>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row3_col0" class="data row3 col0" >7558.23</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row3_col1" class="data row3 col1" >8088.82</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row3_col2" class="data row3 col2" >-7.02</td>
#     </tr>    <tr>
#         <th id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9level0_row4" class="row_heading level0 row4" >50%</th>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row4_col0" class="data row4 col0" >10214.30</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row4_col1" class="data row4 col1" >9311.80</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row4_col2" class="data row4 col2" >8.84</td>
#     </tr>    <tr>
#         <th id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9level0_row5" class="row_heading level0 row5" >max</th>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row5_col0" class="data row5 col0" >11810.59</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row5_col1" class="data row5 col1" >11551.91</td>
#         <td id="T_c5970871_aeb3_11e9_b6b8_fa163ebcacb9row5_col2" class="data row5 col2" >2.19</td>
#     </tr></tbody>
# </table>

# %%
compareTwoVariables(X_train, X_test, 'AVG RR')
# Out:
# <style  type="text/css" >
#     #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row5_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row5_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row5_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >AVG RR</th>
#         <th class="col_heading level0 col1" >AVG RRT</th>
#         <th class="col_heading level0 col2" >Difference in percent</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >count</th>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >471.00</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >202.00</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >57.11</td>
#     </tr>    <tr>
#         <th id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >mean</th>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >51.78</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >52.19</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >-0.80</td>
#     </tr>    <tr>
#         <th id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >std</th>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row2_col0" class="data row2 col0" >8.85</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row2_col1" class="data row2 col1" >6.34</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row2_col2" class="data row2 col2" >28.42</td>
#     </tr>    <tr>
#         <th id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9level0_row3" class="row_heading level0 row3" >min</th>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row3_col0" class="data row3 col0" >32.28</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row3_col1" class="data row3 col1" >34.73</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row3_col2" class="data row3 col2" >-7.60</td>
#     </tr>    <tr>
#         <th id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9level0_row4" class="row_heading level0 row4" >50%</th>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row4_col0" class="data row4 col0" >50.54</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row4_col1" class="data row4 col1" >50.51</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row4_col2" class="data row4 col2" >0.05</td>
#     </tr>    <tr>
#         <th id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9level0_row5" class="row_heading level0 row5" >max</th>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row5_col0" class="data row5 col0" >78.05</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row5_col1" class="data row5 col1" >76.33</td>
#         <td id="T_c5970872_aeb3_11e9_b6b8_fa163ebcacb9row5_col2" class="data row5 col2" >2.20</td>
#     </tr></tbody>
# </table>

# %%
VisualizePredictedYLineWithValues(y.values, y_train.values, targetVariable, 'Denormalized')

# %%
VisualizePredictedYLineWithValues(y, y_train, targetVariable, 'Denormalized')

# %%
VisualizePredictedYLineWithValues(0, y_test, targetVariable, 'Denormalized')

# %%
VisualizePredictedYLineWithValues(0, y_test.values, targetVariable, 'Denormalized')

# %%
VisualizePredictedYLineWithValues(y_train, y_train.values, targetVariable, 'Denormalized')

# %% [markdown]
# ### Train Test set comparison

# %%
from utils import printInfoTrainTestSet

# %%
printInfoTrainTestSet(y_train, y_test)
# Out:
# y_train.min()             =  24193.916
# y_test.min()              =  229587.881
# ------------------------------------------
# type(y_train)             =  <class 'pandas.core.series.Series'>
# type(y_test)              =  <class 'pandas.core.series.Series'>
# ------------------------------------------
# type(y_train.values)      =  <class 'numpy.ndarray'>
# type(y_test.values)       =  <class 'numpy.ndarray'>
# ------------------------------------------
# y_train.values.min()      =  24193.916
# y_test.values.min()       =  229587.881
# ------------------------------------------
# y_train.values.max()      =  32912000.374
# y_test.values.max()       =  42038198.617
# ------------------------------------------
# y_train.values.argmin()   =  5
# y_test.values.argmin()    =  19
# ------------------------------------------
# y_train.values.argmax()   =  240
# y_test.values.argmax()    =  28
# ------------------------------------------
# y_train.idxmin()          =  18
# y_test.idxmin()           =  588
# ------------------------------------------
# y_train.size              =  471
# y_test.size               =  202
# ------------------------------------------
# y_train.first_valid_index()   =  13
# y_test.first_valid_index()    =  566
# ------------------------------------------
# y_train.last_valid_index()    =  564
# y_test.last_valid_index()     =  781
# ------------------------------------------
#  18     24193.916
# 210    24537.236
# Name: avg latency (quantile 0.5), dtype: float64
#  588    229587.881
# 589    229587.881
# Name: avg latency (quantile 0.5), dtype: float64
# ------------------------------------------
# y_train.name            =  avg latency (quantile 0.5)
# y_test.name             =  avg latency (quantile 0.5)
# ------------------------------------------
#  Int64Index([ 13,  14,  15,  16,  17,  18,  19,  20,  22,  23,
#             ...
#             553, 554, 556, 557, 558, 559, 560, 561, 562, 564],
#            dtype='int64', length=471)
#  Int64Index([566, 567, 568, 569, 570, 572, 573, 574, 575, 576,
#             ...
#             772, 773, 774, 775, 776, 777, 778, 779, 780, 781],
#            dtype='int64', length=202)
# ------------------------------------------

# %%
y_train.values[0:10]
# Out:
# array([ 1498608.567,  1499530.468,  2170280.382,  1602826.789,
#         1679743.324,    24193.916,    32378.571,    50828.776,
#         2760269.008,  2760269.008])

# %%
y_test.values[10:20]
# Out:
# array([ 5594757.536,  5547258.272,  3778227.519,  2343328.501,
#         3842487.763,  5217770.458,  4943885.104,  2584097.733,
#         2083820.325,   229587.881])

# %% [markdown]
# ### Normalize Data - based on Train set - It is forbiden to use Test set

# %%
def normalizeXTrainTest(X_train, X_test):
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    scaler.fit(X_train)
    X_train_normalized = scaler.transform(X_train)
    X_test_normalized = scaler.transform(X_test)

    return X_train_normalized, X_test_normalized, scaler

# %%
X_train_normalized, X_test_normalized, X_normalized_MinMaxScalerTrainTest = normalizeXTrainTest(X_train, X_test)

# %%
print("X_train_normalized max = ", X_train_normalized.max())
print("X_train_normalized min = ", X_train_normalized.min())
print("X_test_normalized max  = ", X_test_normalized.max())
print("X_test_normalized min  = ", X_test_normalized.min())
# Out:
# X_train_normalized max =  1.0
# X_train_normalized min =  -1.0
# X_test_normalized max  =  1.0
# X_test_normalized min  =  -1.02083227423

# %%
def normalizeYTrainTest(y_train, y_test):
    # Create numpy.array from pandas.series then reshape numpy array
    y_train_input = y_train.values.reshape(-1, 1)
    y_test_input = y_test.values.reshape(-1, 1)
    # Scaler
    scaler = MinMaxScaler(feature_range=(scaler_min, scaler_max))
    scaler.fit(y_train_input)
    # Scale
    y_train_normalized_tmp = scaler.transform(y_train_input)
    y_test_normalized_tmp = scaler.transform(y_test_input)
    # Flat numpy.array
    y_train_normalized = y_train_normalized_tmp.flatten()
    y_test_normalized = y_test_normalized_tmp.flatten()

    return y_train_normalized, y_test_normalized, scaler

# %%
y_train_normalized, y_test_normalized, y_normalized_MinMaxScalerTrainTest = normalizeYTrainTest(y_train, y_test)

# %%
print("y_train_normalized max = ", y_train_normalized.max())
print("y_train_normalized min = ", y_train_normalized.min())
print("y_test_normalized max  = ", y_test_normalized.max())
print("y_test_normalized min  = ", y_test_normalized.min())
# Out:
# y_train_normalized max =  1.0
# y_train_normalized min =  -1.0
# y_test_normalized max  =  1.55498978046
# y_test_normalized min  =  -0.987509415366

# %%
from utils import printInfoNumpyArrays

# %%
printInfoNumpyArrays(y_train_normalized, y_test_normalized)
# Out:
# type(y_train)             =  <class 'numpy.ndarray'>
# type(y_test)              =  <class 'numpy.ndarray'>
# ------------------------------------------
# len(y_train)              =  471
# len(y_test)               =  202
# ------------------------------------------
# y_train.size              =  471
# y_test.size               =  202
# ------------------------------------------
# y_train.shape             =  (471,)
# y_test.shape              =  (202,)
# ------------------------------------------
# y_train.min               =  -1.0
# y_test.min                =  -0.987509415366
# ------------------------------------------
# y_train.max               =  1.0
# y_test.max                =  1.55498978046

# %%
printInfoNumpyArrays(y_train, y_test)
# Out:
# type(y_train)             =  <class 'pandas.core.series.Series'>
# type(y_test)              =  <class 'pandas.core.series.Series'>
# ------------------------------------------
# len(y_train)              =  471
# len(y_test)               =  202
# ------------------------------------------
# y_train.size              =  471
# y_test.size               =  202
# ------------------------------------------
# y_train.shape             =  (471,)
# y_test.shape              =  (202,)
# ------------------------------------------
# y_train.min               =  24193.916
# y_test.min                =  229587.881
# ------------------------------------------
# y_train.max               =  32912000.374
# y_test.max                =  42038198.617

# %%
for i in range(0,9):
    print(X_test_normalized[:,i].min())
    print(X_test_normalized[:,i].max())
    print('--------------------------')
# Out:
# -0.892778123319
# 0.925000613381
# --------------------------
# -1.02083227423
# 0.903520298425
# --------------------------
# -0.122322514627
# 1.0
# --------------------------
# -0.76708183367
# 0.912774493606
# --------------------------
# -0.750447581807
# 0.878339324448
# --------------------------
# -0.872004712958
# 0.874473818425
# --------------------------
# -0.6713302944
# 0.699040661439
# --------------------------
# -0.588795295738
# 0.917562261089
# --------------------------
# -0.529004385985
# 0.916726794555
# --------------------------

# %%
X_train_denormalized = denormalizeX(X_train_normalized, X_normalized_MinMaxScalerTrainTest)

# %%
X_test_denormalized = denormalizeX(X_test_normalized, X_normalized_MinMaxScalerTrainTest)

# %%
y_train_denormalized = denormalizeY(y_train_normalized, y_normalized_MinMaxScalerTrainTest)

# %%
y_test_denormalized = denormalizeY(y_test_normalized, y_normalized_MinMaxScalerTrainTest)

# %%
VisualizePredictedYLineWithValues(y.values, y_train_denormalized, targetVariable, 'Denormalized')

# %%
VisualizePredictedYLineWithValues(y.values[len(y_train_denormalized):], y_test_denormalized, targetVariable, 'Denormalized')

# %%
# this is the same as did it before, when whole dataset was trained

def trainMultiLayerRegressor(X_train_normalized, y_train_normalized, activation, neuronsTrainTest):

    # Train Neural Network
    mlp = MLPRegressor(hidden_layer_sizes=neuronsTrainTest, \
                       max_iter=250, \
                       activation=activation, \
                       solver="lbfgs", \
                       learning_rate="constant", \
                       learning_rate_init=0.01, \
                       alpha=0.01, \
                       verbose=False, \
                       momentum=0.9, \
                       early_stopping=False, \
                       tol=0.00000001, \
                       shuffle=False, \
                       # n_iter_no_change=200, \
                       random_state=1234)

    mlp.fit(X_train_normalized, y_train_normalized)
    
    # ide kéne beilleszteni a modell elmentését
    joblib.dump(mlp, 'models/saved_mlp_model_train_test.pkl')

    return mlp

# %%
# Train Neural Network
mlp = trainMultiLayerRegressor(X_train_normalized, y_train_normalized, activation_function, neuronsTrainTest)

# %%
def predictMultiLayerRegressor(mlp, X_normalized):
    y_predicted = mlp.predict(X_normalized)

    return y_predicted

# %%
# Create prediction
y_train_predicted = predictMultiLayerRegressor(mlp, X_train_normalized)

# Create prediction
y_test_predicted = predictMultiLayerRegressor(mlp, X_test_normalized)

# %%
evaluateGoodnessOfPrediction(y_train_normalized, y_train_predicted)
print('---------------------')
evaluateGoodnessOfPrediction(y_test_normalized, y_test_predicted)
# Out:
# Correlation           = 0.652
# Explained variance    = 0.424
# Mean Absolute Error   = 0.086
# Mean Squared Error    = 0.020
# R2 Score              = 0.424
# ---------------------
# Correlation           = 0.396
# Explained variance    = -0.652
# Mean Absolute Error   = 0.121
# Mean Squared Error    = 0.072
# R2 Score              = -0.746

# %%
y_train_denormalized = denormalizeY(y_train_normalized, y_normalized_MinMaxScalerTrainTest)

y_test_denormalized = denormalizeY(y_test_normalized, y_normalized_MinMaxScalerTrainTest)

y_train_predicted_denormalized = denormalizeY(y_train_predicted, y_normalized_MinMaxScalerTrainTest)

y_test_predicted_denormalized = denormalizeY(y_test_predicted, y_normalized_MinMaxScalerTrainTest)

# %%
from visualizerlinux import ScatterPlotsTrainTest

# %%
ScatterPlotsTrainTest(y_train_denormalized, y_train_predicted_denormalized, \
                      y_test_denormalized, y_test_predicted_denormalized, targetVariable)

# %%
ScatterPlotsTrainTest(y_train_normalized, y_train_predicted, \
                      y_test_normalized, y_test_predicted, targetVariable)

# %%
VisualizePredictedYLine(y_train_denormalized, y_train_predicted_denormalized, targetVariable, lines = True)

# %%
VisualizePredictedYLine(y_train_normalized, y_train_predicted, targetVariable, lines = True)

# %%
VisualizePredictedYLine(y_test_denormalized, y_test_predicted_denormalized, targetVariable, lines = True)

# %%
VisualizePredictedYLine(y_test_normalized, y_test_predicted, targetVariable, lines = True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
def createBeforeafterDFLags(df, lag):
    beforeafterDFLags = df.copy()
    inputVariables = np.flip(beforeafterDFLags.columns[0:10].ravel(), axis=-1)
    print('Input Variablels : ', inputVariables)

    index = 10
    for i in inputVariables:
        new_column = beforeafterDFLags[i].shift(lag)
        new_column_name = (str('prev') + str(1) + i) # Todo: rename str(lag)
        beforeafterDFLags.insert(loc=index, column=new_column_name, value=new_column)

    beforeafterDFLags = beforeafterDFLags[lag:]             # remove first row as we haven't got data in lag var
    
    return beforeafterDFLags

# %%
beforeafterDFLags = createBeforeafterDFLags(preProcessedDF, 1)
# Out:
# Input Variablels :  ['WorkerCount' 'PktOut' 'KBOut' 'PktIn' 'KBIn' 'CTXSW' 'Inter' 'CPU'
#  'SUM RR' 'AVG RR']

# %%
beforeafterDFLags.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'prev1AVG RR', 'prev1SUM RR', 'prev1CPU',
#        'prev1Inter', 'prev1CTXSW', 'prev1KBIn', 'prev1PktIn', 'prev1KBOut',
#        'prev1PktOut', 'prev1WorkerCount', 'avg latency (quantile 0.5)'],
#       dtype='object')

# %%
def createBeforeafterDFLeads(df, lead = 1):
    beforeafterDFLeads = df.copy()
    inputVariables = np.flip(beforeafterDFLeads.columns[0:10].ravel(), axis=-1)
    print('Input Variablels : ', inputVariables)

    index = 10
    for i in inputVariables:
        new_column = beforeafterDFLeads[i].shift(-lead)
        new_column_name = (str('next') + str(1) + i) # Todo: rename str(lead)
        beforeafterDFLeads.insert(loc=index, column=new_column_name, value=new_column)

    beforeafterDFLeads = beforeafterDFLeads[:-lead]             # remove last row as we haven't got data in lead var
    
    beforeafterDFLeads = beforeafterDFLeads.iloc[:,:-1]     # remove last column - Latency
    
    return beforeafterDFLeads

# %%
beforeafterDF = createBeforeafterDFLeads(beforeafterDFLags, lead = lead)
# Out:
# Input Variablels :  ['WorkerCount' 'PktOut' 'KBOut' 'PktIn' 'KBIn' 'CTXSW' 'Inter' 'CPU'
#  'SUM RR' 'AVG RR']

# %%
beforeafterDF.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'next1AVG RR', 'next1SUM RR', 'next1CPU',
#        'next1Inter', 'next1CTXSW', 'next1KBIn', 'next1PktIn', 'next1KBOut',
#        'next1PktOut', 'next1WorkerCount', 'prev1AVG RR', 'prev1SUM RR',
#        'prev1CPU', 'prev1Inter', 'prev1CTXSW', 'prev1KBIn', 'prev1PktIn',
#        'prev1KBOut', 'prev1PktOut', 'prev1WorkerCount'],
#       dtype='object')

# %%
# assert

a_colName = beforeafterDF.columns[-1]
a_cols = beforeafterDF.shape[1]

assert a_colName == 'prev1WorkerCount', "This column name is: {0} insted of prev1WorkerCount".format(a_colName)
assert a_cols == 30, "This column number is: {0} insted of 17".format(a_colName)

# %%
def calculateWorkerCountDifferences(beforeafterDF):
    new_beforeafterDF = beforeafterDF.copy()
    new_beforeafterDF['addedWorkerCount'] = new_beforeafterDF['next1WorkerCount'].values - new_beforeafterDF['WorkerCount']
    
    return new_beforeafterDF

# %%
theBeforeAfterDF = calculateWorkerCountDifferences(beforeafterDF)

# %%
def createScalingDF(theBeforeAfterDF):
    new_beforeafterDF = theBeforeAfterDF.copy()
    scalingDF = new_beforeafterDF[new_beforeafterDF.WorkerCount != new_beforeafterDF.next1WorkerCount]
    
    return scalingDF

# %%
scalingDF = createScalingDF(theBeforeAfterDF)

# %%
beforeafterMetricsDF = scalingDF.copy()

for i in metricNames:
    # print(i)
    changeInMetricAfterScale = beforeafterMetricsDF['next1'+i]-beforeafterMetricsDF[i]
    beforeafterMetricsDF['changed1'+i] = changeInMetricAfterScale

# %%
beforeafterMetricsDF[['prev1CPU','CPU','next1CPU','changed1CPU','prev1WorkerCount','WorkerCount','next1WorkerCount']]. \
head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row5_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row6_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row7_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row8_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row8_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row8_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row8_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da6_aeb3_11e9_b6b8_fa163ebcacb9row8_col4 {

# %%
beforeafterMetricsDF[['prev1CPU','CPU','next1CPU','changed1CPU','prev1WorkerCount','WorkerCount','next1WorkerCount']]. \
head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row5_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row6_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row7_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row8_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row8_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row8_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row8_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da7_aeb3_11e9_b6b8_fa163ebcacb9row8_col4 {

# %%
beforeafterMetricsDF[['changed1CPU', 'changed1Inter', 'changed1CTXSW', 'changed1KBIn', \
                      'changed1KBOut', 'changed1PktIn', 'changed1PktOut', 'addedWorkerCount']]. \
groupby(['addedWorkerCount'], as_index=False).mean().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >addedWorkerCount</th>
#         <th class="col_heading level0 col1" >changed1CPU</th>
#         <th class="col_heading level0 col2" >changed1Inter</th>
#         <th class="col_heading level0 col3" >changed1CTXSW</th>
#         <th class="col_heading level0 col4" >changed1KBIn</th>
#         <th class="col_heading level0 col5" >changed1KBOut</th>
#         <th class="col_heading level0 col6" >changed1PktIn</th>
#         <th class="col_heading level0 col7" >changed1PktOut</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >-3.00</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >0.99</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >223.90</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col3" class="data row0 col3" >294.84</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col4" class="data row0 col4" >81.40</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col5" class="data row0 col5" >11.76</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col6" class="data row0 col6" >129.57</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row0_col7" class="data row0 col7" >88.69</td>
#     </tr>    <tr>
#         <th id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >-2.00</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >-0.52</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >-5.38</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col3" class="data row1 col3" >-40.48</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col4" class="data row1 col4" >11.53</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col5" class="data row1 col5" >0.53</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col6" class="data row1 col6" >8.16</td>
#         <td id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9row1_col7" class="data row1 col7" >-2.38</td>
#     </tr>    <tr>
#         <th id="T_c93b4da8_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_c93b4da8_aeb3_11e

# %%
beforeafterMetricsDF[['changed1CPU', 'changed1Inter', 'changed1CTXSW', 'changed1KBIn', \
                      'changed1KBOut', 'changed1PktIn', 'changed1PktOut', 'addedWorkerCount']]. \
groupby(['addedWorkerCount'], as_index=False).count().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >addedWorkerCount</th>
#         <th class="col_heading level0 col1" >changed1CPU</th>
#         <th class="col_heading level0 col2" >changed1Inter</th>
#         <th class="col_heading level0 col3" >changed1CTXSW</th>
#         <th class="col_heading level0 col4" >changed1KBIn</th>
#         <th class="col_heading level0 col5" >changed1KBOut</th>
#         <th class="col_heading level0 col6" >changed1PktIn</th>
#         <th class="col_heading level0 col7" >changed1PktOut</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >-3.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >1.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >1.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col3" class="data row0 col3" >1.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col4" class="data row0 col4" >1.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col5" class="data row0 col5" >1.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col6" class="data row0 col6" >1.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row0_col7" class="data row0 col7" >1.00</td>
#     </tr>    <tr>
#         <th id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >-2.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >11.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >11.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col3" class="data row1 col3" >11.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col4" class="data row1 col4" >11.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col5" class="data row1 col5" >11.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col6" class="data row1 col6" >11.00</td>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9row1_col7" class="data row1 col7" >11.00</td>
#     </tr>    <tr>
#         <th id="T_c93b4da9_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_c93b4da9_aeb3_11e9_b6b8_f

# %%
print(theBeforeAfterDF.shape)

print(scalingDF.shape)
# Out:
# (672, 31)
# (106, 31)

# %%
metricNames
# Out:
# ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']

# %%
def calculateLinearRegressionTerms(metric, dataFrame):
    termDF = dataFrame.copy()
    termDF['metric'] = termDF[metric]
    termDF['term1']  = termDF[metric] * termDF['WorkerCount'] / (termDF['WorkerCount'] + termDF['addedWorkerCount'])
    termDF['term2']  = termDF[metric] * termDF['addedWorkerCount'] / (termDF['WorkerCount'] + termDF['addedWorkerCount'])
    return termDF


def createInputAndTargetToLinearRegression(currentMetric, dataFrameB):
    newDataFrameB = dataFrameB.copy()
    yb = newDataFrameB['next1' + str(currentMetric)]
    featuresDF = newDataFrameB[[str(currentMetric), 'WorkerCount', 'next1WorkerCount', 'addedWorkerCount']]
    
    tmpDF = calculateLinearRegressionTerms(currentMetric, featuresDF)
    
    Xb = tmpDF.iloc[:, [-3, -2, -1]]     # keep last three column - given metric, term1, term2
    
    # These are only for check everything is in order
    # print(y.head(1))
    # print(featuresDF.head(1))
    # print(X.head(2))
    # scalingDF[['CPU', 'next1CPU', 'WorkerCount', 'next1WorkerCount', 'addedWorkerCount']][0:3]
    return Xb, yb


def calculateLinearRegressionModel(currentMetric, dataFrameA):
    newDataFrameA = dataFrameA.copy()
    Xa, ya = createInputAndTargetToLinearRegression(currentMetric, newDataFrameA)
    
    # ToDo : Return and store particular model
    
    lr = LinearRegression(fit_intercept=True, normalize=False)
    lr.fit(Xa, ya)
    # prediction = lr.predict(X)
    
    return lr


def calculateLinearRegressionPrediction(metric, dataFrame, model):
    X, y = createInputAndTargetToLinearRegression(metric, dataFrame)
    
    model.fit(X, y)
    y_predicted = model.predict(X)
    
    # print('Score = ', model.score(X, y))
    # print(metric, 'MAE \t=\t{:0.2f}'.format(metrics.mean_absolute_error(y, y_predicted)))
    
    # todo: refactor
    print(metric)
    evaluateGoodnessOfPrediction(y, y_predicted)
    print('-----------------------------------')
    
    return y_predicted

# %%
temporaryScalingDF = scalingDF.copy()

# %%
d={}
for i in metricNames:
    d["model{0}".format(i)]="Hello " + i
    # print(d)
    
d.get('modelCPU')
# Out:
# 'Hello CPU'

# %%
def learningLinearRegression(scalingDF, temporaryScalingDF, metricNames):
    # linearRegressionModels = {}
    # temporaryScalingDF = scalingDF.copy()
    d={}
    
    for i in metricNames:

        # d["model{0}".format(i)]="Hello " + i
        
        model = calculateLinearRegressionModel(i, scalingDF)
        prediction = calculateLinearRegressionPrediction(i, scalingDF, model)
        
        # save model to the file system
        joblib.dump(model, 'models/saved_linearregression_model_' + i + '.pkl')

        # nos van egy ilyen modellünk mit tegyünk vele, tároljuk el mindegyiket különböző néven
        d["model{0}".format(i)] = model

        # el kéne tárolni
        temporaryScalingDF['predictedNext1'+i] = prediction

    
    return temporaryScalingDF, d

# %%
temporaryScalingDF, linearRegressionModels = learningLinearRegression(scalingDF, temporaryScalingDF, metricNames)
# Out:
# CPU
# Correlation           = 0.652
# Explained variance    = 0.425
# Mean Absolute Error   = 5.310
# Mean Squared Error    = 48.328
# R2 Score              = 0.425
# -----------------------------------
# Inter
# Correlation           = 0.647
# Explained variance    = 0.419
# Mean Absolute Error   = 395.734
# Mean Squared Error    = 299776.965
# R2 Score              = 0.419
# -----------------------------------
# CTXSW
# Correlation           = 0.547
# Explained variance    = 0.300
# Mean Absolute Error   = 385.045
# Mean Squared Error    = 297667.521
# R2 Score              = 0.300
# -----------------------------------
# KBIn
# Correlation           = 0.311
# Explained variance    = 0.097
# Mean Absolute Error   = 220.380
# Mean Squared Error    = 107965.121
# R2 Score              = 0.097
# -----------------------------------
# PktIn
# Correlation           = 0.650
# Explained variance    = 0.423
# Mean Absolute Error   = 203.032
# Mean Squared Error    = 80902.089
# R2 Score              = 0.423
# -----------------------------------
# KBOut
# Correlation           = 0.712
# Explained variance    = 0.506
# Mean Absolute Error   = 22.331
# Mean Squared Error    = 881.292
# R2 Score              = 0.506
# -----------------------------------
# PktOut
# Correlation           = 0.721
# Explained variance    = 0.520
# Mean Absolute Error   = 195.482
# Mean Squared Error    = 67018.037
# R2 Score              = 0.520
# -----------------------------------

# %%
linearRegressionModelNames = linearRegressionModels.keys()

print(linearRegressionModelNames)

modelCPU = linearRegressionModels.get('modelCPU')

print(type(modelCPU))
# Out:
# dict_keys(['modelCPU', 'modelInter', 'modelCTXSW', 'modelKBIn', 'modelPktIn', 'modelKBOut', 'modelPktOut'])
# <class 'sklearn.linear_model.base.LinearRegression'>

# %%
temporaryScalingDF.columns
# Out:
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'next1AVG RR', 'next1SUM RR', 'next1CPU',
#        'next1Inter', 'next1CTXSW', 'next1KBIn', 'next1PktIn', 'next1KBOut',
#        'next1PktOut', 'next1WorkerCount', 'prev1AVG RR', 'prev1SUM RR',
#        'prev1CPU', 'prev1Inter', 'prev1CTXSW', 'prev1KBIn', 'prev1PktIn',
#        'prev1KBOut', 'prev1PktOut', 'prev1WorkerCount', 'addedWorkerCount',
#        'predictedNext1CPU', 'predictedNext1Inter', 'predictedNext1CTXSW',
#        'predictedNext1KBIn', 'predictedNext1PktIn', 'predictedNext1KBOut',
#        'predictedNext1PktOut'],
#       dtype='object')

# %%
temporaryScalingDF.shape
# Out:
# (106, 38)

# %%
temporaryScalingDF.shape
# Out:
# (106, 38)

# %%
from visualizerlinux import ipythonPlotMetricsRealAgainstPredicted

# %%
metricNames = ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']

ipythonPlotMetricsRealAgainstPredicted(temporaryScalingDF, metricNames)

# %%
from visualizerlinux import ipythonPlotMetricsRealAgainstPredictedRegression

# %%
ipythonPlotMetricsRealAgainstPredictedRegression(temporaryScalingDF, metricNames)

# %% [markdown]
# ### End of Learning Phase

# %% [markdown]
# <a id="test_begin"></a>
#
# # Advice Phase - Production Phase

# %%
from utils import loadMinMaxScalerXFull, loadMinMaxScalerYFull
from utils import loadNeuralNetworkModel
from utils import readCSV
from utils import preProcessing, renameVariable, setMetricNames, setExtendedMetricNames, dropFirstCases

from linearregression import calculateLinearRegressionTerms

from visualizerlinux import VisualizePredictedYLine, VisualizePredictedYWithWorkers

from sklearn.externals import joblib

pandas_dataframe_styles = {
    'font-family': 'monospace',
    'white-space': 'pre'
}

# %%
X_normalized_MinMaxScaler = loadMinMaxScalerXFull()
y_normalized_MinMaxScaler = loadMinMaxScalerYFull()

modelNeuralNet = loadNeuralNetworkModel()

# %%
# Vigyázat ennek azonosnak kell lennie a korábbi értékkel különben para van (ezt valahogy ki kéne vezetni valami külső
# fájlba, vagy csinálni valamilyen osztályt amiben ez el van tárolva)

cutFirstCases = 0                                                      # 10
targetVariable = 'avg latency (quantile 0.5)'
testFileName = 'data/grafana_data_export_long_running_test.csv'        # original data
testFileName = 'data/test_data.csv'                                    # test data
testFileName = 'data/test_data2.csv'                                   # test data
# testFileName = 'data/micado0730715_v2.csv'

maximumNumberIncreasableNode = 6                                       # must be positive
minimumNumberReducibleNode = -4                                        # must be negativ

upperLimit = 4000000                                                   # 6000000
lowerLimit = 3000000                                                   # 1000000

# %%
newDF = readCSV(testFileName)

# %%
newPreProcessedDF = preProcessing(newDF)

newRenamedDF = renameVariable(newPreProcessedDF, 'Worker count', 'WorkerCount')

metricNames         = setMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut'])
extendedMetricNames = setExtendedMetricNames(['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut', 'WorkerCount'])

newFilteredDF = dropFirstCases(newRenamedDF, cutFirstCases)

# %% [markdown]
# >#### Add new workers (increse the nuber of added Worker)

# %%
metricNames
# Out:
# ['CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut', 'PktOut']

# %%
def calculatePredictedLatencyWithVariousWorkers(modelNeuralNet, to):

    newDFForRegression = newFilteredDF.copy()
    nDD = newFilteredDF.copy()
    
    step = 0
    
    if( to == 0 ):
        print("")
        assert to != 0,"This value can not be 0. Error in calculatePredictedLatencyWithVariousWorkers method set maximum number of scalable nodes."
    elif( to > 0 ):
        step = 1
        print('............. up maximum vm = ' + str(to) + ' ...........')
    elif( to < 0 ):
        step = -1
        print('............. down maximum vm = ' + str(to) + ' ...........')

    for j in range(0, to, step):
        
        addedWorkerCount = j

        newDFForRegression['addedWorkerCount'] = addedWorkerCount

        for i in metricNames:

            newDFForRegressionWithTerms = calculateLinearRegressionTerms(i, newDFForRegression)

            print("------------     ", newDFForRegressionWithTerms.CPU.values[1], "     ------------")
            print("------------     ", newDFForRegressionWithTerms.shape, "     ------------")
            print("------------     ", newDFForRegressionWithTerms.columns, "     ------------")

            # keep last three column - given metric, term1, term2
            X = newDFForRegressionWithTerms.iloc[:, [-3, -2, -1]]
            
            print("------------     ", X.shape, "     ------------")
            print("------------     ", X.values[0], "     ------------") # Error ez az érték első eleme fix kéne hogy legyen
            print("------------     ", X.values[-1], "     ------------")# ugyanakkor folyamatosan változik
            
            # load the proper current metric model
            modelForMetric = joblib.load('models/saved_linearregression_model_' + i + '.pkl')

            print("------------     ", modelForMetric.get_params(), "     ------------")

            if( np.isinf(X).any()[1] ):
                X['term1'] = np.where(np.isinf(X['term1'].values), X['metric'], X['term1'])
                X['term2'] = np.where(np.isinf(X['term2'].values), 0, X['term2'])
                # print('-----------')
                # print(X.to_string())
                
            
            # create prediction and store in a new numpy.array object
            predictedMetric = modelForMetric.predict(X)
            
            
            # leave original metric value (just for fun and investigation) and store in a new column
            newDFForRegression['original' + i] = newDFForRegression[i]

            # store predicted value pretend as would be the original. for example predictedCPU will be CPU
            newDFForRegression[i] = predictedMetric
            nDD[i] = predictedMetric

            print("------------     ", newDFForRegression[['CPU']].values[1], "    ------------")
            print("------------     ", nDD[['CPU']].values[1], "    ------------")

            # print out the new data frame
            newDFForRegression.head()


        newDFForNerualNetworkPrediction = newDFForRegression.copy()     
        
        # X must contain exactly the same columns as the model does
        X = newDFForNerualNetworkPrediction.iloc[:, :9]
        
        # X must be normalized based on a previously created MinMaxScaler
        X_normalized_MinMaxScaler # the name of the MinMaxScaler

        X_normalized = X_normalized_MinMaxScaler.transform(X)

        # modelNeuralNet = joblib.load('models/saved_mlp_model.pkl')
        modelNeuralNet = modelNeuralNet

        # create and store predicted values in a numpy.array object
        y_predicted_with_new_metrics = modelNeuralNet.predict(X_normalized)

        # denormalized predicted values
        y_predicted_with_new_metrics_denormalized = y_normalized_MinMaxScaler.inverse_transform(y_predicted_with_new_metrics.reshape(y_predicted_with_new_metrics.shape[0],1))

        newDFForNerualNetworkPrediction['predictedResponseTimeAdded' + str(j) + 'Worker'] = y_predicted_with_new_metrics
        newDFForNerualNetworkPrediction['denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'] = y_predicted_with_new_metrics_denormalized

        if(j == 0):
            investigationDF = newDFForNerualNetworkPrediction[[targetVariable, 'WorkerCount']]
            investigationDFDeNormalized = newDFForNerualNetworkPrediction[[targetVariable, 'WorkerCount']]
            #investigationDF = newDFForNerualNetworkPrediction[['predictedResponseTimeAdded0Worker']]
            #investigationDFDeNormalized = newDFForNerualNetworkPrediction[['denormalizedPredictedResponseTimeAdded0Worker']]

        investigationDF['predictedResponseTimeAdded' + str(j) + 'Worker'] = newDFForNerualNetworkPrediction[['predictedResponseTimeAdded' + str(j) + 'Worker']]
        investigationDFDeNormalized['denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'] = newDFForNerualNetworkPrediction[['denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker']]

    print(newDFForNerualNetworkPrediction.columns)
    
    print(investigationDFDeNormalized.columns)
    
    return investigationDF, investigationDFDeNormalized

# %%
investigationDFUp, investigationDFDeNormalizedUp = calculatePredictedLatencyWithVariousWorkers(modelNeuralNet, \
                                                                                               maximumNumberIncreasableNode)
# Out:
# ............. up maximum vm = 6 ...........
# ------------      90.205557037      ------------
# ------------      (659, 15)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 85.2  85.2   0. ]      ------------
# ------------      [ 84.689  84.689   0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 16)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 6760.545  6760.545     0.   ]      ------------
# ------------      [ 6191.471  6191.471     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 17)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'metric', 'term1',
#        'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 10141.15  10141.15      0.  ]      ------------
# ------------      [ 9036.789  9036.789     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 18)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1062.958  1062.958     0.   ]      ------------
# ------------      [ 977.234  977.234    0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 19)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1935.567  1935.567     0.   ]      ------------
# ------------      [ 1853.772  1853.772     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 20)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 192.742  192.742    0.   ]      ------------
# ------------      [ 199.202  199.202    0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 21)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'metric', 'term1',
#        'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1512.828  1512.828     0.   ]      ------------
# ------------      [ 1696.547  1696.547     0.   ]      ------------
# ------------
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 84.131  63.098  21.033]      ------------
# ------------      [ 83.755  71.79   11.965]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 6623.409  4967.557  1655.852]      ------------
# ------------      [ 6317.511  5415.01    902.502]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 9875.77   7406.828  2468.943]      ------------
# ------------      [ 9364.045  8026.324  1337.721]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1220.995   915.746   305.249]      ------------
# ------------      [ 1196.087  1025.217   170.87 ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1947.322  1460.492   486.831]      ------------
# ------------      [ 1891.796  1621.539   270.257]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 193.039  144.779   48.26 ]      ------------
# ------------      [ 196.965  168.827   28.138]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1549.22   1161.915   387.305]      ------------
# ------------      [ 1665.086  1427.216   237.869]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 84.49]     ------------
# ------------      [ 84.49]     ------------
# ------------      84.489705515      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 81.844  49.106  32.738]      ------------
# ------------      [ 82.214  61.66   20.553]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 6324.957  3794.974  2529.983]      ------------
# ------------      [ 6262.772  4697.079  1565.693]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 9572.861  5743.717  3829.144]      ------------
# ------------      [ 9418.189  7063.642  2354.547]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1279.694   767.817   511.878]      ------------
# ------------      [ 1266.83    950.123   316.708]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1863.05  1117.83   745.22]      ------------
# ------------      [ 1863.38   1397.535   465.845]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 180.779  108.467   72.312]      ------------
# ------------      [ 188.352  141.264   47.088]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1471.469   882.881   588.588]      ------------
# ------------      [ 1583.396  1187.547   395.849]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 81.198]     ------------
# ------------      [ 81.198]     ------------
# ------------      81.1980851058      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 79.326  39.663  39.663]      ------------
# ------------      [ 80.467  53.645  26.822]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 6045.888  3022.944  3022.944]      ------------
# ------------      [ 6143.337  4095.558  2047.779]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 9333.369  4666.684  4666.684]      ------------
# ------------      [ 9369.17   6246.113  3123.057]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1305.402   652.701   652.701]      ------------
# ------------      [ 1293.492   862.328   431.164]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1750.758   875.379   875.379]      ------------
# ------------      [ 1805.739  1203.826   601.913]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 167.128   83.564   83.564]      ------------
# ------------      [ 178.233  118.822   59.411]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1370.098   685.049   685.049]      ------------
# ------------      [ 1490.8     993.867   496.933]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 78.29]     ------------
# ------------      [ 78.29]     ------------
# ------------      78.2902940369      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 76.979  32.991  43.988]      ------------
# ------------      [ 78.734  47.241  31.494]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 5828.972  2498.131  3330.841]      ------------
# ------------      [ 6013.707  3608.224  2405.483]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 9161.354  3926.295  5235.06 ]      ------------
# ------------      [ 9290.446  5574.267  3716.178]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1318.769   565.187   753.582]      ------------
# ------------      [ 1306.031   783.619   522.413]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1645.539   705.231   940.308]      ------------
# ------------      [ 1734.694  1040.816   693.878]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 155.931   66.828   89.104]      ------------
# ------------      [ 168.906  101.344   67.563]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1281.087   549.037   732.05 ]      ------------
# ------------      [ 1406.121   843.673   562.448]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 75.855]     ------------
# ------------      [ 75.855]     ------------
# ------------      75.8550134317      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 74.943  28.104  46.84 ]      ------------
# ------------      [ 77.126  42.069  35.057]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# ------------      73.8720521932      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 5670.582  2126.468  3544.114]      ------------
# ------------      [ 5895.477  3215.715  2679.762]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# ------------      73.8720521932      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 9040.224  3390.084  5650.14 ]      ------------
# ------------      [ 9210.74  5024.04  4186.7 ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# ------------      73.8720521932      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1326.876   497.579   829.298]      ------------
# ------------      [ 1313.496   716.452   597.043]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# ------------      73.8720521932      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1554.382   582.893   971.489]      ------------
# ------------      [ 1670.607   911.24    759.367]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# ------------      73.8720521932      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 147.699   55.387   92.312]      ------------
# ------------      [ 161.137   87.893   73.244]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# ------------      73.8720521932      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1212.73    454.774   757.956]      ------------
# ------------      [ 1335.682   728.554   607.128]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 73.872]     ------------
# ------------      [ 73.872]     ------------
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'predictedResponseTimeAdded5Worker',
#        'denormalizedPredictedResponseTimeAdded5Worker'],
#       dtype='object')
# Index(['avg latency (quantile 0.5)', 'WorkerCount',
#        'denormalizedPredictedResponseTimeAdded0Worker',
#        'denormalizedPredictedResponseTimeAdded1Worker',
#        'denormalizedPredictedResponseTimeAdded2Worker',
#        'denormalizedPredictedResponseTimeAdded3Worker',
#        'denormalizedPredictedResponseTimeAdded4Worker',
#        'denormalizedPredictedResponseTimeAdded5Worker'],
#       dtype='object')

# %%
investigationDFDown, investigationDFDeNormalizedDown = calculatePredictedLatencyWithVariousWorkers(modelNeuralNet, \
                                                                                                   minimumNumberReducibleNode)
# Out:
# ............. down maximum vm = -4 ...........
# ------------      90.205557037      ------------
# ------------      (659, 15)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 85.2  85.2   0. ]      ------------
# ------------      [ 84.689  84.689   0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 16)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 6760.545  6760.545     0.   ]      ------------
# ------------      [ 6191.471  6191.471     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 17)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'metric', 'term1',
#        'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 10141.15  10141.15      0.  ]      ------------
# ------------      [ 9036.789  9036.789     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 18)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1062.958  1062.958     0.   ]      ------------
# ------------      [ 977.234  977.234    0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 19)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1935.567  1935.567     0.   ]      ------------
# ------------      [ 1853.772  1853.772     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 20)      ------------
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 192.742  192.742    0.   ]      ------------
# ------------      [ 199.202  199.202    0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 21)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'metric', 'term1',
#        'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1512.828  1512.828     0.   ]      ------------
# ------------      [ 1696.547  1696.547     0.   ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 87.815]     ------------
# ------------      [ 87.815]     ------------
# ------------      87.8146942636      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [  84.131  126.196  -42.065]      ------------
# ------------      [  83.755  100.506  -16.751]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#       ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 6623.409  9935.114 -3311.705]      ------------
# ------------      [ 6317.511  7581.014 -1263.502]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [  9875.77   14813.655  -4937.885]      ------------
# ------------      [  9364.045  11236.854  -1872.809]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1220.995  1831.492  -610.497]      ------------
# ------------      [ 1196.087  1435.304  -239.217]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1947.322  2920.984  -973.661]      ------------
# ------------      [ 1891.796  2270.155  -378.359]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 193.039  289.558  -96.519]      ------------
# ------------      [ 196.965  236.358  -39.393]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1549.22   2323.831  -774.61 ]      ------------
# ------------      [ 1665.086  1998.103  -333.017]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 89.185]     ------------
# ------------      [ 89.185]     ------------
# ------------      89.1853995785      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [  86.343  259.028 -172.685]      ------------
# ------------      [  84.261  126.391  -42.13 ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [  6999.169  20997.506 -13998.337]      ------------
# ------------      [ 6556.749  9835.123 -3278.374]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 10112.683  30338.05  -20225.367]      ------------
# ------------      [  9652.178  14478.268  -4826.089]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1241.348  3724.045 -2482.697]      ------------
# ------------      [ 1249.658  1874.488  -624.829]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 2154.958  6464.875 -4309.916]      ------------
# ------------      [ 1992.515  2988.773  -996.258]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 218.1  654.3 -436.2]      ------------
# ------------      [ 205.76  308.64 -102.88]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1773.577  5320.732 -3547.155]      ------------
# ------------      [ 1731.831  2597.747  -865.916]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 99.781]     ------------
# ------------      [ 99.781]     ------------
# ------------      99.7811284437      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 97.283     inf    -inf]      ------------
# ------------      [  86.443  172.886  -86.443]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# ------------      94.8626448082      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 8651.575       inf      -inf]      ------------
# ------------      [  6958.812  13917.625  -6958.812]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# ------------      94.8626448082      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 11336.64       inf      -inf]      ------------
# ------------      [ 10000.93   20001.861 -10000.93 ]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# ------------      94.8626448082      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 1168.865       inf      -inf]      ------------
# ------------      [ 1249.077  2498.153 -1249.077]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# ------------      94.8626448082      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 2965.137       inf      -inf]      ------------
# ------------      [ 2184.06  4368.12 -2184.06]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# ------------      94.8626448082      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 320.894      inf     -inf]      ------------
# ------------      [ 227.471  454.942 -227.471]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# ------------      94.8626448082      ------------
# ------------      (659, 22)      ------------
# ------------      Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'metric', 'term1', 'term2'],
#       dtype='object')      ------------
# ------------      (659, 3)      ------------
# ------------      [ 2635.959       inf      -inf]      ------------
# ------------      [ 1912.484  3824.968 -1912.484]      ------------
# ------------      {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'normalize': False}      ------------
# ------------      [ 94.863]     ------------
# ------------      [ 94.863]     ------------
# Index(['AVG RR', 'SUM RR', 'CPU', 'Inter', 'CTXSW', 'KBIn', 'PktIn', 'KBOut',
#        'PktOut', 'WorkerCount', 'avg latency (quantile 0.5)',
#        'addedWorkerCount', 'originalCPU', 'originalInter', 'originalCTXSW',
#        'originalKBIn', 'originalPktIn', 'originalKBOut', 'originalPktOut',
#        'predictedResponseTimeAdded-3Worker',
#        'denormalizedPredictedResponseTimeAdded-3Worker'],
#       dtype='object')
# Index(['avg latency (quantile 0.5)', 'WorkerCount',
#        'denormalizedPredictedResponseTimeAdded0Worker',
#        'denormalizedPredictedResponseTimeAdded-1Worker',
#        'denormalizedPredictedResponseTimeAdded-2Worker',
#        'denormalizedPredictedResponseTimeAdded-3Worker'],
#       dtype='object')
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Merge Up and Down Adviser

# %%
investigationDeNormalizedDF = pd.concat([investigationDFDeNormalizedDown, \
                             investigationDFDeNormalizedUp], axis = 1).T.drop_duplicates().T

investigationDeNormalizedDF.values.shape
# Out:
# (659, 11)

# %%
investigationDeNormalizedDF.head().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}")
# Out:
# <style  type="text/css" >
#     #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row0_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row1_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row2_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row3_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9row4_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_d1128224_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >avg latency (quantile 0.5)</th>
#         <th class="col_heading level0 col1" >WorkerCount</th>
#         <th class="col_heading level0 col2" >denormalizedPredictedResponseTimeAdded0Worker</th>
#         <th class="col_heading level0 col3" >denormalizedPredictedResponseTimeAdded-1Worker</th>
#         <th class="col_heading level0 col4" >denormalizedPredictedResponseTimeAdded-2Worker</th>
#         <th class="col_heading level0 col5" >denormalizedPredictedResponseTimeAdded-3Worker</th>
#         <th class="col_heading level0 col6" >denormali

# %%
investigationDFUp.head().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}")
# Out:
# <style  type="text/css" >
#     #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >avg latency (quantile 0.5)</th>
#         <th class="col_heading level0 col1" >WorkerCount</th>
#         <th class="col_heading level0 col2" >predictedResponseTimeAdded0Worker</th>
#         <th class="col_heading level0 col3" >predictedResponseTimeAdded1Worker</th>
#         <th class="col_heading level0 col4" >predictedResponseTimeAdded2Worker</th>
#         <th class="col_heading level0 col5" >predictedResponseTimeAdded3Worker</th>
#         <th class="col_heading level0 col6" >predictedResponseTimeAdded4Worker</th>
#         <th class="col_heading level0 col7" >predictedResponseTimeAdded5Worker</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >735675.318</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >3.000</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >-0.956</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col3" class="data row0 col3" >-0.984</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col4" class="data row0 col4" >-1.016</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col5" class="data row0 col5" >-1.037</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col6" class="data row0 col6" >-1.046</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row0_col7" class="data row0 col7" >-1.049</td>
#     </tr>    <tr>
#         <th id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >280211.301</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >3.000</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >-0.892</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col3" class="data row1 col3" >-0.925</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col4" class="data row1 col4" >-0.962</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col5" class="data row1 col5" >-0.986</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col6" class="data row1 col6" >-1.002</td>
#         <td id="T_d1128225_aeb3_11e9_b6b8_fa163ebcacb9row1_col7" class="data row1 col7" >-1.012</td>
#     </tr>

# %%
investigationDFDown.head().style.set_properties(**pandas_dataframe_styles).format("{:0.3f}")
# Out:
# <style  type="text/css" >
#     #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >avg latency (quantile 0.5)</th>
#         <th class="col_heading level0 col1" >WorkerCount</th>
#         <th class="col_heading level0 col2" >predictedResponseTimeAdded0Worker</th>
#         <th class="col_heading level0 col3" >predictedResponseTimeAdded-1Worker</th>
#         <th class="col_heading level0 col4" >predictedResponseTimeAdded-2Worker</th>
#         <th class="col_heading level0 col5" >predictedResponseTimeAdded-3Worker</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >735675.318</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >3.000</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >-0.956</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col3" class="data row0 col3" >-0.924</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col4" class="data row0 col4" >-1.048</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row0_col5" class="data row0 col5" >-0.982</td>
#     </tr>    <tr>
#         <th id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >280211.301</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >3.000</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >-0.892</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col3" class="data row1 col3" >-0.883</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col4" class="data row1 col4" >-0.931</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row1_col5" class="data row1 col5" >-0.897</td>
#     </tr>    <tr>
#         <th id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col0" class="data row2 col0" >723342.349</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col1" class="data row2 col1" >4.000</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col2" class="data row2 col2" >-0.921</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col3" class="data row2 col3" >-0.874</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col4" class="data row2 col4" >-0.908</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row2_col5" class="data row2 col5" >-0.813</td>
#     </tr>    <tr>
#         <th id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9level0_row3" class="row_heading level0 row3" >5</th>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col0" class="data row3 col0" >661149.152</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col1" class="data row3 col1" >4.000</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col2" class="data row3 col2" >-0.923</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col3" class="data row3 col3" >-0.915</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col4" class="data row3 col4" >-0.974</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row3_col5" class="data row3 col5" >-0.966</td>
#     </tr>    <tr>
#         <th id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9level0_row4" class="row_heading level0 row4" >6</th>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col0" class="data row4 col0" >1369729.792</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col1" class="data row4 col1" >4.000</td>
#         <td id="T_d1128226_aeb3_11e9_b6b8_fa163ebcacb9row4_col2" class="data row4 col2"

# %%
investigationDFDeNormalizedUp.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >avg latency (quantile 0.5)</th>
#         <th class="col_heading level0 col1" >WorkerCount</th>
#         <th class="col_heading level0 col2" >denormalizedPredictedResponseTimeAdded0Worker</th>
#         <th class="col_heading level0 col3" >denormalizedPredictedResponseTimeAdded1Worker</th>
#         <th class="col_heading level0 col4" >denormalizedPredictedResponseTimeAdded2Worker</th>
#         <th class="col_heading level0 col5" >denormalizedPredictedResponseTimeAdded3Worker</th>
#         <th class="col_heading level0 col6" >denormalizedPredictedResponseTimeAdded4Worker</th>
#         <th class="col_heading level0 col7" >denormalizedPredictedResponseTimeAdded5Worker</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >735675.32</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >3.00</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >948173.02</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col3" class="data row0 col3" >364691.35</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col4" class="data row0 col4" >-311751.78</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col5" class="data row0 col5" >-747769.85</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col6" class="data row0 col6" >-943432.16</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row0_col7" class="data row0 col7" >-1003234.08</td>
#     </tr>    <tr>
#         <th id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >280211.30</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >3.00</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >2301201.00</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col3" class="data row1 col3" >1593649.79</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col4" class="data row1 col4" >829065.77</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col5" class="data row1 col5" >310211.03</td>
#         <td id="T_d1128227_aeb3_11e9_b6b8_fa163ebcacb9row1_col6" class="data row1 col6" >-15344.90</td>

# %%
investigationDFDeNormalizedDown.head().style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }</style>
# <table id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >avg latency (quantile 0.5)</th>
#         <th class="col_heading level0 col1" >WorkerCount</th>
#         <th class="col_heading level0 col2" >denormalizedPredictedResponseTimeAdded0Worker</th>
#         <th class="col_heading level0 col3" >denormalizedPredictedResponseTimeAdded-1Worker</th>
#         <th class="col_heading level0 col4" >denormalizedPredictedResponseTimeAdded-2Worker</th>
#         <th class="col_heading level0 col5" >denormalizedPredictedResponseTimeAdded-3Worker</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9level0_row0" class="row_heading level0 row0" >1</th>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col0" class="data row0 col0" >735675.32</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col1" class="data row0 col1" >3.00</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col2" class="data row0 col2" >948173.02</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col3" class="data row0 col3" >1628245.06</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col4" class="data row0 col4" >-987294.02</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row0_col5" class="data row0 col5" >395979.02</td>
#     </tr>    <tr>
#         <th id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9level0_row1" class="row_heading level0 row1" >2</th>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col0" class="data row1 col0" >280211.30</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col1" class="data row1 col1" >3.00</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col2" class="data row1 col2" >2301201.00</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col3" class="data row1 col3" >2479383.08</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col4" class="data row1 col4" >1475498.88</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row1_col5" class="data row1 col5" >2189419.78</td>
#     </tr>    <tr>
#         <th id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9level0_row2" class="row_heading level0 row2" >3</th>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col0" class="data row2 col0" >723342.35</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col1" class="data row2 col1" >4.00</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col2" class="data row2 col2" >1687264.18</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col3" class="data row2 col3" >2662209.07</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col4" class="data row2 col4" >1958228.26</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row2_col5" class="data row2 col5" >3954094.05</td>
#     </tr>    <tr>
#         <th id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9level0_row3" class="row_heading level0 row3" >5</th>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col0" class="data row3 col0" >661149.15</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col1" class="data row3 col1" >4.00</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col2" class="data row3 col2" >1651933.07</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col3" class="data row3 col3" >1816959.70</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col4" class="data row3 col4" >564852.58</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row3_col5" class="data row3 col5" >730605.59</td>
#     </tr>    <tr>
#         <th id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9level0_row4" class="row_heading level0 row4" >6</th>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col0" class="data row4 col0" >1369729.79</td>
#         <td id="T_d1128228_aeb3_11e9_b6b8_fa163ebcacb9row4_col1" class="data row4 col1" >

# %%
VisualizePredictedYWithWorkers(0, investigationDFDown[['predictedResponseTimeAdded0Worker', \
                                                       'predictedResponseTimeAdded-1Worker', \
                                                       'predictedResponseTimeAdded-2Worker', \
                                                       'predictedResponseTimeAdded-3Worker']], targetVariable)

# %%
VisualizePredictedYWithWorkers(0, investigationDFUp[['predictedResponseTimeAdded1Worker', \
                                                     'predictedResponseTimeAdded2Worker', \
                                                     'predictedResponseTimeAdded3Worker']], targetVariable)

# %%
VisualizePredictedYWithWorkers(0, investigationDFUp[['predictedResponseTimeAdded0Worker', \
                                              'predictedResponseTimeAdded1Worker', \
                                              'predictedResponseTimeAdded2Worker', \
                                              'predictedResponseTimeAdded3Worker', \
                                              'predictedResponseTimeAdded4Worker', \
                                              'predictedResponseTimeAdded5Worker']], targetVariable)

# %%
VisualizePredictedYWithWorkers(0, investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded1Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded2Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded3Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded4Worker', \
                                                                 'denormalizedPredictedResponseTimeAdded5Worker']], targetVariable)

# %%
VisualizePredictedYLine(investigationDFDeNormalizedUp['avg latency (quantile 0.5)'], \
                        investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker', \
                                                          'denormalizedPredictedResponseTimeAdded1Worker', \
                                                          'denormalizedPredictedResponseTimeAdded2Worker', \
                                                          'denormalizedPredictedResponseTimeAdded3Worker', \
                                                          'denormalizedPredictedResponseTimeAdded4Worker', \
                                                          'denormalizedPredictedResponseTimeAdded5Worker']], targetVariable)

# %%
VisualizePredictedYLine(investigationDFDeNormalizedUp[[targetVariable]], \
                        investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker']], targetVariable)

# %%
VisualizePredictedYLine(investigationDFDeNormalizedUp[[targetVariable]], \
                        investigationDFDeNormalizedUp[['denormalizedPredictedResponseTimeAdded0Worker']], targetVariable)

# %% [markdown]
# ### Get Advice

# %%
from visualizerlinux import VisualizePredictedXYLine
from visualizerlinux import VisualizePredictedXY2Line

# %%
VisualizePredictedXYLine(0, investigationDFDeNormalizedUp[[targetVariable]], \
                         targetVariable, lowerLimit, upperLimit)

# %%
advice = 0
countInRange = 0
countViolatedUp = 0
countViolatedDown = 0

advicedDF = investigationDeNormalizedDF.copy()
advicedDF['advice'] = 0
advicedDF['postScaledTargetVariable'] = np.nan

for i in investigationDeNormalizedDF.index:
    distance = 99999999999
    real = investigationDeNormalizedDF[[targetVariable]].get_value(i, targetVariable)
    if( upperLimit > real and lowerLimit < real ):
        advice = 0
        advicedDF.ix[i,'advice'] = 0
        countInRange += 1
        print("ok")
    else:
        print("threshold violation at index " + str(i))
        if( upperLimit < real ):
            countViolatedUp += 1
            print("threshold up violation")
            advice = 0
            postScaledTargetVariable = np.nan # 0
            distance = float('inf')
            for j in range(1, 6):
                print(distance)
                advice = 0
                # két feltételnek kell megfelelnie sorrendben legyen a legkisebb távolsága a felső limittől
                # kettő legyen a felső limit alatt (utóbbi nem biztos, hogy teljesül)
                varName = 'denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'
                relatedTargetVariable = investigationDeNormalizedDF.get_value(i, varName)
                calculatedDistance = investigationDeNormalizedDF.get_value(i, varName)
                if( calculatedDistance < upperLimit ):
                    distance = calculatedDistance
                    advice = j
                    postScaledTargetVariable = relatedTargetVariable
                    break
                print(calculatedDistance)
            advicedDF.ix[i,'advice'] = advice
            advicedDF.ix[i, 'postScaledTargetVariable'] = postScaledTargetVariable
        elif( lowerLimit > real ):
            countViolatedDown += 1
            print("threshold down violation")
            advice = 0
            postScaledTargetVariable = np.nan # 0
            distance = float('-inf')
            for j in range(-1, -3, -1):
                print(distance)
                advice = 0
                # két feltételnek kell megfelelnie sorrendben legyen a legkisebb távolsága az alsó limittől
                # kettő legyen az alsó limit fölött (utóbbi nem biztos, hogy teljesül)
                varName = 'denormalizedPredictedResponseTimeAdded' + str(j) + 'Worker'
                relatedTargetVariable = investigationDeNormalizedDF.get_value(i, varName)
                calculateDistance = investigationDeNormalizedDF.get_value(i, varName)
                if( calculateDistance > lowerLimit ):
                    distance = calculateDistance
                    advice = j
                    postScaledTargetVariable = relatedTargetVariable
                    if( calculateDistance < upperLimit ):
                        distance = calculateDistance
                        advice = j
                        postScaledTargetVariable = relatedTargetVariable
                        break
                    # break
                print(calculateDistance)
            advicedDF.ix[i, 'advice'] = advice
            advicedDF.ix[i, 'postScaledTargetVariable'] = postScaledTargetVariable
# Out:
# threshold violation at index 1
# threshold down violation
# -inf
# 1628245.06284
# -inf
# -987294.019271
# threshold violation at index 2
# threshold down violation
# -inf
# 2479383.08449
# -inf
# 1475498.87798
# threshold violation at index 3
# threshold down violation
# -inf
# 2662209.06749
# -inf
# 1958228.25548
# threshold violation at index 5
# threshold down violation
# -inf
# 1816959.70265
# -inf
# 564852.57562
# threshold violation at index 6
# threshold down violation
# -inf
# 2014192.85393
# -inf
# 917154.364544
# threshold violation at index 7
# threshold down violation
# -inf
# 2287537.65984
# -inf
# 1154879.73454
# threshold violation at index 8
# threshold down violation
# -inf
# 2351000.7106
# -inf
# 1310821.18468
# threshold violation at index 9
# threshold down violation
# -inf
# 2840427.61887
# -inf
# 2074440.39286
# threshold violation at index 10
# threshold down violation
# -inf
# threshold violation at index 11
# threshold down violation
# -inf
# threshold violation at index 12
# threshold down violation
# -inf
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 25
# threshold down violation
# -inf
# 2562404.00571
# -inf
# 2173683.66326
# threshold violation at index 26
# threshold down violation
# -inf
# 2813180.37329
# -inf
# 2355392.26613
# threshold violation at index 27
# threshold down violation
# -inf
# 2640009.20924
# -inf
# 2219137.40038
# threshold violation at index 28
# threshold down violation
# -inf
# 2781145.61901
# -inf
# 1957510.2584
# threshold violation at index 29
# threshold down violation
# -inf
# 2930201.177
# -inf
# 2098683.29557
# threshold violation at index 30
# threshold down violation
# -inf
# threshold violation at index 31
# threshold down violation
# -inf
# 2982655.70215
# -inf
# 2190030.85362
# threshold violation at index 32
# threshold down violation
# -inf
# 2903670.54557
# -inf
# 2079544.34886
# threshold violation at index 33
# threshold down violation
# -inf
# 2937060.96881
# -inf
# 2099305.59741
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 39
# threshold down violation
# -inf
# threshold violation at index 40
# threshold up violation
# inf
# 4283267.5215
# inf
# threshold violation at index 41
# threshold up violation
# inf
# 4769046.56064
# inf
# threshold violation at index 42
# threshold up violation
# inf
# 4513233.47711
# inf
# threshold violation at index 43
# threshold up violation
# inf
# threshold violation at index 44
# threshold up violation
# inf
# ok
# ok
# ok
# threshold violation at index 50
# threshold down violation
# -inf
# 1717720.64692
# -inf
# 1499838.15997
# threshold violation at index 51
# threshold down violation
# -inf
# 1940586.12674
# -inf
# 1579699.60073
# threshold violation at index 52
# threshold down violation
# -inf
# 2662771.6722
# -inf
# 1984006.44191
# threshold violation at index 53
# threshold down violation
# -inf
# 2503878.18963
# -inf
# 1749168.17045
# threshold violation at index 54
# threshold down violation
# -inf
# 2760585.6423
# -inf
# 1838047.74862
# threshold violation at index 55
# threshold down violation
# -inf
# 2821670.48259
# -inf
# 1982729.93923
# threshold violation at index 56
# threshold down violation
# -inf
# 2851746.2829
# -inf
# 1867574.91118
# threshold violation at index 57
# threshold down violation
# -inf
# 2907753.5592
# -inf
# 2721365.56013
# threshold violation at index 58
# threshold down violation
# -inf
# 2499782.23582
# -inf
# 7984252.60222
# threshold violation at index 59
# threshold down violation
# -inf
# 2415434.53869
# -inf
# 8617703.06499
# threshold violation at index 60
# threshold down violation
# -inf
# 2956378.25695
# -inf
# 8379644.90584
# threshold violation at index 61
# threshold down violation
# -inf
# 2843156.71147
# -inf
# 7044603.60111
# threshold violation at index 62
# threshold down violation
# -inf
# 4196413.77628
# 4196413.77628
# 4609254.71822
# threshold violation at index 63
# threshold down violation
# -inf
# threshold violation at index 64
# threshold up violation
# inf
# 6516250.62231
# inf
# 5985571.01973
# inf
# 4305020.83374
# inf
# threshold violation at index 65
# threshold down violation
# -inf
# threshold violation at index 66
# threshold up violation
# inf
# 5264695.80618
# inf
# 4499017.01359
# inf
# threshold violation at index 67
# threshold up violation
# inf
# 5093988.24569
# inf
# 4823808.34957
# inf
# threshold violation at index 68
# threshold up violation
# inf
# 10707162.3957
# inf
# 9084463.8218
# inf
# 7097812.36112
# inf
# 5257137.70912
# inf
# threshold violation at index 70
# threshold up violation
# inf
# 5242347.14842
# inf
# 4321542.19002
# inf
# threshold violation at index 72
# threshold up violation
# inf
# threshold violation at index 74
# /home/sparkuser/anaconda3/envs/optimizer/lib/python3.6/site-packages/ipykernel_launcher.py:67: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# threshold up violation
# inf
# ok
# ok
# threshold violation at index 77
# threshold down violation
# -inf
# -3116025.16767
# -inf
# -2592506.61704
# threshold violation at index 78
# threshold down violation
# -inf
# 1646179.41654
# -inf
# -1256542.96522
# threshold violation at index 79
# threshold down violation
# -inf
# 2886468.39588
# -inf
# 6761190.74374
# threshold violation at index 80
# threshold down violation
# -inf
# 2473979.85835
# -inf
# 7723185.20849
# threshold violation at index 81
# threshold down violation
# -inf
# 2899208.05934
# -inf
# 6824502.22529
# threshold violation at index 82
# threshold down violation
# -inf
# 2463871.20762
# -inf
# 8023143.61999
# threshold violation at index 83
# threshold down violation
# -inf
# 2703253.80119
# -inf
# 7468962.17033
# threshold violation at index 84
# threshold down violation
# -inf
# 2078136.15579
# -inf
# 8453757.23059
# threshold violation at index 85
# threshold down violation
# -inf
# 2389068.26517
# -inf
# 7391480.08523
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 91
# threshold down violation
# -inf
# 2417214.10306
# -inf
# 903163.412414
# threshold violation at index 92
# threshold down violation
# -inf
# 2689001.8515
# -inf
# 1341488.49195
# threshold violation at index 94
# threshold down violation
# -inf
# 2415301.19888
# -inf
# 1410796.38636
# threshold violation at index 95
# threshold down violation
# -inf
# threshold violation at index 96
# threshold down violation
# -inf
# threshold violation at index 98
# threshold up violation
# inf
# threshold violation at index 99
# threshold down violation
# -inf
# 2707234.60162
# -inf
# 2036920.4111
# ok
# threshold violation at index 101
# threshold down violation
# -inf
# 2902800.87013
# -inf
# 2087791.54809
# threshold violation at index 102
# threshold down violation
# -inf
# threshold violation at index 103
# threshold down violation
# -inf
# threshold violation at index 104
# threshold down violation
# -inf
# 2967587.18473
# -inf
# 2364996.31287
# threshold violation at index 105
# threshold down violation
# -inf
# threshold violation at index 106
# threshold up violation
# inf
# threshold violation at index 107
# threshold up violation
# inf
# threshold violation at index 108
# threshold up violation
# inf
# threshold violation at index 109
# threshold up violation
# inf
# threshold violation at index 110
# threshold up violation
# inf
# threshold violation at index 111
# threshold up violation
# inf
# threshold violation at index 112
# threshold up violation
# inf
# ok
# threshold violation at index 114
# threshold down violation
# -inf
# threshold violation at index 115
# threshold down violation
# -inf
# threshold violation at index 116
# threshold down violation
# -inf
# 2576997.91305
# -inf
# 5043211.49247
# threshold violation at index 117
# threshold up violation
# inf
# 6654035.36251
# inf
# 6681827.57713
# inf
# 5358166.72544
# inf
# threshold violation at index 118
# threshold up violation
# inf
# 4491207.51053
# inf
# threshold violation at index 119
# threshold up violation
# inf
# 4409136.34134
# inf
# threshold violation at index 120
# threshold up violation
# inf
# threshold violation at index 121
# threshold down violation
# -inf
# 2939054.90459
# -inf
# 6171409.27882
# threshold violation at index 122
# threshold up violation
# inf
# 6012117.00353
# inf
# 5184841.5973
# inf
# threshold violation at index 123
# threshold up violation
# inf
# 4650887.79572
# inf
# ok
# threshold violation at index 125
# threshold up violation
# inf
# 4380888.09461
# inf
# ok
# threshold violation at index 127
# threshold up violation
# inf
# 4564474.30025
# inf
# threshold violation at index 128
# threshold up violation
# inf
# threshold violation at index 130
# threshold up violation
# inf
# threshold violation at index 132
# threshold up violation
# inf
# threshold violation at index 134
# threshold down violation
# -inf
# -3132502.46729
# -inf
# -2584638.44196
# threshold violation at index 135
# threshold down violation
# -inf
# -2736691.25123
# -inf
# -2162640.10435
# threshold violation at index 136
# threshold down violation
# -inf
# -1903103.85045
# -inf
# -1327704.56271
# threshold violation at index 137
# threshold down violation
# -inf
# -1008352.68008
# -inf
# -954118.858517
# threshold violation at index 138
# threshold down violation
# -inf
# 2004111.05601
# -inf
# 988715.064524
# threshold violation at index 139
# threshold down violation
# -inf
# threshold violation at index 140
# threshold down violation
# -inf
# threshold violation at index 141
# threshold down violation
# -inf
# 2806287.45342
# -inf
# 2320059.80961
# threshold violation at index 142
# threshold down violation
# -inf
# threshold violation at index 143
# threshold down violation
# -inf
# 2500387.84362
# -inf
# 7943049.01276
# threshold violation at index 144
# threshold down violation
# -inf
# 2303329.59808
# -inf
# 8520612.95114
# threshold violation at index 145
# threshold down violation
# -inf
# 2828997.06829
# -inf
# 7178818.07606
# threshold violation at index 146
# threshold down violation
# -inf
# 2738037.661
# -inf
# 7753904.68471
# threshold violation at index 147
# threshold up violation
# inf
# 5632487.83371
# inf
# 4481601.92734
# inf
# threshold violation at index 149
# threshold down violation
# -inf
# threshold violation at index 150
# threshold down violation
# -inf
# 2489262.42232
# -inf
# 2745218.48075
# ok
# threshold violation at index 152
# threshold down violation
# -inf
# 2586333.05427
# -inf
# 2622734.32701
# threshold violation at index 153
# threshold down violation
# -inf
# 2313675.86558
# -inf
# 2557440.22984
# threshold violation at index 154
# threshold down violation
# -inf
# 2420517.51927
# -inf
# 2057868.6042
# threshold violation at index 155
# threshold down violation
# -inf
# 2932315.78457
# -inf
# 2995181.46836
# threshold violation at index 156
# threshold down violation
# -inf
# 2996843.33171
# -inf
# -8171179.23107
# threshold violation at index 157
# threshold down violation
# -inf
# 2347332.9663
# -inf
# -8886127.39355
# threshold violation at index 158
# threshold down violation
# -inf
# threshold violation at index 159
# threshold down violation
# -inf
# threshold violation at index 160
# threshold down violation
# -inf
# threshold violation at index 161
# threshold down violation
# -inf
# 4698621.1989
# 4698621.1989
# -8421944.31619
# threshold violation at index 162
# threshold down violation
# -inf
# 2469710.90423
# -inf
# -9172035.88129
# threshold violation at index 163
# threshold down violation
# -inf
# threshold violation at index 164
# threshold down violation
# -inf
# threshold violation at index 166
# threshold down violation
# -inf
# 8078786.70282
# 8078786.70282
# 7367181.25516
# threshold violation at index 168
# threshold down violation
# -inf
# -2629025.94229
# -inf
# -1874556.9919
# threshold violation at index 170
# threshold down violation
# -inf
# -2161201.64415
# -inf
# -1783216.71402
# threshold violation at index 171
# threshold down violation
# -inf
# -625730.243874
# -inf
# -616530.176479
# threshold violation at index 172
# threshold down violation
# -inf
# 1027352.89099
# -inf
# 204232.22428
# threshold violation at index 173
# threshold down violation
# -inf
# 1609029.06892
# -inf
# 585072.619288
# threshold violation at index 174
# threshold down violation
# -inf
# 1903810.69795
# -inf
# 726328.164852
# threshold violation at index 175
# threshold down violation
# -inf
# 1903972.73181
# -inf
# 1654724.25034
# threshold violation at index 176
# threshold down violation
# -inf
# 2020757.27272
# -inf
# 2315126.15348
# threshold violation at index 177
# threshold down violation
# -inf
# 2541007.02556
# -inf
# 2011378.85028
# threshold violation at index 179
# threshold down violation
# -inf
# 2035526.72657
# -inf
# 1704630.73781
# threshold violation at index 180
# threshold down violation
# -inf
# 2223983.3828
# -inf
# 1766261.36808
# threshold violation at index 181
# threshold down violation
# -inf
# 2495025.03064
# -inf
# 1539765.93036
# threshold violation at index 182
# threshold down violation
# -inf
# threshold violation at index 183
# threshold down violation
# -inf
# threshold violation at index 184
# threshold down violation
# -inf
# threshold violation at index 187
# threshold down violation
# -inf
# threshold violation at index 192
# threshold up violation
# inf
# 7005664.40911
# inf
# 4098906.84666
# inf
# threshold violation at index 194
# threshold up violation
# inf
# ok
# threshold violation at index 196
# threshold up violation
# inf
# threshold violation at index 197
# threshold up violation
# inf
# threshold violation at index 198
# threshold up violation
# inf
# threshold violation at index 199
# threshold down violation
# -inf
# threshold violation at index 200
# threshold down violation
# -inf
# 5505670.44994
# 5505670.44994
# threshold violation at index 202
# threshold up violation
# inf
# ok
# threshold violation at index 205
# threshold down violation
# -inf
# -1897380.33713
# -inf
# -1337513.38259
# threshold violation at index 206
# threshold down violation
# -inf
# -2609577.54234
# -inf
# -2062125.60348
# threshold violation at index 207
# threshold down violation
# -inf
# -3918004.8621
# -inf
# -3609655.74493
# threshold violation at index 208
# threshold down violation
# -inf
# -4080328.86843
# -inf
# -3483721.63319
# threshold violation at index 209
# threshold down violation
# -inf
# 1716099.97471
# -inf
# -950539.97907
# threshold violation at index 210
# threshold down violation
# -inf
# 2889007.68731
# -inf
# 7020175.42879
# threshold violation at index 211
# threshold down violation
# -inf
# 2675177.06519
# -inf
# 6700141.24456
# threshold violation at index 212
# threshold down violation
# -inf
# 2734360.1735
# -inf
# 6798828.31016
# threshold violation at index 213
# threshold down violation
# -inf
# 2081914.16809
# -inf
# 8462581.47882
# threshold violation at index 214
# threshold down violation
# -inf
# 2875157.42265
# -inf
# 7271180.18939
# threshold violation at index 215
# threshold down violation
# -inf
# ok
# ok
# threshold violation at index 218
# threshold up violation
# inf
# threshold violation at index 219
# threshold up violation
# inf
# threshold violation at index 220
# threshold up violation
# inf
# threshold violation at index 223
# threshold down violation
# -inf
# -1361642.60565
# -inf
# -547673.378129
# threshold violation at index 224
# threshold down violation
# -inf
# -675624.690604
# -inf
# 37583.0200382
# threshold violation at index 225
# threshold down violation
# -inf
# 380924.524913
# -inf
# 809461.385114
# threshold violation at index 226
# threshold down violation
# -inf
# 1345028.46718
# -inf
# 1380420.23486
# threshold violation at index 227
# threshold down violation
# -inf
# 2013111.26066
# -inf
# 1644857.76175
# threshold violation at index 228
# threshold down violation
# -inf
# 2019845.68292
# -inf
# 1624118.61904
# threshold violation at index 229
# threshold down violation
# -inf
# 1542258.56273
# -inf
# 1667946.98383
# threshold violation at index 230
# threshold down violation
# -inf
# 2562477.41098
# -inf
# 2770378.71038
# threshold violation at index 232
# threshold down violation
# -inf
# 2443543.37882
# -inf
# 2217633.79657
# threshold violation at index 233
# threshold down violation
# -inf
# 2949954.55351
# -inf
# 2499759.41094
# threshold violation at index 234
# threshold down violation
# -inf
# 2945826.80016
# -inf
# 2484484.57501
# threshold violation at index 235
# threshold down violation
# -inf
# 2583987.54654
# -inf
# 1862189.22277
# threshold violation at index 236
# threshold down violation
# -inf
# threshold violation at index 237
# threshold down violation
# -inf
# threshold violation at index 238
# threshold down violation
# -inf
# 2930846.0219
# -inf
# 2184240.78686
# threshold violation at index 239
# threshold down violation
# -inf
# 2901376.19854
# -inf
# 2197627.6359
# threshold violation at index 240
# threshold down violation
# -inf
# ok
# threshold violation at index 242
# threshold down violation
# -inf
# 2928718.88906
# -inf
# 2665212.85321
# ok
# threshold violation at index 244
# threshold up violation
# inf
# 4665661.12346
# inf
# threshold violation at index 245
# threshold up violation
# inf
# threshold violation at index 246
# threshold up violation
# inf
# ok
# threshold violation at index 248
# threshold down violation
# -inf
# 4004829.33148
# 4004829.33148
# 4398815.74912
# threshold violation at index 249
# threshold up violation
# inf
# threshold violation at index 250
# threshold up violation
# inf
# 4260120.67595
# inf
# threshold violation at index 251
# threshold up violation
# inf
# 4692415.79395
# inf
# threshold violation at index 252
# threshold up violation
# inf
# 4465797.00051
# inf
# threshold violation at index 253
# threshold up violation
# inf
# 6104901.68132
# inf
# 5063074.24127
# inf
# threshold violation at index 254
# threshold down violation
# -inf
# threshold violation at index 258
# threshold up violation
# inf
# 6499282.9521
# inf
# 6040119.34798
# inf
# threshold violation at index 259
# threshold up violation
# inf
# 5342469.47553
# inf
# threshold violation at index 260
# threshold up violation
# inf
# 6661175.93433
# inf
# 4350542.60104
# inf
# threshold violation at index 268
# threshold up violation
# inf
# 8131553.2555
# inf
# 4353282.50622
# inf
# threshold violation at index 269
# threshold up violation
# inf
# 13155358.6498
# inf
# 8596067.90961
# inf
# 5255375.30948
# inf
# threshold violation at index 270
# threshold up violation
# inf
# 6817900.11135
# inf
# 4535410.08253
# inf
# threshold violation at index 271
# threshold up violation
# inf
# 4355622.02343
# inf
# threshold violation at index 272
# threshold up violation
# inf
# 4892868.87435
# inf
# threshold violation at index 273
# threshold up violation
# inf
# ok
# ok
# threshold violation at index 276
# threshold down violation
# -inf
# 2197202.22364
# -inf
# threshold violation at index 277
# threshold down violation
# -inf
# threshold violation at index 278
# threshold down violation
# -inf
# 6426721.14774
# 6426721.14774
# 6708353.62337
# ok
# threshold violation at index 281
# threshold down violation
# -inf
# 2784266.69256
# -inf
# 5084597.57304
# threshold violation at index 282
# threshold down violation
# -inf
# 2675343.37307
# -inf
# 5930720.46133
# threshold violation at index 283
# threshold down violation
# -inf
# 2288266.48082
# -inf
# 7399926.05977
# threshold violation at index 284
# threshold down violation
# -inf
# 2433013.81707
# -inf
# 7748886.00929
# threshold violation at index 285
# threshold down violation
# -inf
# 2649800.69193
# -inf
# 7088585.30999
# threshold violation at index 286
# threshold down violation
# -inf
# 2648276.524
# -inf
# 7264908.2342
# threshold violation at index 287
# threshold down violation
# -inf
# 9371608.70081
# 9371608.70081
# 5503142.41944
# ok
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 295
# threshold down violation
# -inf
# 2266478.84272
# -inf
# 1214880.56554
# threshold violation at index 296
# threshold down violation
# -inf
# 1429719.27177
# -inf
# 1495495.94499
# threshold violation at index 297
# threshold down violation
# -inf
# 2110122.22163
# -inf
# 1984419.41513
# threshold violation at index 299
# threshold down violation
# -inf
# 2270437.1405
# -inf
# 1706186.25275
# threshold violation at index 300
# threshold down violation
# -inf
# 2450471.97452
# -inf
# 1732315.87612
# threshold violation at index 301
# threshold down violation
# -inf
# 2647082.96543
# -inf
# 1874719.91144
# threshold violation at index 302
# threshold down violation
# -inf
# 2787468.36423
# -inf
# 2022712.30536
# threshold violation at index 303
# threshold down violation
# -inf
# 2751756.18288
# -inf
# 2202410.35213
# threshold violation at index 304
# threshold down violation
# -inf
# 2840788.65574
# -inf
# 2159244.84178
# threshold violation at index 305
# threshold down violation
# -inf
# 2944706.46838
# -inf
# 2489812.93954
# threshold violation at index 306
# threshold down violation
# -inf
# 2609310.27953
# -inf
# 2645534.7713
# threshold violation at index 307
# threshold down violation
# -inf
# 4706569.69308
# 4706569.69308
# ok
# threshold violation at index 309
# threshold down violation
# -inf
# 2038183.28094
# -inf
# 1581411.21108
# ok
# ok
# threshold violation at index 312
# threshold up violation
# inf
# threshold violation at index 313
# threshold up violation
# inf
# ok
# ok
# ok
# ok
# threshold violation at index 318
# threshold down violation
# -inf
# 4178736.40034
# 4178736.40034
# 5922758.69456
# threshold violation at index 319
# threshold down violation
# -inf
# 12670937.232
# 12670937.232
# 1454129.73854
# threshold violation at index 326
# threshold up violation
# inf
# 6535782.5575
# inf
# 6140015.45922
# inf
# threshold violation at index 332
# threshold up violation
# inf
# 4614249.68844
# inf
# threshold violation at index 333
# threshold up violation
# inf
# 4514237.68363
# inf
# threshold violation at index 334
# threshold up violation
# inf
# 5811414.36303
# inf
# 4335024.94696
# inf
# threshold violation at index 335
# threshold up violation
# inf
# 5806533.27041
# inf
# 4575740.43896
# inf
# threshold violation at index 336
# threshold up violation
# inf
# 5364779.76698
# inf
# threshold violation at index 337
# threshold up violation
# inf
# 5101220.6122
# inf
# threshold violation at index 338
# threshold up violation
# inf
# 4182802.61853
# inf
# ok
# threshold violation at index 341
# threshold down violation
# -inf
# 2032550.20955
# -inf
# 60518.9486131
# threshold violation at index 342
# threshold down violation
# -inf
# 431181.094208
# -inf
# -3411112.65992
# threshold violation at index 343
# threshold down violation
# -inf
# -748345.968042
# -inf
# -4081070.62127
# threshold violation at index 344
# threshold down violation
# -inf
# 35995.1361081
# -inf
# -3501805.03149
# threshold violation at index 345
# threshold down violation
# -inf
# 1058443.96321
# -inf
# -2074882.58945
# threshold violation at index 346
# threshold down violation
# -inf
# 2102160.18956
# -inf
# 724412.574036
# threshold violation at index 347
# threshold down violation
# -inf
# 2668574.59521
# -inf
# 1495184.62872
# threshold violation at index 349
# threshold down violation
# -inf
# 1693479.13033
# -inf
# 489831.912475
# threshold violation at index 350
# threshold down violation
# -inf
# 2230233.93885
# -inf
# 972994.816206
# threshold violation at index 351
# threshold down violation
# -inf
# 2195863.53412
# -inf
# 1093768.50621
# threshold violation at index 352
# threshold down violation
# -inf
# 2777294.68378
# -inf
# 2088558.28764
# threshold violation at index 353
# threshold down violation
# -inf
# threshold violation at index 354
# threshold down violation
# -inf
# 2890996.38586
# -inf
# 2245168.61215
# threshold violation at index 355
# threshold down violation
# -inf
# 2917004.14302
# -inf
# 2163094.83233
# threshold violation at index 356
# threshold down violation
# -inf
# 2606286.42736
# -inf
# 1621345.29796
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 363
# threshold down violation
# -inf
# ok
# ok
# threshold violation at index 366
# threshold up violation
# inf
# threshold violation at index 368
# threshold up violation
# inf
# threshold violation at index 369
# threshold up violation
# inf
# threshold violation at index 370
# threshold up violation
# inf
# ok
# ok
# threshold violation at index 373
# threshold down violation
# -inf
# ok
# ok
# ok
# threshold violation at index 377
# threshold down violation
# -inf
# threshold violation at index 378
# threshold down violation
# -inf
# ok
# threshold violation at index 380
# threshold down violation
# -inf
# threshold violation at index 381
# threshold up violation
# inf
# 4438327.52231
# inf
# threshold violation at index 382
# threshold down violation
# -inf
# threshold violation at index 383
# threshold up violation
# inf
# 4510422.20803
# inf
# threshold violation at index 384
# threshold up violation
# inf
# threshold violation at index 385
# threshold up violation
# inf
# threshold violation at index 386
# threshold up violation
# inf
# threshold violation at index 387
# threshold up violation
# inf
# ok
# threshold violation at index 389
# threshold down violation
# -inf
# 4428917.63232
# 4428917.63232
# threshold violation at index 391
# threshold up violation
# inf
# ok
# threshold violation at index 394
# threshold up violation
# inf
# ok
# ok
# ok
# threshold violation at index 398
# threshold down violation
# -inf
# 2988287.42614
# -inf
# 2045782.64245
# threshold violation at index 399
# threshold down violation
# -inf
# 2974972.85857
# -inf
# 2077626.39506
# threshold violation at index 400
# threshold down violation
# -inf
# threshold violation at index 401
# threshold down violation
# -inf
# 2987467.11822
# -inf
# 2160314.23505
# threshold violation at index 402
# threshold down violation
# -inf
# 2934301.81546
# -inf
# 2203460.83673
# ok
# threshold violation at index 404
# threshold down violation
# -inf
# threshold violation at index 407
# threshold up violation
# inf
# 6776046.58006
# inf
# 6378508.63434
# inf
# 5041931.41727
# inf
# threshold violation at index 408
# threshold up violation
# inf
# 4550769.11009
# inf
# threshold violation at index 409
# threshold up violation
# inf
# threshold violation at index 410
# threshold up violation
# inf
# threshold violation at index 411
# threshold up violation
# inf
# 4663943.74489
# inf
# threshold violation at index 412
# threshold up violation
# inf
# 5904161.79713
# inf
# 5104141.94759
# inf
# threshold violation at index 413
# threshold down violation
# -inf
# 4302251.12563
# 4302251.12563
# 1983388.01705
# threshold violation at index 414
# threshold up violation
# inf
# 6737624.42394
# inf
# 5842296.27386
# inf
# 4763615.32606
# inf
# ok
# threshold violation at index 418
# threshold up violation
# inf
# ok
# ok
# ok
# threshold violation at index 423
# threshold down violation
# -inf
# 2505193.93227
# -inf
# threshold violation at index 424
# threshold down violation
# -inf
# 2731503.78862
# -inf
# 5279795.91261
# threshold violation at index 425
# threshold down violation
# -inf
# threshold violation at index 426
# threshold down violation
# -inf
# threshold violation at index 427
# threshold down violation
# -inf
# threshold violation at index 428
# threshold down violation
# -inf
# 4175957.78564
# 4175957.78564
# 5852449.93441
# threshold violation at index 429
# threshold down violation
# -inf
# threshold violation at index 430
# threshold down violation
# -inf
# threshold violation at index 431
# threshold down violation
# -inf
# threshold violation at index 434
# threshold up violation
# inf
# 7898024.52597
# inf
# 7528717.52774
# inf
# 6289652.55294
# inf
# 4832610.34914
# inf
# threshold violation at index 435
# threshold up violation
# inf
# threshold violation at index 437
# threshold up violation
# inf
# ok
# threshold violation at index 439
# threshold up violation
# inf
# 4450534.22056
# inf
# threshold violation at index 440
# threshold up violation
# inf
# threshold violation at index 441
# threshold up violation
# inf
# threshold violation at index 442
# threshold up violation
# inf
# ok
# threshold violation at index 444
# threshold down violation
# -inf
# 2748549.64879
# -inf
# threshold violation at index 446
# threshold down violation
# -inf
# -431514.662163
# -inf
# 92638.1778112
# threshold violation at index 447
# threshold down violation
# -inf
# 424812.295544
# -inf
# 742001.070842
# threshold violation at index 448
# threshold down violation
# -inf
# 1155268.47512
# -inf
# 1211379.62367
# threshold violation at index 449
# threshold down violation
# -inf
# 1931250.37463
# -inf
# 1767208.67724
# threshold violation at index 450
# threshold down violation
# -inf
# 2099386.25702
# -inf
# 1862142.6469
# threshold violation at index 451
# threshold down violation
# -inf
# 2266165.76564
# -inf
# 1931678.40466
# threshold violation at index 452
# threshold down violation
# -inf
# 2001222.04096
# -inf
# 1683134.74719
# threshold violation at index 453
# threshold down violation
# -inf
# 2261447.09788
# -inf
# 2150945.82289
# threshold violation at index 454
# threshold down violation
# -inf
# 2662705.0715
# -inf
# 2765443.04393
# ok
# ok
# threshold violation at index 458
# threshold down violation
# -inf
# threshold violation at index 459
# threshold down violation
# -inf
# 2565339.69105
# -inf
# 2187339.55116
# ok
# threshold violation at index 461
# threshold down violation
# -inf
# 2666667.53863
# -inf
# 1968462.65718
# threshold violation at index 462
# threshold down violation
# -inf
# ok
# threshold violation at index 464
# threshold down violation
# -inf
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 470
# threshold down violation
# -inf
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 485
# threshold down violation
# -inf
# 1810399.30501
# -inf
# 1774694.79326
# threshold violation at index 486
# threshold down violation
# -inf
# 2554825.35157
# -inf
# 2247585.70217
# threshold violation at index 487
# threshold down violation
# -inf
# 2668277.62023
# -inf
# 2254325.59623
# threshold violation at index 488
# threshold down violation
# -inf
# 2412417.46358
# -inf
# 1388895.79376
# threshold violation at index 489
# threshold down violation
# -inf
# 2977267.42845
# -inf
# 2200279.64717
# threshold violation at index 490
# threshold down violation
# -inf
# threshold violation at index 491
# threshold down violation
# -inf
# threshold violation at index 492
# threshold down violation
# -inf
# ok
# ok
# ok
# threshold violation at index 496
# threshold down violation
# -inf
# ok
# threshold violation at index 498
# threshold up violation
# inf
# threshold violation at index 499
# threshold up violation
# inf
# 5012918.18812
# inf
# ok
# threshold violation at index 501
# threshold up violation
# inf
# 6235578.21277
# inf
# 5623374.65115
# inf
# threshold violation at index 502
# threshold up violation
# inf
# 4799432.93179
# inf
# threshold violation at index 503
# threshold up violation
# inf
# 4457342.19105
# inf
# threshold violation at index 504
# threshold up violation
# inf
# 4337846.43505
# inf
# threshold violation at index 505
# threshold up violation
# inf
# 4638703.52905
# inf
# threshold violation at index 506
# threshold up violation
# inf
# 4635462.99996
# inf
# threshold violation at index 507
# threshold down violation
# -inf
# threshold violation at index 508
# threshold down violation
# -inf
# 5610612.60945
# 5610612.60945
# -8327632.65158
# threshold violation at index 511
# threshold down violation
# -inf
# 6451956.75087
# 6451956.75087
# -7965199.1358
# threshold violation at index 512
# threshold down violation
# -inf
# 4580301.30191
# 4580301.30191
# -7257891.09569
# threshold violation at index 513
# threshold down violation
# -inf
# 4011155.26135
# 4011155.26135
# -8504944.43223
# threshold violation at index 514
# threshold down violation
# -inf
# 4509587.47713
# 4509587.47713
# -6786292.0859
# threshold violation at index 515
# threshold down violation
# -inf
# threshold violation at index 516
# threshold down violation
# -inf
# 13178814.3933
# 13178814.3933
# 12641335.2635
# threshold violation at index 518
# threshold down violation
# -inf
# 8989737.86904
# 8989737.86904
# 8193639.94995
# threshold violation at index 520
# threshold down violation
# -inf
# -1493936.86451
# -inf
# -1094981.83447
# threshold violation at index 522
# threshold down violation
# -inf
# -2623082.9221
# -inf
# -2059689.6264
# threshold violation at index 523
# threshold down violation
# -inf
# -1772292.10921
# -inf
# -1548158.5139
# threshold violation at index 524
# threshold down violation
# -inf
# -523063.630353
# -inf
# -1083154.45881
# threshold violation at index 525
# threshold down violation
# -inf
# 104052.123101
# -inf
# -935736.028873
# threshold violation at index 526
# threshold down violation
# -inf
# 1232138.0206
# -inf
# 223013.456386
# threshold violation at index 527
# threshold down violation
# -inf
# 1424764.70692
# -inf
# 505355.392861
# threshold violation at index 528
# threshold down violation
# -inf
# 1061978.93226
# -inf
# 1653910.18427
# ok
# threshold violation at index 531
# threshold down violation
# -inf
# 2005543.02026
# -inf
# 1728653.56839
# threshold violation at index 532
# threshold down violation
# -inf
# 2344074.27978
# -inf
# 1934394.00923
# threshold violation at index 533
# threshold down violation
# -inf
# 2627413.82629
# -inf
# 2163470.07825
# ok
# threshold violation at index 535
# threshold down violation
# -inf
# threshold violation at index 536
# threshold down violation
# -inf
# ok
# ok
# ok
# threshold violation at index 542
# threshold up violation
# inf
# 4051065.19382
# inf
# threshold violation at index 543
# threshold up violation
# inf
# 6199390.99929
# inf
# 6107995.97951
# inf
# 5321740.93656
# inf
# 4402785.28895
# inf
# threshold violation at index 544
# threshold up violation
# inf
# 9817128.51351
# inf
# 7353676.5467
# inf
# 5290160.56591
# inf
# threshold violation at index 546
# threshold up violation
# inf
# 4100012.43763
# inf
# threshold violation at index 547
# threshold up violation
# inf
# threshold violation at index 548
# threshold up violation
# inf
# 4270526.77071
# inf
# threshold violation at index 549
# threshold up violation
# inf
# threshold violation at index 550
# threshold up violation
# inf
# 4231178.94981
# inf
# threshold violation at index 551
# threshold up violation
# inf
# 4206084.55404
# inf
# threshold violation at index 552
# threshold up violation
# inf
# ok
# threshold violation at index 555
# threshold down violation
# -inf
# 2308452.41558
# -inf
# 2221305.90475
# ok
# threshold violation at index 558
# threshold up violation
# inf
# threshold violation at index 559
# threshold up violation
# inf
# threshold violation at index 560
# threshold down violation
# -inf
# threshold violation at index 561
# threshold down violation
# -inf
# threshold violation at index 562
# threshold down violation
# -inf
# 4455153.52679
# 4455153.52679
# 5516522.09754
# threshold violation at index 563
# threshold down violation
# -inf
# threshold violation at index 564
# threshold down violation
# -inf
# 4279403.34994
# 4279403.34994
# 5577842.16792
# threshold violation at index 565
# threshold down violation
# -inf
# threshold violation at index 566
# threshold up violation
# inf
# 6053305.45138
# inf
# 5310825.66868
# inf
# threshold violation at index 567
# threshold up violation
# inf
# 4209742.9656
# inf
# threshold violation at index 568
# threshold up violation
# inf
# 6370925.06289
# inf
# 5597573.20443
# inf
# threshold violation at index 569
# threshold up violation
# inf
# 6167190.074
# inf
# 5522916.75526
# inf
# 4179054.75064
# inf
# threshold violation at index 570
# threshold up violation
# inf
# 11790097.0834
# inf
# 8052385.62292
# inf
# 5365447.47658
# inf
# threshold violation at index 572
# threshold up violation
# inf
# 9837671.53165
# inf
# 7985658.2356
# inf
# 6248416.86741
# inf
# 4724133.52108
# inf
# threshold violation at index 574
# threshold up violation
# inf
# threshold violation at index 575
# threshold up violation
# inf
# threshold violation at index 576
# threshold up violation
# inf
# threshold violation at index 577
# threshold up violation
# inf
# threshold violation at index 578
# threshold up violation
# inf
# threshold violation at index 579
# threshold up violation
# inf
# threshold violation at index 580
# threshold up violation
# inf
# ok
# ok
# ok
# ok
# threshold violation at index 585
# threshold up violation
# inf
# threshold violation at index 586
# threshold up violation
# inf
# ok
# ok
# threshold violation at index 589
# threshold down violation
# -inf
# 2877802.85167
# -inf
# 2163690.06066
# threshold violation at index 590
# threshold down violation
# -inf
# threshold violation at index 591
# threshold down violation
# -inf
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 597
# threshold up violation
# inf
# threshold violation at index 598
# threshold up violation
# inf
# threshold violation at index 599
# threshold down violation
# -inf
# threshold violation at index 600
# threshold up violation
# inf
# 4627883.24382
# inf
# 4015734.9376
# inf
# threshold violation at index 601
# threshold down violation
# -inf
# 2836470.06693
# -inf
# 4220025.63471
# threshold violation at index 602
# threshold down violation
# -inf
# ok
# threshold violation at index 604
# threshold up violation
# inf
# 4126194.56878
# inf
# threshold violation at index 605
# threshold up violation
# inf
# 4353832.23948
# inf
# ok
# threshold violation at index 607
# threshold up violation
# inf
# 6572351.62331
# inf
# 5359865.6725
# inf
# threshold violation at index 608
# threshold up violation
# inf
# 4609828.13555
# inf
# threshold violation at index 609
# threshold up violation
# inf
# 4615109.07059
# inf
# threshold violation at index 610
# threshold up violation
# inf
# 4623326.19958
# inf
# ok
# ok
# ok
# threshold violation at index 616
# threshold up violation
# inf
# 5928374.00012
# inf
# 5050084.73706
# inf
# threshold violation at index 622
# threshold up violation
# inf
# ok
# ok
# threshold violation at index 625
# threshold down violation
# -inf
# 1869854.4933
# -inf
# ok
# threshold violation at index 627
# threshold down violation
# -inf
# threshold violation at index 628
# threshold down violation
# -inf
# 2406853.40767
# -inf
# 8953375.86418
# threshold violation at index 629
# threshold down violation
# -inf
# 8036092.06686
# 8036092.06686
# 8156388.04853
# ok
# threshold violation at index 632
# threshold down violation
# -inf
# ok
# ok
# ok
# threshold violation at index 636
# threshold down violation
# -inf
# threshold violation at index 637
# threshold down violation
# -inf
# 2626314.20438
# -inf
# 7887967.72985
# threshold violation at index 638
# threshold up violation
# inf
# 4360307.42543
# inf
# threshold violation at index 639
# threshold up violation
# inf
# threshold violation at index 641
# threshold up violation
# inf
# ok
# ok
# ok
# ok
# threshold violation at index 646
# threshold down violation
# -inf
# ok
# threshold violation at index 648
# threshold down violation
# -inf
# 2261303.70406
# -inf
# 1746350.62241
# threshold violation at index 649
# threshold up violation
# inf
# ok
# ok
# threshold violation at index 652
# threshold down violation
# -inf
# 2485714.69649
# -inf
# 1656242.58799
# ok
# threshold violation at index 654
# threshold down violation
# -inf
# 2943513.50753
# -inf
# 2198019.9681
# ok
# threshold violation at index 656
# threshold down violation
# -inf
# 2926047.59955
# -inf
# 2408215.36346
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 662
# threshold up violation
# inf
# threshold violation at index 663
# threshold up violation
# inf
# threshold violation at index 664
# threshold up violation
# inf
# threshold violation at index 665
# threshold up violation
# inf
# threshold violation at index 666
# threshold up violation
# inf
# threshold violation at index 667
# threshold up violation
# inf
# ok
# threshold violation at index 669
# threshold up violation
# inf
# threshold violation at index 670
# threshold up violation
# inf
# threshold violation at index 671
# threshold up violation
# inf
# threshold violation at index 672
# threshold up violation
# inf
# threshold violation at index 673
# threshold up violation
# inf
# threshold violation at index 674
# threshold up violation
# inf
# threshold violation at index 675
# threshold up violation
# inf
# threshold violation at index 676
# threshold up violation
# inf
# threshold violation at index 677
# threshold up violation
# inf
# threshold violation at index 678
# threshold up violation
# inf
# threshold violation at index 679
# threshold up violation
# inf
# ok
# threshold violation at index 681
# threshold down violation
# -inf
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 687
# threshold up violation
# inf
# threshold violation at index 688
# threshold up violation
# inf
# ok
# threshold violation at index 690
# threshold up violation
# inf
# threshold violation at index 691
# threshold up violation
# inf
# ok
# ok
# ok
# threshold violation at index 695
# threshold up violation
# inf
# threshold violation at index 696
# threshold up violation
# inf
# threshold violation at index 697
# threshold up violation
# inf
# threshold violation at index 698
# threshold up violation
# inf
# threshold violation at index 699
# threshold up violation
# inf
# ok
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 706
# threshold down violation
# -inf
# 1422143.98108
# -inf
# 1230002.42532
# threshold violation at index 707
# threshold down violation
# -inf
# 1653053.65949
# -inf
# 1501982.48505
# threshold violation at index 708
# threshold down violation
# -inf
# 1753814.59301
# -inf
# 1624366.49087
# threshold violation at index 709
# threshold down violation
# -inf
# 1799344.11412
# -inf
# 1595463.36218
# threshold violation at index 710
# threshold down violation
# -inf
# 1693184.67495
# -inf
# 1569834.60453
# ok
# threshold violation at index 712
# threshold down violation
# -inf
# 2075978.31737
# -inf
# 1679485.88533
# threshold violation at index 713
# threshold down violation
# -inf
# 4135113.93935
# 4135113.93935
# ok
# threshold violation at index 715
# threshold down violation
# -inf
# 2670079.62633
# -inf
# 2062161.64853
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# threshold violation at index 731
# threshold up violation
# inf
# threshold violation at index 732
# threshold up violation
# inf
# ok
# ok
# ok
# threshold violation at index 736
# threshold up violation
# inf
# threshold violation at index 737
# threshold up violation
# inf
# threshold violation at index 738
# threshold up violation
# inf
# threshold violation at index 739
# threshold up violation
# inf
# threshold violation at index 740
# threshold up violation
# inf
# ok
# threshold violation at index 742
# threshold up violation
# inf
# threshold violation at index 743
# threshold up violation
# inf
# ok
# ok
# ok
# threshold violation at index 747
# threshold up violation
# inf
# ok
# threshold violation at index 749
# threshold up violation
# inf
# threshold violation at index 750
# threshold up violation
# inf
# threshold violation at index 751
# threshold up violation
# inf
# threshold violation at index 752
# threshold up violation
# inf
# threshold violation at index 753
# threshold up violation
# inf
# threshold violation at index 754
# threshold up violation
# inf

# %%
advicedDF.head(10).style.set_properties(**pandas_dataframe_styles).format("{:0.0f}")
# Out:
# <style  type="text/css" >
#     #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row0_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row1_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row2_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row3_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d304f102_aeb3_11e9_b6b8_fa163ebcacb

# %%
VisualizePredictedXYLine(advicedDF[['advice']] * 2000000, advicedDF[[targetVariable]], \
                         targetVariable, lowerLimit, upperLimit)

# %%
print('countInRange      = ', countInRange)
print('countViolatedDown = ', countViolatedDown)
print('countVilolatedUp  = ', countViolatedUp)
# Out:
# countInRange      =  190
# countViolatedDown =  282
# countVilolatedUp  =  187

# %%
VisualizePredictedXY2Line(advicedDF[[targetVariable]], advicedDF[['advice']], \
                         targetVariable, lowerLimit, upperLimit)

# %%
from visualizerlinux import VisualizePredictedXY3Line

# %%
VisualizePredictedXY3Line(advicedDF[[targetVariable]], \
                          advicedDF[['postScaledTargetVariable']], \
                          advicedDF[['advice']], \
                          targetVariable, lowerLimit, upperLimit)

# %%
advicedDF.style.set_properties(**pandas_dataframe_styles).format("{:0.2f}")
# Out:
# <style  type="text/css" >
#     #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row0_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row1_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row2_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col8 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col9 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col10 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col11 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row3_col12 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col0 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col1 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col2 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col3 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col4 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col5 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col6 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb9row4_col7 {
#             font-family:  monospace;
#             white-space:  pre;
#         }    #T_d47bb282_aeb3_11e9_b6b8_fa163ebcacb

# %%
advicedDF.to_csv('outputs/adviceDF.csv', sep=';', encoding='utf-8')
